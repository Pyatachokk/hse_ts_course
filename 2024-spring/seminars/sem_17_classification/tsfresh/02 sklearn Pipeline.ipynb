# %% [markdown]
# # Feature Selection in a sklearn pipeline

# %% [markdown]
# This notebook is quite similar to [the first example](./01%20Feature%20Extraction%20and%20Selection.ipynb).
# This time however, we use the `sklearn` pipeline API of `tsfresh`.
# If you want to learn more, have a look at [the documentation](https://tsfresh.readthedocs.io/en/latest/text/sklearn_transformers.html).

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

from tsfresh.examples import load_robot_execution_failures
from tsfresh.transformers import RelevantFeatureAugmenter
from tsfresh.utilities.dataframe_functions import impute

# %% [markdown]
# ## Load and Prepare the Data

# %% [markdown]
# Check out the first example notebook to learn more about the data and format.

# %%
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures
download_robot_execution_failures() 
df_ts, y = load_robot_execution_failures()

# %% [markdown]
# We want to use the extracted features to predict for each of the robot executions, if it was a failure or not.
# Therefore our basic "entity" is a single robot execution given by a distinct `id`.
#
# A dataframe with these identifiers as index needs to be prepared for the pipeline.

# %%
X = pd.DataFrame(index=y.index)

# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ## Build the pipeline

# %% [markdown]
# We build a sklearn pipeline that consists of a feature extraction step (`RelevantFeatureAugmenter`) with a subsequent `RandomForestClassifier`.
#
# The `RelevantFeatureAugmenter` takes roughly the same arguments as `extract_features` and `select_features` do.

# %%
ppl = Pipeline([
        ('augmenter', RelevantFeatureAugmenter(column_id='id', column_sort='time')),
        ('classifier', RandomForestClassifier())
      ])

# %% [markdown]
# <div class="alert alert-warning">
#
# Here comes the tricky part!
#
# The input to the pipeline will be our dataframe `X`, which one row per identifier.
# It is currently empty.
# But which time series data should the `RelevantFeatureAugmenter` to actually extract the features from?
#
# We need to pass the time series data (stored in `df_ts`) to the transformer.
#
# </div>

# %% [markdown]
# In this case, df_ts contains the time series of both train and test set, if you have different dataframes for
# train and test set, you have to call set_params two times
# (see further below on how to deal with two independent data sets)

# %%
ppl.set_params(augmenter__timeseries_container=df_ts);

# %% [markdown]
# We are now ready to fit the pipeline

# %%
ppl.fit(X_train, y_train)
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:06<00:00,  3.19it/s]
# /Users/mszekhov/Desktop/current_projects/hse_ts_course/venv/lib/python3.10/site-packages/tsfresh/utilities/dataframe_functions.py:198: RuntimeWarning: The columns ['F_x__partial_autocorrelation__lag_7'
#  'F_x__partial_autocorrelation__lag_8'
#  'F_x__partial_autocorrelation__lag_9' ...
#  'T_z__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"mean"'
#  'T_z__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"var"'
#  'T_z__query_similarity_count__query_None__threshold_0.0'] did not have any finite values. Filling with zeros.
#   warnings.warn(
# Pipeline(steps=[('augmenter',
#                  RelevantFeatureAugmenter(column_id='id', column_sort='time',
#                                           timeseries_container=      id  time  F_x  F_y  F_z  T_x  T_y  T_z
# 0      1     0   -1   -1   63   -3   -1    0
# 1      1     1    0    0   62   -3   -1    0
# 2      1     2   -1   -1   61   -3    0    0
# 3      1     3   -1   -1   63   -2   -1    0
# 4      1     4   -1   -1   63   -3   -1    0
# ...   ..   ...  ...  ...  ...  ...  ...  ...
# 1315  88    10  -10    2   39  -21  -24    5
# 1316  88    11  -11    2   38  -24  -22    6
# 1317  88    12  -12    3   23  -24  -24    5
# 1318  88    13  -13    4   26  -29  -27    5
# 1319  88    14  -13    2   15  -25  -25    6
#
# [1320 rows x 8 columns])),
#                 ('classifier', RandomForestClassifier())])

# %% [markdown]
# The augmenter has used the input time series data to extract time series features for each of the identifiers in the `X_train` and selected only the relevant ones using the passed `y_train` as target.
# These features have been added to `X_train` as new columns.
# The classifier can now use these features during trainings.

# %% [markdown]
# ## Prediction

# %% [markdown]
# During interference, the augmentor does only extract the relevant features it has found out in the training phase and the classifier predicts the target using these features.

# %%
y_pred = ppl.predict(X_test)
# Out:
# Feature Extraction: 100%|██████████| 19/19 [00:02<00:00,  8.15it/s]

# %% [markdown]
# So, finally we inspect the performance:

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00        16
#         True       1.00      1.00      1.00         6
#
#     accuracy                           1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22

# %% [markdown]
# You can also find out, which columns the augmenter has selected

# %%
ppl.named_steps["augmenter"].feature_selector.relevant_features
# Out:
# ['F_x__value_count__value_-1',
#  'F_x__range_count__max_1__min_-1',
#  'F_x__mean_n_absolute_max__number_of_maxima_7',
#  'F_x__variance',
#  'F_x__abs_energy',
#  'F_x__root_mean_square',
#  'F_x__standard_deviation',
#  'F_y__abs_energy',
#  'F_y__root_mean_square',
#  'F_x__fft_coefficient__attr_"abs"__coeff_1',
#  'T_y__absolute_maximum',
#  'F_y__mean_n_absolute_max__number_of_maxima_7',
#  'F_x__absolute_maximum',
#  'T_y__variance',
#  'T_y__standard_deviation',
#  'F_x__ratio_value_number_to_time_series_length',
#  'T_x__variance',
#  'T_x__standard_deviation',
#  'T_x__absolute_maximum',
#  'F_y__absolute_maximum',
#  'T_y__fft_coefficient__attr_"abs"__coeff_1',
#  'T_x__ratio_value_number_to_time_series_length',
#  'F_z__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'T_x__fft_coefficient__attr_"abs"__coeff_2',
#  'F_z__standard_deviation',
#  'T_y__root_mean_square',
#  'T_y__fft_coefficient__attr_"abs"__coeff_2',
#  'F_z__variance',
#  'F_x__fft_coefficient__attr_"abs"__coeff_4',
#  'T_y__abs_energy',
#  'T_y__mean_n_absolute_max__number_of_maxima_7',
#  'F_x__variance_larger_than_standard_deviation',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'F_x__lempel_ziv_complexity__bins_100',
#  'F_x__fft_coefficient__attr_"abs"__coeff_2',
#  'T_y__linear_trend__attr_"stderr"',
#  'F_x__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'T_x__fft_coefficient__attr_"abs"__coeff_1',
#  'T_x__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'T_y__fft_coefficient__attr_"abs"__coeff_3',
#  'F_x__linear_trend__attr_"stderr"',
#  'F_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'F_x__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'T_y__fft_coefficient__attr_"abs"__coeff_4',
#  'T_z__mean_n_absolute_max__number_of_maxima_7',
#  'F_y__variance',
#  'T_x__fft_coefficient__attr_"abs"__coeff_5',
#  'F_y__standard_deviation',
#  'F_x__fft_coefficient__attr_"abs"__coeff_3',
#  'T_z__variance',
#  'T_z__standard_deviation',
#  'F_x__fft_coefficient__attr_"abs"__coeff_0',
#  'T_z__abs_energy',
#  'T_z__root_mean_square',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'F_x__autocorrelation__lag_1',
#  'F_x__partial_autocorrelation__lag_1',
#  'F_x__cid_ce__normalize_True',
#  'T_x__mean_n_absolute_max__number_of_maxima_7',
#  'T_y__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'T_y__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'F_z__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#  'T_z__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'F_y__ratio_value_number_to_time_series_length',
#  'T_y__percentage_of_reoccurring_values_to_all_values',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'F_y__fft_coefficient__attr_"abs"__coeff_2',
#  'T_x__fft_coefficient__attr_"abs"__coeff_4',
#  'F_y__fft_coefficient__attr_"abs"__coeff_0',
#  'T_x__fft_coefficient__attr_"abs"__coeff_3',
#  'T_z__ratio_value_number_to_time_series_length',
#  'F_x__approximate_entropy__m_2__r_0.1',
#  'F_y__fft_coefficient__attr_"abs"__coeff_1',
#  'T_x__root_mean_square',
#  'T_x__abs_energy',
#  'T_z__absolute_maximum',
#  'F_z__fft_coefficient__attr_"abs"__coeff_1',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'T_y__ratio_value_number_to_time_series_length',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'T_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'T_x__cid_ce__normalize_False',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'T_x__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'T_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'F_z__fft_aggregated__aggtype_"centroid"',
#  'T_z__fft_coefficient__attr_"abs"__coeff_1',
#  'F_z__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'T_y__cid_ce__normalize_False',
#  'F_z__fft_coefficient__attr_"abs"__coeff_6',
#  'T_z__linear_trend__attr_"stderr"',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'T_x__absolute_sum_of_changes',
#  'T_x__mean_abs_change',
#  'F_y__range_count__max_1__min_-1',
#  'T_x__approximate_entropy__m_2__r_0.9',
#  'F_z__approximate_entropy__m_2__r_0.9',
#  'F_x__fft_aggregated__aggtype_"variance"',
#  'T_x__linear_trend__attr_"stderr"',
#  'T_z__range_count__max_1__min_-1',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'F_x__cid_ce__normalize_False',
#  'F_z__fft_coefficient__attr_"abs"__coeff_2',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'F_z__fft_coefficient__attr_"abs"__coeff_3',
#  'F_y__lempel_ziv_complexity__bins_100',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'F_z__minimum',
#  'F_y__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'T_y__spkt_welch_density__coeff_2',
#  'F_x__spkt_welch_density__coeff_2',
#  'T_z__fft_coefficient__attr_"abs"__coeff_4',
#  'T_z__lempel_ziv_complexity__bins_100',
#  'F_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'T_z__absolute_sum_of_changes',
#  'T_z__mean_abs_change',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'F_y__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#  'T_z__variance_larger_than_standard_deviation',
#  'F_z__quantile__q_0.1',
#  'T_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'F_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'T_z__cid_ce__normalize_False',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'T_z__fft_coefficient__attr_"abs"__coeff_0',
#  'T_z__fft_coefficient__attr_"abs"__coeff_2',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'T_x__percentage_of_reoccurring_values_to_all_values',
#  'T_z__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#  'F_z__fft_aggregated__aggtype_"skew"',
#  'F_z__sum_of_reoccurring_data_points',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'F_z__fft_coefficient__attr_"abs"__coeff_4',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'F_x__absolute_sum_of_changes',
#  'F_x__mean_abs_change',
#  'T_y__approximate_entropy__m_2__r_0.9',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'F_y__fft_coefficient__attr_"abs"__coeff_4',
#  'F_z__linear_trend__attr_"stderr"',
#  'F_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'F_z__fft_aggregated__aggtype_"variance"',
#  'F_z__ratio_value_number_to_time_series_length',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'T_y__fft_coefficient__attr_"abs"__coeff_7',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'T_z__fft_coefficient__attr_"abs"__coeff_5',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'T_x__fft_coefficient__attr_"abs"__coeff_7',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'F_z__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'T_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'T_x__fft_coefficient__attr_"abs"__coeff_6',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'T_y__mean_abs_change',
#  'T_y__absolute_sum_of_changes',
#  'F_z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#  'T_y__fft_coefficient__attr_"abs"__coeff_5',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'T_y__fft_coefficient__attr_"abs"__coeff_6',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'T_x__fourier_entropy__bins_5',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'F_z__fft_coefficient__attr_"abs"__coeff_5',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'F_z__cid_ce__normalize_False',
#  'F_y__linear_trend__attr_"stderr"',
#  'T_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'F_y__fft_coefficient__attr_"abs"__coeff_3',
#  'F_x__longest_strike_above_mean',
#  'F_y__fft_coefficient__attr_"abs"__coeff_5',
#  'F_y__value_count__value_-1',
#  'T_x__fourier_entropy__bins_10',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'T_x__cid_ce__normalize_True',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'T_z__fft_coefficient__attr_"abs"__coeff_6',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'F_z__quantile__q_0.2',
#  'T_y__cid_ce__normalize_True',
#  'F_x__percentage_of_reoccurring_values_to_all_values',
#  'F_z__absolute_sum_of_changes',
#  'F_z__mean_abs_change',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'F_y__cid_ce__normalize_True',
#  'T_z__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'T_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'T_x__spkt_welch_density__coeff_2',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'T_z__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'F_z__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'F_z__percentage_of_reoccurring_values_to_all_values',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'F_x__autocorrelation__lag_9',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  'T_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'F_y__fft_aggregated__aggtype_"variance"',
#  'T_z__has_duplicate_min',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'F_x__value_count__value_0',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'T_x__lempel_ziv_complexity__bins_100',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'F_z__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'T_y__lempel_ziv_complexity__bins_100',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'F_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'F_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'F_z__fft_aggregated__aggtype_"kurtosis"',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'F_x__fft_coefficient__attr_"abs"__coeff_5',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'F_y__percentage_of_reoccurring_values_to_all_values',
#  'F_z__sum_of_reoccurring_values',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'F_z__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"max"',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'F_x__number_crossing_m__m_-1',
#  'T_y__autocorrelation__lag_1',
#  'T_y__partial_autocorrelation__lag_1',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'T_z__value_count__value_0',
#  'T_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'F_y__cid_ce__normalize_False',
#  'T_z__binned_entropy__max_bins_10',
#  'T_y__fft_aggregated__aggtype_"variance"',
#  'F_x__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'F_y__mean_abs_change',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'F_y__absolute_sum_of_changes',
#  'F_z__agg_autocorrelation__f_agg_"median"__maxlag_40',
#  'F_y__value_count__value_0',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'F_x__benford_correlation',
#  'F_y__fft_coefficient__attr_"abs"__coeff_6',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'F_x__fft_coefficient__attr_"abs"__coeff_7',
#  'T_z__fft_coefficient__attr_"abs"__coeff_3',
#  'F_x__fft_coefficient__attr_"abs"__coeff_6',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'F_z__fft_coefficient__attr_"abs"__coeff_7',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'F_z__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'F_z__approximate_entropy__m_2__r_0.7',
#  'F_z__fourier_entropy__bins_100',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'T_y__approximate_entropy__m_2__r_0.7',
#  'F_z__cid_ce__normalize_True',
#  'F_y__autocorrelation__lag_1',
#  'F_y__partial_autocorrelation__lag_1',
#  'F_z__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'F_z__quantile__q_0.3',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'F_z__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#  'T_z__fft_coefficient__attr_"abs"__coeff_7',
#  'F_z__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_1__w_10__widths_(2, 5, 10, 20)',
#  'F_y__maximum',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'F_z__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#  'F_x__linear_trend__attr_"pvalue"',
#  'F_z__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'T_y__fft_coefficient__attr_"abs"__coeff_0',
#  'F_z__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'F_x__autocorrelation__lag_7',
#  'F_z__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'F_z__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#  'F_y__value_count__value_1',
#  'T_z__percentage_of_reoccurring_values_to_all_values',
#  'F_y__spkt_welch_density__coeff_2',
#  'F_y__number_crossing_m__m_0',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'F_z__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#  'F_z__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'F_z__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#  'T_y__fft_aggregated__aggtype_"kurtosis"',
#  'T_x__fourier_entropy__bins_2',
#  'F_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'F_z__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#  'F_z__longest_strike_above_mean',
#  'F_y__fourier_entropy__bins_5',
#  'F_z__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'T_x__fourier_entropy__bins_3',
#  'F_z__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'F_z__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#  'F_z__c3__lag_3',
#  'F_z__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#  'F_y__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"min"',
#  'F_z__fourier_entropy__bins_10',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'T_x__autocorrelation__lag_1',
#  'F_z__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#  'T_x__partial_autocorrelation__lag_1',
#  'F_z__mean',
#  'F_z__sum_values',
#  'F_z__fft_coefficient__attr_"real"__coeff_0',
#  'T_x__fft_coefficient__attr_"abs"__coeff_0',
#  'F_z__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'F_z__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#  'T_x__fourier_entropy__bins_100',
#  'T_z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'F_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'F_z__fourier_entropy__bins_5',
#  'T_z__last_location_of_minimum',
#  'F_x__approximate_entropy__m_2__r_0.9',
#  'T_y__ratio_beyond_r_sigma__r_1',
#  'F_z__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#  'F_y__quantile__q_0.9',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'F_z__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#  'T_x__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'F_z__benford_correlation',
#  'F_y__approximate_entropy__m_2__r_0.9',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'F_z__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#  'F_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'T_x__approximate_entropy__m_2__r_0.7',
#  'F_z__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'F_z__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'F_z__quantile__q_0.4',
#  'F_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'F_z__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#  'F_z__spkt_welch_density__coeff_2',
#  'F_y__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'T_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'T_z__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'F_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'F_z__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"max"',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'F_z__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'F_z__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#  'F_z__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'F_z__count_below__t_0',
#  'F_z__range_count__max_1000000000000.0__min_0',
#  'F_z__range_count__max_0__min_-1000000000000.0',
#  'F_z__count_above__t_0',
#  'F_z__median',
#  'F_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'T_z__spkt_welch_density__coeff_2',
#  'T_z__lempel_ziv_complexity__bins_10',
#  'F_z__cwt_coefficients__coeff_14__w_5__widths_(2, 5, 10, 20)',
#  'F_z__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#  'T_z__approximate_entropy__m_2__r_0.5',
#  'F_z__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)',
#  'T_x__sample_entropy',
#  'F_z__fft_coefficient__attr_"angle"__coeff_0',
#  'T_x__fft_aggregated__aggtype_"kurtosis"',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'T_z__approximate_entropy__m_2__r_0.3',
#  'F_z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#  'T_x__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#  'F_z__fourier_entropy__bins_3',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'T_z__approximate_entropy__m_2__r_0.1',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'F_z__quantile__q_0.8',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'F_y__benford_correlation',
#  'F_z__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)',
#  'F_y__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#  'F_y__number_crossing_m__m_-1',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'F_y__fft_coefficient__attr_"abs"__coeff_7',
#  'F_x__augmented_dickey_fuller__attr_"usedlag"__autolag_"AIC"',
#  'F_z__partial_autocorrelation__lag_1',
#  'F_z__autocorrelation__lag_1',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'F_z__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'F_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  'T_y__autocorrelation__lag_9',
#  'F_z__cwt_coefficients__coeff_11__w_5__widths_(2, 5, 10, 20)',
#  'F_z__fourier_entropy__bins_2',
#  'F_x__binned_entropy__max_bins_10',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'F_z__autocorrelation__lag_2',
#  'F_z__c3__lag_1',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'F_x__agg_autocorrelation__f_agg_"median"__maxlag_40',
#  'F_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'T_y__linear_trend__attr_"pvalue"',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'F_z__quantile__q_0.7',
#  'F_y__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'T_x__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'F_x__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'T_x__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'T_z__approximate_entropy__m_2__r_0.9',
#  'F_y__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"var"',
#  'F_z__last_location_of_maximum',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'T_x__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  'F_z__cwt_coefficients__coeff_12__w_5__widths_(2, 5, 10, 20)',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  'F_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'T_y__fft_coefficient__attr_"angle"__coeff_0',
#  'F_x__fourier_entropy__bins_2',
#  'T_y__longest_strike_above_mean',
#  'F_y__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#  'F_z__number_cwt_peaks__n_5',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'F_x__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'T_z__minimum',
#  'T_z__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'F_y__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'F_z__cwt_coefficients__coeff_13__w_5__widths_(2, 5, 10, 20)',
#  'F_z__quantile__q_0.6',
#  'T_z__approximate_entropy__m_2__r_0.7',
#  'F_z__linear_trend__attr_"pvalue"',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'T_x__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'F_x__fft_coefficient__attr_"angle"__coeff_0',
#  'F_z__c3__lag_2',
#  'T_y__agg_autocorrelation__f_agg_"median"__maxlag_40',
#  'F_x__maximum',
#  'F_z__cwt_coefficients__coeff_13__w_2__widths_(2, 5, 10, 20)',
#  'F_z__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#  'F_x__count_below__t_0',
#  'F_y__fourier_entropy__bins_10',
#  'F_y__permutation_entropy__dimension_4__tau_1',
#  'F_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'T_z__symmetry_looking__r_0.15000000000000002',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'F_y__fourier_entropy__bins_3',
#  'F_x__lempel_ziv_complexity__bins_10',
#  'T_x__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"max"',
#  'F_y__last_location_of_minimum',
#  'T_y__count_below__t_0',
#  'F_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'F_z__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#  'F_x__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  'F_z__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#  'T_x__has_duplicate_min',
#  'F_y__cwt_coefficients__coeff_12__w_2__widths_(2, 5, 10, 20)',
#  'T_z__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'F_z__cwt_coefficients__coeff_12__w_2__widths_(2, 5, 10, 20)',
#  'T_x__lempel_ziv_complexity__bins_2',
#  'F_x__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'F_z__absolute_maximum',
#  'F_y__fft_aggregated__aggtype_"centroid"',
#  'T_y__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#  'F_y__linear_trend__attr_"pvalue"',
#  'F_z__quantile__q_0.9',
#  'F_y__autocorrelation__lag_3',
#  'T_y__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#  'F_z__fft_coefficient__attr_"imag"__coeff_5',
#  'T_z__value_count__value_-1',
#  'T_y__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#  'F_y__approximate_entropy__m_2__r_0.7',
#  'F_z__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"var"',
#  'F_y__permutation_entropy__dimension_5__tau_1',
#  'T_z__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'T_x__ratio_beyond_r_sigma__r_1']

# %% [markdown]
# <div class="alert alert-info">
#
# In this example we passed in an empty (except the index) `X_train` or `X_test` into the pipeline.
# However, you can also fill the input with other features you have (e.g. features extracted from the metadata)
# or even use other pipeline components before.
#
# </div>

# %% [markdown]
# ## Separating the time series data containers

# %% [markdown]
# In the example above we passed in a single `df_ts` into the `RelevantFeatureAugmenter`, which was used both for training and predicting.
# During training, only the data with the `id`s from `X_train` where extracted and during prediction the rest.
#
# However, it is perfectly fine to call `set_params` twice: once before training and once before prediction.
# This can be handy if you for example dump the trained pipeline to disk and re-use it only later for prediction.
# You only need to make sure that the `id`s of the enteties you use during training/prediction are actually present in the passed time series data.

# %%
df_ts_train = df_ts[df_ts["id"].isin(y_train.index)]
df_ts_test = df_ts[df_ts["id"].isin(y_test.index)]

# %%
ppl.set_params(augmenter__timeseries_container=df_ts_train);
ppl.fit(X_train, y_train);
# Out:
# Feature Extraction: 100%|██████████| 20/20 [00:05<00:00,  3.94it/s]
# /Users/mszekhov/Desktop/current_projects/hse_ts_course/venv/lib/python3.10/site-packages/tsfresh/utilities/dataframe_functions.py:198: RuntimeWarning: The columns ['F_x__partial_autocorrelation__lag_7'
#  'F_x__partial_autocorrelation__lag_8'
#  'F_x__partial_autocorrelation__lag_9' ...
#  'T_z__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"mean"'
#  'T_z__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"var"'
#  'T_z__query_similarity_count__query_None__threshold_0.0'] did not have any finite values. Filling with zeros.
#   warnings.warn(

# %%
import pickle
with open("pipeline.pkl", "wb") as f:
    pickle.dump(ppl, f)

# %% [markdown]
# Later: load the fitted model and do predictions on new, unseen data

# %%
import pickle
with open("pipeline.pkl", "rb") as f:
    ppk = pickle.load(f)

# %%
ppl.set_params(augmenter__timeseries_container=df_ts_test);
y_pred = ppl.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
