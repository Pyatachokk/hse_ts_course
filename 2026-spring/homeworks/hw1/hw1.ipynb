# %% [markdown]
# # Домашнее задание 1

# %% [markdown]
# NB! Важный дисклеймер, который нужно учитывать во всех домашних заданиях по курсу. Обосновывайте ваши действия. При проверке нам важно увидеть, что вы комплексно подходите к задаче и понимаете, зачем нужны те или иные шаги.
#
# Примеры важных моментов:
#
# * Я использую следующие предпосылки: ...
# * Я выбираю метрику X, потому что ...
# * Я выбираю горизонт прогнозирования Y, потому что ...
# * Я выбираю ETS-спецификацию Z, потому что ...
# * Я использую преобразование ряда, потому что ...
# * ...
#
# Необоснованные действия могут остаться без оценки. Там, где это явно необходимо, добавлены markdown-ячейки для ответа. Но вы, конечно, можете добавлять дополнительные.

# %% [markdown]
# Мы сотрудники одного из крупных банков с развитой сетью банкоматов. Предположим, что мы рассматриваем банкоматы, которые работают только на выдачу наличных. Возможно на текущий момент это редкость, но для периода, когда собирался датасет, они были распространены.
#
# Наша задача состоит в том, чтобы предсказать спрос на наличность и вовремя загрузить в банкомат деньги, чтобы он работал бесперебойно. В то же время, мы хотим не гонять доблестных инкассаторов к наполовину полным банкоматам, так как их перемещения стоят денег. Попытаемся построить модель, которая для конкретного банкомата будет прогнозировать количество денег, которые будет необходимо выдать в следующие периоды.
#
# Конечно, в оригинале задача была сложнее, так как банкоматы могут ломаться и простаивать, о чём вендору известно. Ещё, например, некоторые банкоматы доступны 24 часа в сутки, а некоторые -- наоборот, стоят в закрываемых помещениях. Но мы на такой уровень погружаться не будем.
#
# В файле `data.csv` представлены три временных ряда. Каждый из них представляет собой объём выданной наличности в определённом банкомате.
#
# В файле `description.csv` представлено краткое описание каждого банкомата: ID, Адрес, описание местоположения, а также географические координаты.
#
# **В этой домашней работе необходимо использовать все три ряда.**
#
# Рекомендуется использовать набор библиотек Nixtla.
#
# Проверка остатков выполняется тестом Ljung-Box.
#
# Ограничение на модели: в этом ДЗ используем только ETS-модели.
#
# **Внимание!** ДЗ построено по наиболее стандартному шаблону прогнозирования, описанному в лекции. Некоторые пункты будут напрямую влиять на последующие. Крайне рекомендуется сначала внимательно прочитать все пункты задания, а уже потом приступать к выполнению, чтобы сэкономить себе время на переделку.

# %% [markdown]
# ## 1) Подгрузка и первичная подготовка данных (1.2 балла)

# %% [markdown]
# ### 1.1) Загрузка данных (0.3 балла)
#
# Загрузите `data.csv` и `description.csv`. Преобразуйте колонку `Date` в формат `pd.Timestamp`.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 1.2) Частота и целостность (0.3 балла)
#
# Установите частоту ряда, конвертируйте даты к этой частоте, проверьте целостность данных (есть ли пропуски), отсортируйте данные по времени.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 1.3) Краткий отчёт по рядам (0.3 балла)
#
# Для каждого из трёх рядов выведите: длину ряда, долю нулей и долю пропусков.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 1.4) Подготовка формата (0.3 балла)
#
# Преобразуйте данные в формат, удобный для единообразной обработки трёх рядов. Формат зависит от библиотек, которые вы будете использовать далее. Например, Nixtla требует long-формата, где ряды различаются только по категориальному столбцу и вытянуты в вектор.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ## 2) EDA и интерпретация (2.3 балла)

# %% [markdown]
# ### 2.1) Полные графики рядов (0.4 балла)
#
# Постройте графики всех трёх рядов на полном доступном интервале.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 2.2) Локальные графики (0.3 балла)
#
# Постройте локальные графики (например, последний год или квартал), чтобы лучше увидеть сезонность, выбросы и структурные особенности. Опишите значимые паттерны, которые сможете обнаружить. Постройте дополнительные графики, если сочтёте их необходимыми.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 2.3) Коррелограммы и их интерпретация (0.5 балла)
#
# Постройте ACF и интерпретируйте значимые пики.
#
# Обратите внимание, что ACF корректно определена для стационарных рядов. Вы можете привести ряды к стационарному виду, применив переход к дельтам (возможно, дважды):
#
# $$\Delta y_t = y_t - y_{t-1}$$
#
# Мы пока что не прошли специализированные тесты на стационарность, но есть простое rule of thumb. Если ряд нестационарный, то его оценённые ACF высокие и очень медленно убывают, а PACF близка к 1 на первом лаге и около-нулевая на остальных.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 2.4) Дополнительные исследования (0.5 балла)
#
# Сделайте дополнительные исследования, которые считаете полезными (например, boxplot по дням недели/месяцам, rolling-статистики, сравнение волатильности рядов и т.д.). Исходите из специфики задачи и моделей, которые вы планируете оценивать. Проинтерпретируйте полученные статистики.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 2.5) Итоговые выводы по каждому ряду (0.6 балла)
#
# Для каждого ряда опишите наблюдаемые особенности: тренд, сезонность, аномалии, нули, ожидаемые риски для ETS-моделей и любые дополнительные аспекты, которые сочтёте нужными.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ## 3) Дизайн forecasting-эксперимента (1.8 балла)

# %% [markdown]
# ### 3.1) Выбор метрики (0.5 балла)
#
# Выберите метрику качества и обоснуйте выбор на основе свойств рядов (нули, масштаб, устойчивость). Вы вправе предложить нестандартную метрику, если обоснуете её дизайн.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 3.2) Выбор горизонта прогнозирования (0.4 балла)
#
# Выберите горизонт прогнозирования и обоснуйте его практическим смыслом задачи и характеристиками рядов.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 3.3) Разбиение на train/test (0.4 балла)
#
# Разбейте данные на train и test без утечек, с единой логикой для всех трёх рядов. Длина test -- горизонт прогнозирования

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 3.4) Дополнительные обратимые преобразования (0.5 балла)
#
# При необходимости выполните преобразования на train (например, для стабилизации дисперсии/ обработки нулей и т.п.). Обоснуйте проведённые преобразования. Преобразования должны быть обратимыми, так как метрики считаются в исходных величинах.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ## 4) ETS-кандидаты и кросс-валидация expanding window (2.7 балла)

# %% [markdown]
# ### 4.1) Набор моделей-кандидатов (0.6 балла)
#
# Выберите 5-6 ETS-моделей-кандидатов и обоснуйте, почему они подходят под структуру рядов.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 4.2) Выбор периода сезонности (0.5 балла)
#
# Определите сезонный период по самому сильному пику коррелограмм. Вновь, используйте стационарные версии рядов.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 4.3) Кросс-валидация expanding window (1 балл)
#
# Проведите кросс-валидацию на каждом ряде для выбранных ETS-кандидатов методом расширяющегося окна на train-части. Вам необходимо определить два параметра: стартовый размер train и шаг окна, на которое он будет расширяться. Размер validation равен горизонту прогнозирования.
#
# Рекомендации.
# 1) Не берите слишком маленький стартовый train. Хотя бы 4-5 горизонтов прогнозирования стоит включить. В качестве простого варианта можете взять половину доступных данных.
# 2) Чем меньше сдвиг окна, тем больше мы проведём вычислений и тем устойчивее метрика кросс-валидации. В идеале можно взять 1. Если будет слишком должно считаться, повысьте.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 4.4) Выбор двух лучших моделей (0.6 балла)
#
# Сравните качество моделей, соберите сводную таблицу по трём рядам и выберите две лучшие модели по каждому.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ## 5) Финальная валидация и тест (2.0 балла)

# %% [markdown]
# ### 5.1) Дообучение на полном train (0.3 балла)
#
# Оцените две лучшие модели на всём train по каждому ряду.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 5.2) Остатки и Ljung-Box (0.6 балла)
#
# Постройте in-sample остатки обеих моделей и проведите тест Ljung-Box. Проинтерпретируйте результаты. В данном случае данные слишком сложны для ETS-модели и у вас не получится получить белый шум, но я решил не выбрасывать этот пункт из пайплайна в целях тренировки.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 5.3) Прогноз на test и визуализация (0.3 балла)
#
# Постройте прогнозы обеих моделей на test и визуализируйте факт/прогноз для каждого из трёх рядов. В итоге должно получиться три графика следующего вида:
#
# 1) Небольшая часть train (1-2 горизонта)
# 2) Ground truth test
# 3) Прогнозы двух моделей разными цветами

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 5.4) Сравнение моделей и тест Диболда-Мариано (0.5 балла)
#
# Сравните качество моделей на test и проведите тест Диболда-Мариано на сравнение двух моделей по каждому ряду. Различимы ли по качеству модели на каждом из рядов? Выберите по каждому ряду лучшую модель.

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 5.5) Оцените бейзлайн-модель (0.3)
#
# Вычислите метрику на тестовых данных для сезонной наивной модели c аналогичным периодом сезонности. Сравните с метриками ваших моделей. Получилось ли побить качество по отдельным рядам и в среднем для всех рядов?

# %%
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# #### Ответ
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ### 5.6) Бонус. (0.1 балла)
# Расскажите, чем бы вы занимались, если бы не нужно было думать о деньгах.

# %% [markdown]
# ### 5.7) Бонус. Рубрика 'как вам домашка?' (0.1 балла)
#
# Пройдите короткий опрос. Это действительно важно. https://forms.gle/eKQTEKbYKD9YripL8

# %% [markdown]
# ༼ つ ◕_◕ ༽つ

# %% [markdown]
# ## Бонус (2 балла) ETS(A,A,N) как RNN в PyTorch

# %% [markdown]
# ### Cгенерим выборку

# %%
import torch
import torch.nn as nn
import torch.optim as optim
torch.manual_seed(322)

def generate_ets(T, alpha, beta, sigma, l0, b0):
    y = torch.zeros(T)
    l = torch.zeros(T)
    b = torch.zeros(T)
    l_prev = l0
    b_prev = b0

    for t in range(T):
        eps = torch.randn(1) * sigma
        y_hat = l_prev +  b_prev
        y[t] = y_hat + eps
        l_t = l_prev +   b_prev + alpha * eps
        b_t =  b_prev + beta * eps
        l[t] = l_t
        b[t] = b_t

        l_prev, b_prev = l_t, b_t

    return y

# %%
alpha_true = 0.4
beta_true  = 0.2
sigma_true = 0.05
l0_true = 10.0
b0_true = 0.5

T = 1500
y = generate_ets(T, alpha_true, beta_true, sigma_true, l0_true, b0_true)

# %% [markdown]
# ### Цель
#
# Реализовать модель ETS(A,A,N) в виде рекуррентной нейросети (RNN) с вероятностным выходом и обучить её методом максимального правдоподобия на торче
#
#
# #### Напомним модель
#
# ETS(A,A,N) в задаётся системой:
#
# $$
# y_t = \ell_{t-1} + b_{t-1} + \varepsilon_t
# $$
#
# $$
# \ell_t = \ell_{t-1} + b_{t-1} + \alpha \varepsilon_t
# $$
#
# $$
# b_t =  b_{t-1} + \beta \varepsilon_t
# $$
#
# где
#
# $$
# \varepsilon_t \sim \mathcal{N}(0, \sigma^2)
# $$
#
# Скрытое состояние модели:
#
# $$
# h_t = (\ell_t, b_t)
# $$
#
# Таким образом, ETS является линейной RNN со скрытым состоянием размерности 2, как и было показано на семе
#
#
#
# ## Требования к реализации
#
# ### 1. Класс модели
#
# Необходимо реализовать класс:
#
# ```python
# class ETS_RNN(nn.Module):
# ```
#
#
#
# ### 2. Метод `__init__`
#
# В методе инициализации должны быть объявлены обучаемые параметры:
#
# - `alpha_raw`
# - `beta_raw`
# - `log_sigma`
# - `l0`
# - `b0`
#
# Ограничения параметров для стабильности:
#
# $$
# \alpha = \sigma(\text{alpha\_raw})
# $$
#
# $$
# \beta = \sigma(\text{beta\_raw})
# $$
#
#
# $$
# \sigma = \exp(\text{log\_sigma})
# $$
#
# где $\sigma(\cdot)$ — сигмоид-функция.
#
#
#
# ### 3. Метод `forward(self, y)`
#
# Метод `forward` должен:
#
# 1. Преобразовать raw-параметры к допустимым значениям.
# 2. Инициализировать состояние:
#    $$
#    \ell_{\text{prev}} = \ell_0, \quad b_{\text{prev}} = b_0
#    $$
# 3. Пройти циклом по времени (unrolled RNN).
# 4. На каждом шаге:
#    - вычислить прогноз:
#      $$
#      \hat{y}_t = \ell_{\text{prev}} +   b_{\text{prev}}
#      $$
#    - вычислить инновацию:
#      $$
#      \varepsilon_t = y_t - \hat{y}_t
#      $$
#    - обновить состояние:
#      $$
#      \ell_t = \ell_{\text{prev}} +   b_{\text{prev}} + \alpha \varepsilon_t
#      $$
#      $$
#      b_t =   b_{\text{prev}} + \beta \varepsilon_t
#      $$
#    - аккумулировать лог-правдоподобие.
#
#
# ## Функция потерь
#
# Используется отрицательное лог-правдоподобие нормального распределения:
#
# $$
# \log p(y_t \mid \mathcal{F}_{t-1}) =
# -\frac{1}{2}
# \left(
# \log(2\pi\sigma^2) +
# \frac{\varepsilon_t^2}{\sigma^2}
# \right)
# $$
#
# Необходимо аккумулировать лог-правдоподобие по всем $t$ и вернуть:
#
# $$
# \text{NLL} = - \sum_{t=1}^{T} \log p(y_t \mid \mathcal{F}_{t-1})
# $$
#
# В `forward()` необходимо вернуть отрицательное лог-правдоподобие (NLL).
#
# Обучение производится минимизацией NLL.
#
#
#
# ## Обучение
#
# - Использовать оптимизатор Adam или другой торчовский
# - PyTorch автоматически применит BPTT

# %%
class ETS_RNN(nn.Module):
    def __init__(self):
        """
        alpha_raw, beta_raw - smoothing params in (0,1) via sigmoid
        log_sigma - noise std > 0 via exp
        l0, b0 - initial level and trend
        """
        super().__init__()


    def forward(self, y):
        """
        Computes negative log-likelihood for a 1D time series y (shape T).
        Returns: nll (scalar), alpha (scalar), beta (scalar), sigma (scalar).
        """

# %%
model = ETS_RNN()
optimizer =

# training loop

# %% [markdown]
# ### Сравните истинные параметры с оцененными
