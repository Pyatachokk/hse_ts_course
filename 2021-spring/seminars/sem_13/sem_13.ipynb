# %% [markdown]
# Timeseries Classification: KNN & DTW
# ===
# Mark Regan
#
# ---
# When it comes to building a classification algorithm, analysts have a broad range of open source options to choose from. However, for time series classification, there are less out-of-the box solutions. Many of the typical classification algorithms (Logistic Regression, Random Forests, SVM etc) are applicable to time-series data when the temporal data structure is abstracted away through feature engineering.
#
# My experience with this approach has been poor. The full timeseries feature vector contains a large amount of valuable information that can be lost through the process of flattening the datastructure.
#
# I began researching the domain of time series classification and was intrigued by a recommended technique called K Nearest Neighbors and Dynamic Time Warping. A meta analysis completed by Mitsa (2010) suggests that when it comes to timeseries classification, 1 Nearest Neighbor (K=1) and Dynamic Timewarping is very difficult to beat [1].
#
# ##K Nearest Neighbors & Dynamic Time Warping

# %%
from IPython.display import Image
Image('images/dtw_knn_schematic.png', width=780)

# %% [markdown]
# K Nearest Neighbors is a classification algorithm familiar to many. It takes a unlabled observation (the star above) and compares it to a population of labled observations (blue and orange circles). By finding the K nearest circles to the star, we can infer the class label for the star through majority voting.
#
# We can also use KNN in the context of time series data. The question becomes, "how do we compute the distance between two timeseries sequences"? "Dynamic Time Warping" is a technique that was heavily used for speech recognition in the 80s. The DTW algorithm finds the optimum alignment between two sequences of observations by warping the time dimension with certain constraints.
#
# Because of this temporal dimension warping, DTW is good for classifying sequences that have different frequences or that are out of phase. Later we'll see how we can use DTW to classify whether a person is walking, lying down, sitting etc.
#
# The above right diagram shows how a DTW distance matrix representation. Each cell is computed by measuring the distance between $A_i$ and $B_j$. The red path represents the shortest path and hence optimum alignment of the two sequences.
#
# $$DTW_{AB} = SUM(shortest\ paths_{AB})$$
#
# ####Max Warping Window Allowed
# Computing the full distance matrix between A and B scales with $O(n^2)$, where n is the number of sequences in A and B. This performance can be improved by constraining the amount of warping allowed. This limits the number of cells that need to be computed in the DTW distance matrix. Research by Keogh et al has shown that a warping window not only improves performance but also improves classification accuracy [2].

# %%
Image('images/max_window_warping.png')

# %% [markdown]
# ####Coded in Python
# The below python code represents the KNN & DTW classification algorithm. The following key methods are described:
#
# | Method        | Description                                                                                                           |
# |---------------|-----------------------------------------------------------------------------------------------------------------------|
# | `_dtw_distance` | computes the Dynamic Time Warping distance between two sequences                                                      |
# | `_dist_matrix`  | computes the distance matrix between $A$ and $B$                  |
# | `predict`       | uses both of the above methods to compute the class labels and probability of dataset $B$ through K Nearest Neighbors |

# %%
import sys
import collections
import itertools
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import mode
from scipy.spatial.distance import squareform

plt.style.use('bmh')
# %matplotlib inline

try:
    from IPython.display import clear_output
    have_ipython = True
except ImportError:
    have_ipython = False

class KnnDtw(object):
    """K-nearest neighbor classifier using dynamic time warping
    as the distance measure between pairs of time series arrays
    
    Arguments
    ---------
    n_neighbors : int, optional (default = 5)
        Number of neighbors to use by default for KNN
        
    max_warping_window : int, optional (default = infinity)
        Maximum warping window allowed by the DTW dynamic
        programming function
            
    subsample_step : int, optional (default = 1)
        Step size for the timeseries array. By setting subsample_step = 2,
        the timeseries length will be reduced by 50% because every second
        item is skipped. Implemented by x[:, ::subsample_step]
    """
    
    def __init__(self, n_neighbors=5, max_warping_window=10000, subsample_step=1):
        self.n_neighbors = n_neighbors
        self.max_warping_window = max_warping_window
        self.subsample_step = subsample_step
    
    def fit(self, x, l):
        """Fit the model using x as training data and l as class labels
        
        Arguments
        ---------
        x : array of shape [n_samples, n_timepoints]
            Training data set for input into KNN classifer
            
        l : array of shape [n_samples]
            Training labels for input into KNN classifier
        """
        
        self.x = x
        self.l = l
        
    def _dtw_distance(self, ts_a, ts_b, d = lambda x,y: abs(x-y)):
        """Returns the DTW similarity distance between two 2-D
        timeseries numpy arrays.

        Arguments
        ---------
        ts_a, ts_b : array of shape [n_samples, n_timepoints]
            Two arrays containing n_samples of timeseries data
            whose DTW distance between each sample of A and B
            will be compared
        
        d : DistanceMetric object (default = abs(x-y))
            the distance measure used for A_i - B_j in the
            DTW dynamic programming function
        
        Returns
        -------
        DTW distance between A and B
        """

        # Create cost matrix via broadcasting with large int
        ts_a, ts_b = np.array(ts_a), np.array(ts_b)
        M, N = len(ts_a), len(ts_b)
        cost = sys.maxsize * np.ones((M, N))

        # Initialize the first row and column
        cost[0, 0] = d(ts_a[0], ts_b[0])
        for i in range(1, M):
            cost[i, 0] = cost[i-1, 0] + d(ts_a[i], ts_b[0])

        for j in range(1, N):
            cost[0, j] = cost[0, j-1] + d(ts_a[0], ts_b[j])

        # Populate rest of cost matrix within window
        for i in range(1, M):
            for j in range(max(1, i - self.max_warping_window),
                            min(N, i + self.max_warping_window)):
                choices = cost[i - 1, j - 1], cost[i, j-1], cost[i-1, j]
                cost[i, j] = min(choices) + d(ts_a[i], ts_b[j])

        # Return DTW distance given window 
        return cost[-1, -1]
    
    def _dist_matrix(self, x, y):
        """Computes the M x N distance matrix between the training
        dataset and testing dataset (y) using the DTW distance measure
        
        Arguments
        ---------
        x : array of shape [n_samples, n_timepoints]
        
        y : array of shape [n_samples, n_timepoints]
        
        Returns
        -------
        Distance matrix between each item of x and y with
            shape [training_n_samples, testing_n_samples]
        """
        
        # Compute the distance matrix        
        dm_count = 0
        
        # Compute condensed distance matrix (upper triangle) of pairwise dtw distances
        # when x and y are the same array
        if(np.array_equal(x, y)):
            x_s = np.shape(x)
            dm = np.zeros((x_s[0] * (x_s[0] - 1)) // 2, dtype=np.double)
            
            p = ProgressBar(shape(dm)[0])
            
            for i in range(0, x_s[0] - 1):
                for j in range(i + 1, x_s[0]):
                    dm[dm_count] = self._dtw_distance(x[i, ::self.subsample_step],
                                                      y[j, ::self.subsample_step])
                    
                    dm_count += 1
                    p.animate(dm_count)
            
            # Convert to squareform
            dm = squareform(dm)
            return dm
        
        # Compute full distance matrix of dtw distnces between x and y
        else:
            x_s = np.shape(x)
            y_s = np.shape(y)
            dm = np.zeros((x_s[0], y_s[0])) 
            dm_size = x_s[0]*y_s[0]
            
            p = ProgressBar(dm_size)
        
            for i in range(0, x_s[0]):
                for j in range(0, y_s[0]):
                    dm[i, j] = self._dtw_distance(x[i, ::self.subsample_step],
                                                  y[j, ::self.subsample_step])
                    # Update progress bar
                    dm_count += 1
                    p.animate(dm_count)
        
            return dm
        
    def predict(self, x):
        """Predict the class labels or probability estimates for 
        the provided data

        Arguments
        ---------
          x : array of shape [n_samples, n_timepoints]
              Array containing the testing data set to be classified
          
        Returns
        -------
          2 arrays representing:
              (1) the predicted class labels 
              (2) the knn label count probability
        """
        
        dm = self._dist_matrix(x, self.x)

        # Identify the k nearest neighbors
        knn_idx = dm.argsort()[:, :self.n_neighbors]

        # Identify k nearest labels
        knn_labels = self.l[knn_idx]
        
        # Model Label
        mode_data = mode(knn_labels, axis=1)
        mode_label = mode_data[0]
        mode_proba = mode_data[1]/self.n_neighbors

        return mode_label.ravel(), mode_proba.ravel()

class ProgressBar:
    """This progress bar was taken from PYMC
    """
    def __init__(self, iterations):
        self.iterations = iterations
        self.prog_bar = '[]'
        self.fill_char = '*'
        self.width = 40
        self.__update_amount(0)
        if have_ipython:
            self.animate = self.animate_ipython
        else:
            self.animate = self.animate_noipython

    def animate_ipython(self, iter):
        sys.stdout.flush()
        self.update_iteration(iter + 1)

    def update_iteration(self, elapsed_iter):
        self.__update_amount((elapsed_iter / float(self.iterations)) * 100.0)
        self.prog_bar += '  %d of %s complete' % (elapsed_iter, self.iterations)

    def __update_amount(self, new_amount):
        percent_done = int(round((new_amount / 100.0) * 100.0))
        all_full = self.width - 2
        num_hashes = int(round((percent_done / 100.0) * all_full))
        self.prog_bar = '[' + self.fill_char * num_hashes + ' ' * (all_full - num_hashes) + ']'
        pct_place = (len(self.prog_bar) // 2) - len(str(percent_done))
        pct_string = '%d%%' % percent_done
        self.prog_bar = self.prog_bar[0:pct_place] + \
            (pct_string + self.prog_bar[pct_place + len(pct_string):])

    def __str__(self):
        return str(self.prog_bar)

# %% [markdown]
# #### Measuring the DTW distance
# The DTW distance between two sequences can be calculated using the `_dtw_distance()` method

# %%
time = np.linspace(0,20,1000)
amplitude_a = 5*np.sin(time)
amplitude_b = 3*np.sin(time + 1)

m = KnnDtw()
distance = m._dtw_distance(amplitude_a, amplitude_b)

fig = plt.figure(figsize=(12,4))
_ = plt.plot(time, amplitude_a, label='A')
_ = plt.plot(time, amplitude_b, label='B')
_ = plt.title('DTW distance between A and B is %.2f' % distance)
_ = plt.ylabel('Amplitude')
_ = plt.xlabel('Time')
_ = plt.legend()

# %%
distance
# Out:
# 812.6799819951367

# %% [markdown]
# It is also possible to compute the distance between each pair of two collections of inputs by using the `_dist_matrix()` method. These are the two methods which underpin the KnnDtw() classification algorithm. In the next section we will use the `fit()` and `predict()` method to train our classifier and predict class labels forunseen data.

# %%
m._dist_matrix(np.random.random((4,50)), np.random.random((4,50)))
# Out:
# array([[ 8.28495417,  9.80030131,  8.88314235,  8.4925165 ],
#        [ 9.4467886 , 10.27339229,  8.46101179,  8.99443378],
#        [ 9.20281059,  9.12976082,  7.14490429,  8.40674626],
#        [ 9.02798099,  9.97754361, 10.26107717, 10.38259377]])

# %% [markdown]
# ## Human Activity Recognition Dataset
# The Human Activity Recognition Dataset (HAR) dataset is chosen to test the classification performance of DTW & KNN [3].

# %%
Image('images/stand-sit-run.jpg')

# %% [markdown]
# > The experiments were carried out with a group of 30 volunteers within an age bracket of 19-48 years. Each person performed six activities (walking, walking upstairs, walking downstairs, sitting, standing and laying) wearing a smartphone (Samsung Galaxy S II) on the waist. Using its embedded accelerometer and gyroscope, we captured 3-axial linear acceleration and 3-axial angular velocity at a constant rate of 50Hz. The experiments have been video-recorded to label the data manually.
#
# The remainder of this analysis uses a training and test dataset provided by the authors. They have combined the above timeseries signals and created a single timeseries feature vector. Unfortunately, their methodology is not described.
#
# ####Import the HAR dataset

# %%
import numpy as np
# Import the HAR dataset
x_train_file = open('data/UCI-HAR-Dataset/train/X_train.txt', 'r')
y_train_file = open('data/UCI-HAR-Dataset/train/y_train.txt', 'r')

x_test_file = open('data/UCI-HAR-Dataset/test/X_test.txt', 'r')
y_test_file = open('data/UCI-HAR-Dataset/test/y_test.txt', 'r')

# Create empty lists
x_train = []
y_train = []
x_test = []
y_test = []

# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

# Loop through datasets
for x in x_train_file:
    x_train.append([float(ts) for ts in x.split()])
    
for y in y_train_file:
    y_train.append(int(y.rstrip('\n')))
    
for x in x_test_file:
    x_test.append([float(ts) for ts in x.split()])
    
for y in y_test_file:
    y_test.append(int(y.rstrip('\n')))
    
# Convert to numpy for efficiency
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# #### Visualizing sample observations from the HAR dataset

# %%
plt.figure(figsize=(11,7))
colors = ['#D62728','#2C9F2C','#FD7F23','#1F77B4','#9467BD',
          '#8C564A','#7F7F7F','#1FBECF','#E377C2','#BCBD27']

for i, r in enumerate([0,27,65,100,145,172]):
    plt.subplot(3,2,i+1)
    plt.plot(x_train[r][:100], label=labels[y_train[r]], color=colors[i], linewidth=2)
    plt.xlabel('Samples @50Hz')
    plt.legend(loc='upper left')
    plt.tight_layout()

# %% [markdown]
# #### Model Performance
# The performance of the KNN & DTW classifier is measured by comparing the class labels from the holdout dataset against predictions made by the classifier. The HAR dataset was pre-split into 70% training and 30% test. Cross validation was not performed.

# %%
m = KnnDtw(n_neighbors=1, max_warping_window=10)
m.fit(x_train[::10], y_train[::10])
label, proba = m.predict(x_test[::10])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28233/2790924532.py in <module>
#       1 m = KnnDtw(n_neighbors=1, max_warping_window=10)
#       2 m.fit(x_train[::10], y_train[::10])
# ----> 3 label, proba = m.predict(x_test[::10])
#
# /tmp/ipykernel_28233/2650884385.py in predict(self, x)
#     172         """
#     173
# --> 174         dm = self._dist_matrix(x, self.x)
#     175
#     176         # Identify the k nearest neighbors
#
# /tmp/ipykernel_28233/2650884385.py in _dist_matrix(self, x, y)
#     152                     # Update progress bar
#     153                     dm_count += 1
# --> 154                     p.animate(dm_count)
#     155
#     156             return dm
#
# /tmp/ipykernel_28233/2650884385.py in animate_ipython(self, iter)
#     202
#     203     def animate_ipython(self, iter):
# --> 204         sys.stdout.flush()
#     205         self.update_iteration(iter + 1)
#     206
#
# ~/.local/lib/python3.8/site-packages/ipykernel/iostream.py in flush(self)
#     456         if self.pub_thread and self.pub_thread.thread is not None and self.pub_thread.thread.is_alive():
#     457             # request flush on the background thread
# --> 458             self.pub_thread.schedule(self._flush)
#     459             # wait for flush to actually get through, if we can.
#     460             # waiting across threads during import can cause deadlocks
#
# ~/.local/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~/.local/lib/python3.8/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     545                 )
#     546             data.group = group
# --> 547         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     548
#     549     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/.local/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(label, y_test[::10],
                            target_names=[l for l in labels.values()]))

conf_mat = confusion_matrix(label, y_test[::10])

fig = plt.figure(figsize=(6,6))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')
for i, row in enumerate(conf_mat):
    for j, c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)
            
cb = fig.colorbar(res)
plt.title('Confusion Matrix')
_ = plt.xticks(range(6), [l for l in labels.values()], rotation=90)
_ = plt.yticks(range(6), [l for l in labels.values()])
# Out:
#                     precision    recall  f1-score   support
#
#            WALKING       0.96      0.80      0.87        60
#   WALKING UPSTAIRS       0.85      0.80      0.83        51
# WALKING DOWNSTAIRS       0.68      0.97      0.80        31
#            SITTING       0.78      0.78      0.78        51
#           STANDING       0.84      0.76      0.80        55
#             LAYING       0.90      1.00      0.95        47
#
#        avg / total       0.85      0.84      0.84       295

# %% [markdown]
# The KNN & DTW classifier performed very well across each of the 6 classes. It even beats the best classification rate published by the authors of the HAR paper.
#
# However, this performance comes at a cost. The KNN algorithm is implemented using brute force. So, comparing 500 training observations to 500 test observations results in 250,000 DTW distances to be computed. And each (unconstrained) DTW distance calculation takes over 65K calculations each (256 x 256). This results in 16.3 billion calculations for just 500 x 500 observations.. Clearly not a scalable classification technique!
#
# Performance improvements can be achieved by reducing the `max_warping_window` parameter. However, these gains will not be sufficient to make KNN & DTW a viable classification technique for large or medium sized datasets.

# %%
import time

time_taken = []
windows = [1,2,5,10,50,100,500,1000,5000]

for w in windows:
    begin = time.time()
    
    t = KnnDtw(n_neighbors=1, max_warping_window=w)
    t.fit(x_train[:20], y_train[:20])
    label, proba = t.predict(x_test[:20])
    
    end = time.time()
    time_taken.append(end - begin)

fig = plt.figure(figsize=(12,5))
_ = plt.plot(windows, [t/400. for t in time_taken], lw=4)
plt.title('DTW Execution Time with \nvarying Max Warping Window')
plt.ylabel('Execution Time (seconds)')
plt.xlabel('Max Warping Window')
plt.xscale('log')
# Out:
# [****************100%******************]  400 of 400 complete

# %% [markdown]
# ---
#
# #### Final thoughts
# There are many improvements that could be made to this python implementation of KNN & DTW (eg. rewrite in C++ or explore parallel processing). However, the objective of this project was learning related. I've gained a deeper insight into the underlying mechanics of DTW by implementing it in python using dynamic programming techniques.
#
# #### References
# 1.  Mitsa (2010). Temporal Data Mining (Chapter on Temporal Classification).
# 2.  Xi (2006). Fast Time Series Classification Using Numerosity Reduction.
# 3.  Davide Anguita, Alessandro Ghio, Luca Oneto, Xavier Parra and Jorge L. Reyes-Ortiz. Human Activity Recognition on Smartphones using a Multiclass Hardware-Friendly Support Vector Machine. International Workshop of Ambient Assisted Living (IWAAL 2012). Vitoria-Gasteiz, Spain. Dec 2012. [Read Paper](http://arxiv.org/pdf/1401.8212.pdf)
#
# #### Credit
# -  The progressbar used in the `DtwKnn()` class was taken from PYMC
# -  The matplotlib style and IPython notebook was taken from Cameron Davidson-Pilon's excelent ["Bayesian Methods for Hackers"](https://github.com/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers)

# %%
from IPython.core.display import HTML

def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunss.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsx.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunsi.otf');
#     }
#     @font-face {
#         font-family: "Computer Modern";
#         font-weight: bold;
#         font-style: oblique;
#         src: url('http://9dbb143991406a7c655e-aa5fcb0a5a4ec34cff238a2d56ca4144.r56.cf5.rackcdn.com/cmunso.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: Helvetica, serif;
#     }
#     h4{
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 130%;
#         width:800px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro", source-code-pro,Consolas, monospace;
#     }
#     .prompt{
#         display: None;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 22pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")


import numpy as np
# Import the HAR dataset
x_train_file = open('data/UCI-HAR-Dataset/train/X_train.txt', 'r')
y_train_file = open('data/UCI-HAR-Dataset/train/y_train.txt', 'r')

x_test_file = open('data/UCI-HAR-Dataset/test/X_test.txt', 'r')
y_test_file = open('data/UCI-HAR-Dataset/test/y_test.txt', 'r')

# Create empty lists
x_train = []
y_train = []
x_test = []
y_test = []

# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

# Loop through datasets
for x in x_train_file:
    x_train.append([float(ts) for ts in x.split()])
    
for y in y_train_file:
    y_train.append(int(y.rstrip('\n')))
    
for x in x_test_file:
    x_test.append([float(ts) for ts in x.split()])
    
for y in y_test_file:
    y_test.append(int(y.rstrip('\n')))
    
# Convert to numpy for efficiency
x_train = np.array(x_train[::10])
y_train = np.array(y_train[::10])
x_test = np.array(x_test[::10])
y_test = np.array(y_test[::10])

# %%
from scipy.spatial.distance import euclidean
from fastdtw import fastdtw
from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier(n_neighbors=3, metric = lambda x,y : fastdtw(x, y, dist=euclidean)[0], n_jobs=3)
neigh.fit(x_train, y_train)

y_pred = neigh.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28233/135370646.py in <module>
#       3 neigh.fit(x_train, y_train)
#       4
# ----> 5 y_pred = neigh.predict(x_test)
#
# ~/.local/lib/python3.8/site-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     212             Class labels for each data sample.
#     213         """
# --> 214         neigh_dist, neigh_ind = self.kneighbors(X)
#     215         classes_ = self.classes_
#     216         _y = self._y
#
# ~/.local/lib/python3.8/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     750                 kwds = self.effective_metric_params_
#     751
# --> 752             chunked_results = list(
#     753                 pairwise_distances_chunked(
#     754                     X,
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1715         else:
#    1716             X_chunk = X[sl]
# -> 1717         D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1718         if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1719             metric, None
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1887         func = partial(distance.cdist, metric=metric, **kwds)
#    1888
# -> 1889     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1890
#    1891
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1433     fd = delayed(_dist_wrapper)
#    1434     ret = np.empty((X.shape[0], Y.shape[0]), dtype=dtype, order="F")
# -> 1435     Parallel(backend="threading", n_jobs=n_jobs)(
#    1436         fd(func, ret, s, X, Y[s], **kwds)
#    1437         for s in gen_even_slices(_num_samples(Y), effective_n_jobs(n_jobs))
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1054
#    1055             with self._backend.retrieval_context():
# -> 1056                 self.retrieve()
#    1057             # Make sure that we get a last message telling us we are done
#    1058             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     933             try:
#     934                 if getattr(self._backend, 'supports_timeout', False):
# --> 935                     self._output.extend(job.get(timeout=self.timeout))
#     936                 else:
#     937                     self._output.extend(job.get())
#
# /usr/lib/python3.8/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# /usr/lib/python3.8/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# /usr/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
from sktime.transformations.panel import tsfresh as tsf 

extractor = tsf.TSFreshFeatureExtractor()

x_train_f = extractor.fit_transform(x_train)
x_test_f = extractor.transform(x_test)
# Out:
# Feature Extraction:   0%|                                                   | 0/736 [00:00<?, ?it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   0%|                                           | 1/736 [00:00<07:44,  1.58it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   0%|                                           | 2/736 [00:01<05:52,  2.08it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   0%|▏                                          | 3/736 [00:01<08:10,  1.49it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▏                                          | 4/736 [00:02<08:33,  1.43it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▎                                          | 5/736 [00:03<08:11,  1.49it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▎                                          | 6/736 [00:03<08:05,  1.50it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▍                                          | 7/736 [00:04<09:10,  1.32it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▍                                          | 8/736 [00:05<08:50,  1.37it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▌                                          | 9/736 [00:05<07:15,  1.67it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▌                                         | 10/736 [00:06<07:51,  1.54it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   1%|▋                                         | 11/736 [00:07<07:44,  1.56it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   2%|▋                                         | 12/736 [00:08<08:39,  1.39it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   2%|▋                                         | 13/736 [00:08<08:14,  1.46it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   2%|▊                                         | 14/736 [00:09<07:21,  1.63it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   2%|▊                                         | 15/736 [00:10<09:02,  1.33it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   2%|▉                                         | 16/736 [00:10<07:49,  1.53it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   2%|▉                                         | 17/736 [00:11<07:54,  1.52it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   2%|█                                         | 18/736 [00:12<07:52,  1.52it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   3%|█                                         | 19/736 [00:12<07:23,  1.62it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   3%|█▏                                        | 20/736 [00:12<06:50,  1.75it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   3%|█▏                                        | 21/736 [00:13<06:29,  1.84it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   3%|█▎                                        | 22/736 [00:13<06:11,  1.92it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   3%|█▎                                        | 23/736 [00:14<05:42,  2.08it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   3%|█▎                                        | 24/736 [00:15<07:18,  1.62it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   3%|█▍                                        | 25/736 [00:16<08:39,  1.37it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▍                                        | 26/736 [00:17<10:12,  1.16it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▌                                        | 27/736 [00:18<10:00,  1.18it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▌                                        | 28/736 [00:19<11:41,  1.01it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▋                                        | 29/736 [00:20<11:05,  1.06it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▋                                        | 30/736 [00:20<09:29,  1.24it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▊                                        | 31/736 [00:21<08:08,  1.44it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▊                                        | 32/736 [00:21<07:23,  1.59it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   4%|█▉                                        | 33/736 [00:22<07:57,  1.47it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   5%|█▉                                        | 34/736 [00:23<07:45,  1.51it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   5%|█▉                                        | 35/736 [00:23<07:25,  1.57it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   5%|██                                        | 36/736 [00:24<07:14,  1.61it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   5%|██                                        | 37/736 [00:24<06:47,  1.72it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   5%|██▏                                       | 38/736 [00:25<06:24,  1.81it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   5%|██▏                                       | 39/736 [00:25<06:13,  1.87it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   5%|██▎                                       | 40/736 [00:26<05:58,  1.94it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   6%|██▎                                       | 41/736 [00:27<06:45,  1.71it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   6%|██▍                                       | 42/736 [00:27<07:14,  1.60it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   6%|██▍                                       | 43/736 [00:28<07:30,  1.54it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   6%|██▌                                       | 44/736 [00:29<07:23,  1.56it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   6%|██▌                                       | 45/736 [00:29<07:16,  1.58it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   6%|██▋                                       | 46/736 [00:30<07:50,  1.47it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   6%|██▋                                       | 47/736 [00:30<06:53,  1.67it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|██▋                                       | 48/736 [00:31<07:10,  1.60it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|██▊                                       | 49/736 [00:32<07:25,  1.54it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|██▊                                       | 50/736 [00:32<07:19,  1.56it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|██▉                                       | 51/736 [00:33<07:41,  1.48it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|██▉                                       | 52/736 [00:34<07:03,  1.61it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|███                                       | 53/736 [00:34<06:34,  1.73it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|███                                       | 54/736 [00:35<06:05,  1.87it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   7%|███▏                                      | 55/736 [00:35<06:20,  1.79it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   8%|███▏                                      | 56/736 [00:36<06:15,  1.81it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   8%|███▎                                      | 57/736 [00:37<06:58,  1.62it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   8%|███▎                                      | 58/736 [00:37<07:44,  1.46it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   8%|███▎                                      | 59/736 [00:38<08:09,  1.38it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   8%|███▍                                      | 60/736 [00:39<08:11,  1.37it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   8%|███▍                                      | 61/736 [00:39<07:38,  1.47it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   8%|███▌                                      | 62/736 [00:40<08:27,  1.33it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   9%|███▌                                      | 63/736 [00:41<09:03,  1.24it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   9%|███▋                                      | 64/736 [00:42<09:25,  1.19it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   9%|███▋                                      | 65/736 [00:43<09:05,  1.23it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   9%|███▊                                      | 66/736 [00:45<12:59,  1.16s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   9%|███▊                                      | 67/736 [00:46<12:37,  1.13s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   9%|███▉                                      | 68/736 [00:47<13:23,  1.20s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:   9%|███▉                                      | 69/736 [00:48<11:18,  1.02s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|███▉                                      | 70/736 [00:48<09:12,  1.20it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|████                                      | 71/736 [00:49<08:01,  1.38it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|████                                      | 72/736 [00:49<07:30,  1.47it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|████▏                                     | 73/736 [00:50<06:51,  1.61it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|████▏                                     | 74/736 [00:50<06:20,  1.74it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|████▎                                     | 75/736 [00:51<05:46,  1.91it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|████▎                                     | 76/736 [00:51<05:54,  1.86it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  10%|████▍                                     | 77/736 [00:52<05:56,  1.85it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  11%|████▍                                     | 78/736 [00:52<05:37,  1.95it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  11%|████▌                                     | 79/736 [00:53<05:40,  1.93it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  11%|████▌                                     | 80/736 [00:53<05:26,  2.01it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  11%|████▌                                     | 81/736 [00:54<05:04,  2.15it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  11%|████▋                                     | 82/736 [00:55<06:22,  1.71it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  11%|████▋                                     | 83/736 [00:55<06:20,  1.72it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  11%|████▊                                     | 84/736 [00:56<06:17,  1.73it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|████▊                                     | 85/736 [00:56<06:01,  1.80it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|████▉                                     | 86/736 [00:57<05:39,  1.91it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|████▉                                     | 87/736 [00:57<05:27,  1.98it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|█████                                     | 88/736 [00:58<05:33,  1.94it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|█████                                     | 89/736 [00:58<05:18,  2.03it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|█████▏                                    | 90/736 [00:59<04:59,  2.16it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|█████▏                                    | 91/736 [00:59<04:57,  2.17it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  12%|█████▎                                    | 92/736 [00:59<04:56,  2.17it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  13%|█████▎                                    | 93/736 [01:00<04:55,  2.18it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  13%|█████▎                                    | 94/736 [01:00<04:42,  2.27it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  13%|█████▍                                    | 95/736 [01:01<04:37,  2.31it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  13%|█████▍                                    | 96/736 [01:01<04:38,  2.30it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  13%|█████▌                                    | 97/736 [01:02<05:13,  2.04it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  13%|█████▌                                    | 98/736 [01:02<05:15,  2.02it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  13%|█████▋                                    | 99/736 [01:03<05:25,  1.96it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  14%|█████▌                                   | 100/736 [01:03<05:17,  2.00it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  14%|█████▋                                   | 101/736 [01:04<05:12,  2.03it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  14%|█████▋                                   | 102/736 [01:04<04:59,  2.12it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  14%|█████▋                                   | 103/736 [01:05<05:28,  1.93it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  14%|█████▊                                   | 104/736 [01:06<06:09,  1.71it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  14%|█████▊                                   | 105/736 [01:06<07:06,  1.48it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  14%|█████▉                                   | 106/736 [01:08<08:34,  1.22it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|█████▉                                   | 107/736 [01:08<08:39,  1.21it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|██████                                   | 108/736 [01:10<10:47,  1.03s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|██████                                   | 109/736 [01:11<10:32,  1.01s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|██████▏                                  | 110/736 [01:12<09:41,  1.08it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|██████▏                                  | 111/736 [01:12<08:22,  1.24it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|██████▏                                  | 112/736 [01:13<07:45,  1.34it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|██████▎                                  | 113/736 [01:13<06:43,  1.54it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  15%|██████▎                                  | 114/736 [01:14<06:03,  1.71it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  16%|██████▍                                  | 115/736 [01:14<05:44,  1.80it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  16%|██████▍                                  | 116/736 [01:15<05:19,  1.94it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  16%|██████▌                                  | 117/736 [01:15<05:13,  1.97it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  16%|██████▌                                  | 118/736 [01:15<04:53,  2.11it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  16%|██████▋                                  | 119/736 [01:16<04:40,  2.20it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  16%|██████▋                                  | 120/736 [01:16<04:27,  2.30it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  16%|██████▋                                  | 121/736 [01:17<04:36,  2.22it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  17%|██████▊                                  | 122/736 [01:17<04:36,  2.22it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  17%|██████▊                                  | 123/736 [01:18<04:20,  2.35it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  17%|██████▉                                  | 124/736 [01:18<04:47,  2.13it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  17%|██████▉                                  | 125/736 [01:19<04:53,  2.08it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  17%|███████                                  | 126/736 [01:19<05:27,  1.87it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  17%|███████                                  | 127/736 [01:20<05:07,  1.98it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# ...
#   warnings.warn(
# Feature Extraction:  86%|███████████████████████████████████▎     | 254/295 [02:24<00:21,  1.94it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  86%|███████████████████████████████████▍     | 255/295 [02:24<00:20,  1.99it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  87%|███████████████████████████████████▌     | 256/295 [02:25<00:18,  2.06it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  87%|███████████████████████████████████▋     | 257/295 [02:25<00:17,  2.13it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  87%|███████████████████████████████████▊     | 258/295 [02:26<00:18,  2.05it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  88%|███████████████████████████████████▉     | 259/295 [02:27<00:26,  1.36it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  88%|████████████████████████████████████▏    | 260/295 [02:28<00:28,  1.21it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  88%|████████████████████████████████████▎    | 261/295 [02:29<00:33,  1.01it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  89%|████████████████████████████████████▍    | 262/295 [02:31<00:35,  1.08s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  89%|████████████████████████████████████▌    | 263/295 [02:32<00:39,  1.23s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  89%|████████████████████████████████████▋    | 264/295 [02:34<00:43,  1.40s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  90%|████████████████████████████████████▊    | 265/295 [02:36<00:47,  1.60s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  90%|████████████████████████████████████▉    | 266/295 [02:37<00:40,  1.39s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  91%|█████████████████████████████████████    | 267/295 [02:38<00:34,  1.21s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  91%|█████████████████████████████████████▏   | 268/295 [02:39<00:28,  1.05s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  91%|█████████████████████████████████████▍   | 269/295 [02:39<00:24,  1.06it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  92%|█████████████████████████████████████▌   | 270/295 [02:40<00:20,  1.20it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  92%|█████████████████████████████████████▋   | 271/295 [02:40<00:18,  1.32it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  92%|█████████████████████████████████████▊   | 272/295 [02:41<00:16,  1.41it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  93%|█████████████████████████████████████▉   | 273/295 [02:42<00:18,  1.20it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  93%|██████████████████████████████████████   | 274/295 [02:43<00:18,  1.14it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  93%|██████████████████████████████████████▏  | 275/295 [02:44<00:18,  1.07it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  94%|██████████████████████████████████████▎  | 276/295 [02:45<00:19,  1.03s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  94%|██████████████████████████████████████▍  | 277/295 [02:47<00:21,  1.22s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  94%|██████████████████████████████████████▋  | 278/295 [02:49<00:22,  1.30s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  95%|██████████████████████████████████████▊  | 279/295 [02:50<00:19,  1.22s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  95%|██████████████████████████████████████▉  | 280/295 [02:51<00:17,  1.14s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  95%|███████████████████████████████████████  | 281/295 [02:51<00:14,  1.06s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  96%|███████████████████████████████████████▏ | 282/295 [02:52<00:11,  1.14it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  96%|███████████████████████████████████████▎ | 283/295 [02:53<00:10,  1.10it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  96%|███████████████████████████████████████▍ | 284/295 [02:54<00:10,  1.05it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  97%|███████████████████████████████████████▌ | 285/295 [02:55<00:10,  1.02s/it]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  97%|███████████████████████████████████████▋ | 286/295 [02:56<00:07,  1.17it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  97%|███████████████████████████████████████▉ | 287/295 [02:56<00:06,  1.26it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  98%|████████████████████████████████████████ | 288/295 [02:57<00:05,  1.19it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  98%|████████████████████████████████████████▏| 289/295 [02:58<00:04,  1.34it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  98%|████████████████████████████████████████▎| 290/295 [02:58<00:03,  1.48it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  99%|████████████████████████████████████████▍| 291/295 [02:59<00:02,  1.52it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  99%|████████████████████████████████████████▌| 292/295 [02:59<00:01,  1.72it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction:  99%|████████████████████████████████████████▋| 293/295 [03:00<00:01,  1.81it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction: 100%|████████████████████████████████████████▊| 294/295 [03:00<00:00,  1.94it/s]/home/the_sun/.local/lib/python3.8/site-packages/tsfresh/feature_extraction/extraction.py:354: UserWarning: linear_trend_timewise requires the data to have a index of type <class 'pandas.core.indexes.datetimes.DatetimeIndex'>. Results will not be calculated
#   warnings.warn(
# Feature Extraction: 100%|█████████████████████████████████████████| 295/295 [03:01<00:00,  1.63it/s]
# /home/the_sun/.local/lib/python3.8/site-packages/tsfresh/utilities/dataframe_functions.py:198: RuntimeWarning: The columns ['var_0__query_similarity_count__query_None__threshold_0.0'] did not have any finite values. Filling with zeros.
#   warnings.warn(

# %%
x_train_f.columns.values
# Out:
# array(['var_0__variance_larger_than_standard_deviation',
#        'var_0__has_duplicate_max', 'var_0__has_duplicate_min',
#        'var_0__has_duplicate', 'var_0__sum_values', 'var_0__abs_energy',
#        'var_0__mean_abs_change', 'var_0__mean_change',
#        'var_0__mean_second_derivative_central', 'var_0__median',
#        'var_0__mean', 'var_0__length', 'var_0__standard_deviation',
#        'var_0__variation_coefficient', 'var_0__variance',
#        'var_0__skewness', 'var_0__kurtosis', 'var_0__root_mean_square',
#        'var_0__absolute_sum_of_changes',
#        'var_0__longest_strike_below_mean',
#        'var_0__longest_strike_above_mean', 'var_0__count_above_mean',
#        'var_0__count_below_mean', 'var_0__last_location_of_maximum',
#        'var_0__first_location_of_maximum',
#        'var_0__last_location_of_minimum',
#        'var_0__first_location_of_minimum',
#        'var_0__percentage_of_reoccurring_values_to_all_values',
#        'var_0__percentage_of_reoccurring_datapoints_to_all_datapoints',
#        'var_0__sum_of_reoccurring_values',
#        'var_0__sum_of_reoccurring_data_points',
#        'var_0__ratio_value_number_to_time_series_length',
#        'var_0__maximum', 'var_0__absolute_maximum', 'var_0__minimum',
#        'var_0__benford_correlation',
#        'var_0__time_reversal_asymmetry_statistic__lag_1',
#        'var_0__time_reversal_asymmetry_statistic__lag_2',
#        'var_0__time_reversal_asymmetry_statistic__lag_3',
#        'var_0__c3__lag_1', 'var_0__c3__lag_2', 'var_0__c3__lag_3',
#        'var_0__cid_ce__normalize_True', 'var_0__cid_ce__normalize_False',
#        'var_0__symmetry_looking__r_0.0',
#        'var_0__symmetry_looking__r_0.05',
#        'var_0__symmetry_looking__r_0.1',
#        'var_0__symmetry_looking__r_0.15000000000000002',
#        'var_0__symmetry_looking__r_0.2',
#        'var_0__symmetry_looking__r_0.25',
#        'var_0__symmetry_looking__r_0.30000000000000004',
#        'var_0__symmetry_looking__r_0.35000000000000003',
#        'var_0__symmetry_looking__r_0.4',
#        'var_0__symmetry_looking__r_0.45',
#        'var_0__symmetry_looking__r_0.5',
#        'var_0__symmetry_looking__r_0.55',
#        'var_0__symmetry_looking__r_0.6000000000000001',
#        'var_0__symmetry_looking__r_0.65',
#        'var_0__symmetry_looking__r_0.7000000000000001',
#        'var_0__symmetry_looking__r_0.75',
#        'var_0__symmetry_looking__r_0.8',
#        'var_0__symmetry_looking__r_0.8500000000000001',
#        'var_0__symmetry_looking__r_0.9',
#        'var_0__symmetry_looking__r_0.9500000000000001',
#        'var_0__large_standard_deviation__r_0.05',
#        'var_0__large_standard_deviation__r_0.1',
#        'var_0__large_standard_deviation__r_0.15000000000000002',
#        'var_0__large_standard_deviation__r_0.2',
#        'var_0__large_standard_deviation__r_0.25',
#        'var_0__large_standard_deviation__r_0.30000000000000004',
#        'var_0__large_standard_deviation__r_0.35000000000000003',
#        'var_0__large_standard_deviation__r_0.4',
#        'var_0__large_standard_deviation__r_0.45',
#        'var_0__large_standard_deviation__r_0.5',
#        'var_0__large_standard_deviation__r_0.55',
#        'var_0__large_standard_deviation__r_0.6000000000000001',
#        'var_0__large_standard_deviation__r_0.65',
#        'var_0__large_standard_deviation__r_0.7000000000000001',
#        'var_0__large_standard_deviation__r_0.75',
#        'var_0__large_standard_deviation__r_0.8',
#        'var_0__large_standard_deviation__r_0.8500000000000001',
#        'var_0__large_standard_deviation__r_0.9',
#        'var_0__large_standard_deviation__r_0.9500000000000001',
#        'var_0__quantile__q_0.1', 'var_0__quantile__q_0.2',
#        'var_0__quantile__q_0.3', 'var_0__quantile__q_0.4',
#        'var_0__quantile__q_0.6', 'var_0__quantile__q_0.7',
#        'var_0__quantile__q_0.8', 'var_0__quantile__q_0.9',
#        'var_0__autocorrelation__lag_0', 'var_0__autocorrelation__lag_1',
#        'var_0__autocorrelation__lag_2', 'var_0__autocorrelation__lag_3',
#        'var_0__autocorrelation__lag_4', 'var_0__autocorrelation__lag_5',
#        'var_0__autocorrelation__lag_6', 'var_0__autocorrelation__lag_7',
#        'var_0__autocorrelation__lag_8', 'var_0__autocorrelation__lag_9',
#        'var_0__agg_autocorrelation__f_agg_"mean"__maxlag_40',
#        'var_0__agg_autocorrelation__f_agg_"median"__maxlag_40',
#        'var_0__agg_autocorrelation__f_agg_"var"__maxlag_40',
#        'var_0__partial_autocorrelation__lag_0',
#        'var_0__partial_autocorrelation__lag_1',
#        'var_0__partial_autocorrelation__lag_2',
#        'var_0__partial_autocorrelation__lag_3',
#        'var_0__partial_autocorrelation__lag_4',
#        'var_0__partial_autocorrelation__lag_5',
#        'var_0__partial_autocorrelation__lag_6',
#        'var_0__partial_autocorrelation__lag_7',
#        'var_0__partial_autocorrelation__lag_8',
#        'var_0__partial_autocorrelation__lag_9',
#        'var_0__number_cwt_peaks__n_1', 'var_0__number_cwt_peaks__n_5',
#        'var_0__number_peaks__n_1', 'var_0__number_peaks__n_3',
#        'var_0__number_peaks__n_5', 'var_0__number_peaks__n_10',
#        'var_0__number_peaks__n_50', 'var_0__binned_entropy__max_bins_10',
#        'var_0__index_mass_quantile__q_0.1',
#        'var_0__index_mass_quantile__q_0.2',
#        'var_0__index_mass_quantile__q_0.3',
#        'var_0__index_mass_quantile__q_0.4',
#        'var_0__index_mass_quantile__q_0.6',
#        'var_0__index_mass_quantile__q_0.7',
#        'var_0__index_mass_quantile__q_0.8',
#        'var_0__index_mass_quantile__q_0.9',
#        'var_0__cwt_coefficients__coeff_0__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_0__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_1__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_2__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_2__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_2__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_2__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_3__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_3__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_3__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_3__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_4__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_4__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_4__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_4__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_5__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_5__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_5__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_6__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_6__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_6__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_6__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_7__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_7__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_7__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_7__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_8__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_8__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_8__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_9__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_9__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_9__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_9__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_10__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_10__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_10__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_10__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_11__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_11__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_11__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_11__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_12__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_12__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_12__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_12__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_13__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_13__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_13__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_13__w_20__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_14__w_2__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_14__w_5__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_14__w_10__widths_(2, 5, 10, 20)',
#        'var_0__cwt_coefficients__coeff_14__w_20__widths_(2, 5, 10, 20)',
#        'var_0__spkt_welch_density__coeff_2',
#        'var_0__spkt_welch_density__coeff_5',
#        'var_0__spkt_welch_density__coeff_8',
#        'var_0__ar_coefficient__coeff_0__k_10',
#        'var_0__ar_coefficient__coeff_1__k_10',
#        'var_0__ar_coefficient__coeff_2__k_10',
#        'var_0__ar_coefficient__coeff_3__k_10',
#        'var_0__ar_coefficient__coeff_4__k_10',
#        'var_0__ar_coefficient__coeff_5__k_10',
#        'var_0__ar_coefficient__coeff_6__k_10',
#        'var_0__ar_coefficient__coeff_7__k_10',
#        'var_0__ar_coefficient__coeff_8__k_10',
#        'var_0__ar_coefficient__coeff_9__k_10',
#        'var_0__ar_coefficient__coeff_10__k_10',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.4',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.6',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.6',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#        'var_0__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#        'var_0__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#        'var_0__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#        'var_0__fft_coefficient__attr_"real"__coeff_0',
#        'var_0__fft_coefficient__attr_"real"__coeff_1',
#        'var_0__fft_coefficient__attr_"real"__coeff_2',
#        'var_0__fft_coefficient__attr_"real"__coeff_3',
#        'var_0__fft_coefficient__attr_"real"__coeff_4',
#        'var_0__fft_coefficient__attr_"real"__coeff_5',
#        'var_0__fft_coefficient__attr_"real"__coeff_6',
#        'var_0__fft_coefficient__attr_"real"__coeff_7',
#        'var_0__fft_coefficient__attr_"real"__coeff_8',
#        'var_0__fft_coefficient__attr_"real"__coeff_9',
#        'var_0__fft_coefficient__attr_"real"__coeff_10',
#        'var_0__fft_coefficient__attr_"real"__coeff_11',
#        'var_0__fft_coefficient__attr_"real"__coeff_12',
#        'var_0__fft_coefficient__attr_"real"__coeff_13',
#        'var_0__fft_coefficient__attr_"real"__coeff_14',
#        'var_0__fft_coefficient__attr_"real"__coeff_15',
#        'var_0__fft_coefficient__attr_"real"__coeff_16',
#        'var_0__fft_coefficient__attr_"real"__coeff_17',
#        'var_0__fft_coefficient__attr_"real"__coeff_18',
#        'var_0__fft_coefficient__attr_"real"__coeff_19',
#        'var_0__fft_coefficient__attr_"real"__coeff_20',
#        'var_0__fft_coefficient__attr_"real"__coeff_21',
#        'var_0__fft_coefficient__attr_"real"__coeff_22',
#        'var_0__fft_coefficient__attr_"real"__coeff_23',
#        'var_0__fft_coefficient__attr_"real"__coeff_24',
#        'var_0__fft_coefficient__attr_"real"__coeff_25',
#        'var_0__fft_coefficient__attr_"real"__coeff_26',
#        'var_0__fft_coefficient__attr_"real"__coeff_27',
#        'var_0__fft_coefficient__attr_"real"__coeff_28',
#        'var_0__fft_coefficient__attr_"real"__coeff_29',
#        'var_0__fft_coefficient__attr_"real"__coeff_30',
#        'var_0__fft_coefficient__attr_"real"__coeff_31',
#        'var_0__fft_coefficient__attr_"real"__coeff_32',
#        'var_0__fft_coefficient__attr_"real"__coeff_33',
#        'var_0__fft_coefficient__attr_"real"__coeff_34',
#        'var_0__fft_coefficient__attr_"real"__coeff_35',
#        'var_0__fft_coefficient__attr_"real"__coeff_36',
#        'var_0__fft_coefficient__attr_"real"__coeff_37',
#        'var_0__fft_coefficient__attr_"real"__coeff_38',
#        'var_0__fft_coefficient__attr_"real"__coeff_39',
#        'var_0__fft_coefficient__attr_"real"__coeff_40',
#        'var_0__fft_coefficient__attr_"real"__coeff_41',
#        'var_0__fft_coefficient__attr_"real"__coeff_42',
#        'var_0__fft_coefficient__attr_"real"__coeff_43',
#        'var_0__fft_coefficient__attr_"real"__coeff_44',
#        'var_0__fft_coefficient__attr_"real"__coeff_45',
#        'var_0__fft_coefficient__attr_"real"__coeff_46',
#        'var_0__fft_coefficient__attr_"real"__coeff_47',
#        'var_0__fft_coefficient__attr_"real"__coeff_48',
#        'var_0__fft_coefficient__attr_"real"__coeff_49',
#        'var_0__fft_coefficient__attr_"real"__coeff_50',
#        'var_0__fft_coefficient__attr_"real"__coeff_51',
#        'var_0__fft_coefficient__attr_"real"__coeff_52',
#        'var_0__fft_coefficient__attr_"real"__coeff_53',
#        'var_0__fft_coefficient__attr_"real"__coeff_54',
#        'var_0__fft_coefficient__attr_"real"__coeff_55',
#        'var_0__fft_coefficient__attr_"real"__coeff_56',
#        'var_0__fft_coefficient__attr_"real"__coeff_57',
#        'var_0__fft_coefficient__attr_"real"__coeff_58',
#        'var_0__fft_coefficient__attr_"real"__coeff_59',
#        'var_0__fft_coefficient__attr_"real"__coeff_60',
#        'var_0__fft_coefficient__attr_"real"__coeff_61',
#        'var_0__fft_coefficient__attr_"real"__coeff_62',
#        'var_0__fft_coefficient__attr_"real"__coeff_63',
#        'var_0__fft_coefficient__attr_"real"__coeff_64',
#        'var_0__fft_coefficient__attr_"real"__coeff_65',
#        'var_0__fft_coefficient__attr_"real"__coeff_66',
#        'var_0__fft_coefficient__attr_"real"__coeff_67',
#        'var_0__fft_coefficient__attr_"real"__coeff_68',
#        'var_0__fft_coefficient__attr_"real"__coeff_69',
#        'var_0__fft_coefficient__attr_"real"__coeff_70',
#        'var_0__fft_coefficient__attr_"real"__coeff_71',
#        'var_0__fft_coefficient__attr_"real"__coeff_72',
#        'var_0__fft_coefficient__attr_"real"__coeff_73',
#        'var_0__fft_coefficient__attr_"real"__coeff_74',
#        'var_0__fft_coefficient__attr_"real"__coeff_75',
#        'var_0__fft_coefficient__attr_"real"__coeff_76',
#        'var_0__fft_coefficient__attr_"real"__coeff_77',
#        'var_0__fft_coefficient__attr_"real"__coeff_78',
#        'var_0__fft_coefficient__attr_"real"__coeff_79',
#        'var_0__fft_coefficient__attr_"real"__coeff_80',
#        'var_0__fft_coefficient__attr_"real"__coeff_81',
#        'var_0__fft_coefficient__attr_"real"__coeff_82',
#        'var_0__fft_coefficient__attr_"real"__coeff_83',
#        'var_0__fft_coefficient__attr_"real"__coeff_84',
#        'var_0__fft_coefficient__attr_"real"__coeff_85',
#        'var_0__fft_coefficient__attr_"real"__coeff_86',
#        'var_0__fft_coefficient__attr_"real"__coeff_87',
#        'var_0__fft_coefficient__attr_"real"__coeff_88',
#        'var_0__fft_coefficient__attr_"real"__coeff_89',
#        'var_0__fft_coefficient__attr_"real"__coeff_90',
#        'var_0__fft_coefficient__attr_"real"__coeff_91',
#        'var_0__fft_coefficient__attr_"real"__coeff_92',
#        'var_0__fft_coefficient__attr_"real"__coeff_93',
#        'var_0__fft_coefficient__attr_"real"__coeff_94',
#        'var_0__fft_coefficient__attr_"real"__coeff_95',
#        'var_0__fft_coefficient__attr_"real"__coeff_96',
#        'var_0__fft_coefficient__attr_"real"__coeff_97',
#        'var_0__fft_coefficient__attr_"real"__coeff_98',
#        'var_0__fft_coefficient__attr_"real"__coeff_99',
#        'var_0__fft_coefficient__attr_"imag"__coeff_0',
#        'var_0__fft_coefficient__attr_"imag"__coeff_1',
#        'var_0__fft_coefficient__attr_"imag"__coeff_2',
#        'var_0__fft_coefficient__attr_"imag"__coeff_3',
#        'var_0__fft_coefficient__attr_"imag"__coeff_4',
#        'var_0__fft_coefficient__attr_"imag"__coeff_5',
#        'var_0__fft_coefficient__attr_"imag"__coeff_6',
#        'var_0__fft_coefficient__attr_"imag"__coeff_7',
#        'var_0__fft_coefficient__attr_"imag"__coeff_8',
#        'var_0__fft_coefficient__attr_"imag"__coeff_9',
#        'var_0__fft_coefficient__attr_"imag"__coeff_10',
#        'var_0__fft_coefficient__attr_"imag"__coeff_11',
#        'var_0__fft_coefficient__attr_"imag"__coeff_12',
#        'var_0__fft_coefficient__attr_"imag"__coeff_13',
#        'var_0__fft_coefficient__attr_"imag"__coeff_14',
#        'var_0__fft_coefficient__attr_"imag"__coeff_15',
#        'var_0__fft_coefficient__attr_"imag"__coeff_16',
#        'var_0__fft_coefficient__attr_"imag"__coeff_17',
#        'var_0__fft_coefficient__attr_"imag"__coeff_18',
#        'var_0__fft_coefficient__attr_"imag"__coeff_19',
#        'var_0__fft_coefficient__attr_"imag"__coeff_20',
#        'var_0__fft_coefficient__attr_"imag"__coeff_21',
#        'var_0__fft_coefficient__attr_"imag"__coeff_22',
#        'var_0__fft_coefficient__attr_"imag"__coeff_23',
#        'var_0__fft_coefficient__attr_"imag"__coeff_24',
#        'var_0__fft_coefficient__attr_"imag"__coeff_25',
#        'var_0__fft_coefficient__attr_"imag"__coeff_26',
#        'var_0__fft_coefficient__attr_"imag"__coeff_27',
#        'var_0__fft_coefficient__attr_"imag"__coeff_28',
#        'var_0__fft_coefficient__attr_"imag"__coeff_29',
#        'var_0__fft_coefficient__attr_"imag"__coeff_30',
#        'var_0__fft_coefficient__attr_"imag"__coeff_31',
#        'var_0__fft_coefficient__attr_"imag"__coeff_32',
#        'var_0__fft_coefficient__attr_"imag"__coeff_33',
#        'var_0__fft_coefficient__attr_"imag"__coeff_34',
#        'var_0__fft_coefficient__attr_"imag"__coeff_35',
#        'var_0__fft_coefficient__attr_"imag"__coeff_36',
#        'var_0__fft_coefficient__attr_"imag"__coeff_37',
#        'var_0__fft_coefficient__attr_"imag"__coeff_38',
#        'var_0__fft_coefficient__attr_"imag"__coeff_39',
#        'var_0__fft_coefficient__attr_"imag"__coeff_40',
#        'var_0__fft_coefficient__attr_"imag"__coeff_41',
#        'var_0__fft_coefficient__attr_"imag"__coeff_42',
#        'var_0__fft_coefficient__attr_"imag"__coeff_43',
#        'var_0__fft_coefficient__attr_"imag"__coeff_44',
#        'var_0__fft_coefficient__attr_"imag"__coeff_45',
#        'var_0__fft_coefficient__attr_"imag"__coeff_46',
#        'var_0__fft_coefficient__attr_"imag"__coeff_47',
#        'var_0__fft_coefficient__attr_"imag"__coeff_48',
#        'var_0__fft_coefficient__attr_"imag"__coeff_49',
#        'var_0__fft_coefficient__attr_"imag"__coeff_50',
#        'var_0__fft_coefficient__attr_"imag"__coeff_51',
#        'var_0__fft_coefficient__attr_"imag"__coeff_52',
#        'var_0__fft_coefficient__attr_"imag"__coeff_53',
#        'var_0__fft_coefficient__attr_"imag"__coeff_54',
#        'var_0__fft_coefficient__attr_"imag"__coeff_55',
#        'var_0__fft_coefficient__attr_"imag"__coeff_56',
#        'var_0__fft_coefficient__attr_"imag"__coeff_57',
#        'var_0__fft_coefficient__attr_"imag"__coeff_58',
#        'var_0__fft_coefficient__attr_"imag"__coeff_59',
#        'var_0__fft_coefficient__attr_"imag"__coeff_60',
#        'var_0__fft_coefficient__attr_"imag"__coeff_61',
#        'var_0__fft_coefficient__attr_"imag"__coeff_62',
#        'var_0__fft_coefficient__attr_"imag"__coeff_63',
#        'var_0__fft_coefficient__attr_"imag"__coeff_64',
#        'var_0__fft_coefficient__attr_"imag"__coeff_65',
#        'var_0__fft_coefficient__attr_"imag"__coeff_66',
#        'var_0__fft_coefficient__attr_"imag"__coeff_67',
#        'var_0__fft_coefficient__attr_"imag"__coeff_68',
#        'var_0__fft_coefficient__attr_"imag"__coeff_69',
#        'var_0__fft_coefficient__attr_"imag"__coeff_70',
#        'var_0__fft_coefficient__attr_"imag"__coeff_71',
#        'var_0__fft_coefficient__attr_"imag"__coeff_72',
#        'var_0__fft_coefficient__attr_"imag"__coeff_73',
#        'var_0__fft_coefficient__attr_"imag"__coeff_74',
#        'var_0__fft_coefficient__attr_"imag"__coeff_75',
#        'var_0__fft_coefficient__attr_"imag"__coeff_76',
#        'var_0__fft_coefficient__attr_"imag"__coeff_77',
#        'var_0__fft_coefficient__attr_"imag"__coeff_78',
#        'var_0__fft_coefficient__attr_"imag"__coeff_79',
#        'var_0__fft_coefficient__attr_"imag"__coeff_80',
#        'var_0__fft_coefficient__attr_"imag"__coeff_81',
#        'var_0__fft_coefficient__attr_"imag"__coeff_82',
#        'var_0__fft_coefficient__attr_"imag"__coeff_83',
#        'var_0__fft_coefficient__attr_"imag"__coeff_84',
#        'var_0__fft_coefficient__attr_"imag"__coeff_85',
#        'var_0__fft_coefficient__attr_"imag"__coeff_86',
#        'var_0__fft_coefficient__attr_"imag"__coeff_87',
#        'var_0__fft_coefficient__attr_"imag"__coeff_88',
#        'var_0__fft_coefficient__attr_"imag"__coeff_89',
#        'var_0__fft_coefficient__attr_"imag"__coeff_90',
#        'var_0__fft_coefficient__attr_"imag"__coeff_91',
#        'var_0__fft_coefficient__attr_"imag"__coeff_92',
#        'var_0__fft_coefficient__attr_"imag"__coeff_93',
#        'var_0__fft_coefficient__attr_"imag"__coeff_94',
#        'var_0__fft_coefficient__attr_"imag"__coeff_95',
#        'var_0__fft_coefficient__attr_"imag"__coeff_96',
#        'var_0__fft_coefficient__attr_"imag"__coeff_97',
#        'var_0__fft_coefficient__attr_"imag"__coeff_98',
#        'var_0__fft_coefficient__attr_"imag"__coeff_99',
#        'var_0__fft_coefficient__attr_"abs"__coeff_0',
#        'var_0__fft_coefficient__attr_"abs"__coeff_1',
#        'var_0__fft_coefficient__attr_"abs"__coeff_2',
#        'var_0__fft_coefficient__attr_"abs"__coeff_3',
#        'var_0__fft_coefficient__attr_"abs"__coeff_4',
#        'var_0__fft_coefficient__attr_"abs"__coeff_5',
#        'var_0__fft_coefficient__attr_"abs"__coeff_6',
#        'var_0__fft_coefficient__attr_"abs"__coeff_7',
#        'var_0__fft_coefficient__attr_"abs"__coeff_8',
#        'var_0__fft_coefficient__attr_"abs"__coeff_9',
#        'var_0__fft_coefficient__attr_"abs"__coeff_10',
#        'var_0__fft_coefficient__attr_"abs"__coeff_11',
#        'var_0__fft_coefficient__attr_"abs"__coeff_12',
#        'var_0__fft_coefficient__attr_"abs"__coeff_13',
#        'var_0__fft_coefficient__attr_"abs"__coeff_14',
#        'var_0__fft_coefficient__attr_"abs"__coeff_15',
#        'var_0__fft_coefficient__attr_"abs"__coeff_16',
#        'var_0__fft_coefficient__attr_"abs"__coeff_17',
#        'var_0__fft_coefficient__attr_"abs"__coeff_18',
#        'var_0__fft_coefficient__attr_"abs"__coeff_19',
#        'var_0__fft_coefficient__attr_"abs"__coeff_20',
#        'var_0__fft_coefficient__attr_"abs"__coeff_21',
#        'var_0__fft_coefficient__attr_"abs"__coeff_22',
#        'var_0__fft_coefficient__attr_"abs"__coeff_23',
#        'var_0__fft_coefficient__attr_"abs"__coeff_24',
#        'var_0__fft_coefficient__attr_"abs"__coeff_25',
#        'var_0__fft_coefficient__attr_"abs"__coeff_26',
#        'var_0__fft_coefficient__attr_"abs"__coeff_27',
#        'var_0__fft_coefficient__attr_"abs"__coeff_28',
#        'var_0__fft_coefficient__attr_"abs"__coeff_29',
#        'var_0__fft_coefficient__attr_"abs"__coeff_30',
#        'var_0__fft_coefficient__attr_"abs"__coeff_31',
#        'var_0__fft_coefficient__attr_"abs"__coeff_32',
#        'var_0__fft_coefficient__attr_"abs"__coeff_33',
#        'var_0__fft_coefficient__attr_"abs"__coeff_34',
#        'var_0__fft_coefficient__attr_"abs"__coeff_35',
#        'var_0__fft_coefficient__attr_"abs"__coeff_36',
#        'var_0__fft_coefficient__attr_"abs"__coeff_37',
#        'var_0__fft_coefficient__attr_"abs"__coeff_38',
#        'var_0__fft_coefficient__attr_"abs"__coeff_39',
#        'var_0__fft_coefficient__attr_"abs"__coeff_40',
#        'var_0__fft_coefficient__attr_"abs"__coeff_41',
#        'var_0__fft_coefficient__attr_"abs"__coeff_42',
#        'var_0__fft_coefficient__attr_"abs"__coeff_43',
#        'var_0__fft_coefficient__attr_"abs"__coeff_44',
#        'var_0__fft_coefficient__attr_"abs"__coeff_45',
#        'var_0__fft_coefficient__attr_"abs"__coeff_46',
#        'var_0__fft_coefficient__attr_"abs"__coeff_47',
#        'var_0__fft_coefficient__attr_"abs"__coeff_48',
#        'var_0__fft_coefficient__attr_"abs"__coeff_49',
#        'var_0__fft_coefficient__attr_"abs"__coeff_50',
#        'var_0__fft_coefficient__attr_"abs"__coeff_51',
#        'var_0__fft_coefficient__attr_"abs"__coeff_52',
#        'var_0__fft_coefficient__attr_"abs"__coeff_53',
#        'var_0__fft_coefficient__attr_"abs"__coeff_54',
#        'var_0__fft_coefficient__attr_"abs"__coeff_55',
#        'var_0__fft_coefficient__attr_"abs"__coeff_56',
#        'var_0__fft_coefficient__attr_"abs"__coeff_57',
#        'var_0__fft_coefficient__attr_"abs"__coeff_58',
#        'var_0__fft_coefficient__attr_"abs"__coeff_59',
#        'var_0__fft_coefficient__attr_"abs"__coeff_60',
#        'var_0__fft_coefficient__attr_"abs"__coeff_61',
#        'var_0__fft_coefficient__attr_"abs"__coeff_62',
#        'var_0__fft_coefficient__attr_"abs"__coeff_63',
#        'var_0__fft_coefficient__attr_"abs"__coeff_64',
#        'var_0__fft_coefficient__attr_"abs"__coeff_65',
#        'var_0__fft_coefficient__attr_"abs"__coeff_66',
#        'var_0__fft_coefficient__attr_"abs"__coeff_67',
#        'var_0__fft_coefficient__attr_"abs"__coeff_68',
#        'var_0__fft_coefficient__attr_"abs"__coeff_69',
#        'var_0__fft_coefficient__attr_"abs"__coeff_70',
#        'var_0__fft_coefficient__attr_"abs"__coeff_71',
#        'var_0__fft_coefficient__attr_"abs"__coeff_72',
#        'var_0__fft_coefficient__attr_"abs"__coeff_73',
#        'var_0__fft_coefficient__attr_"abs"__coeff_74',
#        'var_0__fft_coefficient__attr_"abs"__coeff_75',
#        'var_0__fft_coefficient__attr_"abs"__coeff_76',
#        'var_0__fft_coefficient__attr_"abs"__coeff_77',
#        'var_0__fft_coefficient__attr_"abs"__coeff_78',
#        'var_0__fft_coefficient__attr_"abs"__coeff_79',
#        'var_0__fft_coefficient__attr_"abs"__coeff_80',
#        'var_0__fft_coefficient__attr_"abs"__coeff_81',
#        'var_0__fft_coefficient__attr_"abs"__coeff_82',
#        'var_0__fft_coefficient__attr_"abs"__coeff_83',
#        'var_0__fft_coefficient__attr_"abs"__coeff_84',
#        'var_0__fft_coefficient__attr_"abs"__coeff_85',
#        'var_0__fft_coefficient__attr_"abs"__coeff_86',
#        'var_0__fft_coefficient__attr_"abs"__coeff_87',
#        'var_0__fft_coefficient__attr_"abs"__coeff_88',
#        'var_0__fft_coefficient__attr_"abs"__coeff_89',
#        'var_0__fft_coefficient__attr_"abs"__coeff_90',
#        'var_0__fft_coefficient__attr_"abs"__coeff_91',
#        'var_0__fft_coefficient__attr_"abs"__coeff_92',
#        'var_0__fft_coefficient__attr_"abs"__coeff_93',
#        'var_0__fft_coefficient__attr_"abs"__coeff_94',
#        'var_0__fft_coefficient__attr_"abs"__coeff_95',
#        'var_0__fft_coefficient__attr_"abs"__coeff_96',
#        'var_0__fft_coefficient__attr_"abs"__coeff_97',
#        'var_0__fft_coefficient__attr_"abs"__coeff_98',
#        'var_0__fft_coefficient__attr_"abs"__coeff_99',
#        'var_0__fft_coefficient__attr_"angle"__coeff_0',
#        'var_0__fft_coefficient__attr_"angle"__coeff_1',
#        'var_0__fft_coefficient__attr_"angle"__coeff_2',
#        'var_0__fft_coefficient__attr_"angle"__coeff_3',
#        'var_0__fft_coefficient__attr_"angle"__coeff_4',
#        'var_0__fft_coefficient__attr_"angle"__coeff_5',
#        'var_0__fft_coefficient__attr_"angle"__coeff_6',
#        'var_0__fft_coefficient__attr_"angle"__coeff_7',
#        'var_0__fft_coefficient__attr_"angle"__coeff_8',
#        'var_0__fft_coefficient__attr_"angle"__coeff_9',
#        'var_0__fft_coefficient__attr_"angle"__coeff_10',
#        'var_0__fft_coefficient__attr_"angle"__coeff_11',
#        'var_0__fft_coefficient__attr_"angle"__coeff_12',
#        'var_0__fft_coefficient__attr_"angle"__coeff_13',
#        'var_0__fft_coefficient__attr_"angle"__coeff_14',
#        'var_0__fft_coefficient__attr_"angle"__coeff_15',
#        'var_0__fft_coefficient__attr_"angle"__coeff_16',
#        'var_0__fft_coefficient__attr_"angle"__coeff_17',
#        'var_0__fft_coefficient__attr_"angle"__coeff_18',
#        'var_0__fft_coefficient__attr_"angle"__coeff_19',
#        'var_0__fft_coefficient__attr_"angle"__coeff_20',
#        'var_0__fft_coefficient__attr_"angle"__coeff_21',
#        'var_0__fft_coefficient__attr_"angle"__coeff_22',
#        'var_0__fft_coefficient__attr_"angle"__coeff_23',
#        'var_0__fft_coefficient__attr_"angle"__coeff_24',
#        'var_0__fft_coefficient__attr_"angle"__coeff_25',
#        'var_0__fft_coefficient__attr_"angle"__coeff_26',
#        'var_0__fft_coefficient__attr_"angle"__coeff_27',
#        'var_0__fft_coefficient__attr_"angle"__coeff_28',
#        'var_0__fft_coefficient__attr_"angle"__coeff_29',
#        'var_0__fft_coefficient__attr_"angle"__coeff_30',
#        'var_0__fft_coefficient__attr_"angle"__coeff_31',
#        'var_0__fft_coefficient__attr_"angle"__coeff_32',
#        'var_0__fft_coefficient__attr_"angle"__coeff_33',
#        'var_0__fft_coefficient__attr_"angle"__coeff_34',
#        'var_0__fft_coefficient__attr_"angle"__coeff_35',
#        'var_0__fft_coefficient__attr_"angle"__coeff_36',
#        'var_0__fft_coefficient__attr_"angle"__coeff_37',
#        'var_0__fft_coefficient__attr_"angle"__coeff_38',
#        'var_0__fft_coefficient__attr_"angle"__coeff_39',
#        'var_0__fft_coefficient__attr_"angle"__coeff_40',
#        'var_0__fft_coefficient__attr_"angle"__coeff_41',
#        'var_0__fft_coefficient__attr_"angle"__coeff_42',
#        'var_0__fft_coefficient__attr_"angle"__coeff_43',
#        'var_0__fft_coefficient__attr_"angle"__coeff_44',
#        'var_0__fft_coefficient__attr_"angle"__coeff_45',
#        'var_0__fft_coefficient__attr_"angle"__coeff_46',
#        'var_0__fft_coefficient__attr_"angle"__coeff_47',
#        'var_0__fft_coefficient__attr_"angle"__coeff_48',
#        'var_0__fft_coefficient__attr_"angle"__coeff_49',
#        'var_0__fft_coefficient__attr_"angle"__coeff_50',
#        'var_0__fft_coefficient__attr_"angle"__coeff_51',
#        'var_0__fft_coefficient__attr_"angle"__coeff_52',
#        'var_0__fft_coefficient__attr_"angle"__coeff_53',
#        'var_0__fft_coefficient__attr_"angle"__coeff_54',
#        'var_0__fft_coefficient__attr_"angle"__coeff_55',
#        'var_0__fft_coefficient__attr_"angle"__coeff_56',
#        'var_0__fft_coefficient__attr_"angle"__coeff_57',
#        'var_0__fft_coefficient__attr_"angle"__coeff_58',
#        'var_0__fft_coefficient__attr_"angle"__coeff_59',
#        'var_0__fft_coefficient__attr_"angle"__coeff_60',
#        'var_0__fft_coefficient__attr_"angle"__coeff_61',
#        'var_0__fft_coefficient__attr_"angle"__coeff_62',
#        'var_0__fft_coefficient__attr_"angle"__coeff_63',
#        'var_0__fft_coefficient__attr_"angle"__coeff_64',
#        'var_0__fft_coefficient__attr_"angle"__coeff_65',
#        'var_0__fft_coefficient__attr_"angle"__coeff_66',
#        'var_0__fft_coefficient__attr_"angle"__coeff_67',
#        'var_0__fft_coefficient__attr_"angle"__coeff_68',
#        'var_0__fft_coefficient__attr_"angle"__coeff_69',
#        'var_0__fft_coefficient__attr_"angle"__coeff_70',
#        'var_0__fft_coefficient__attr_"angle"__coeff_71',
#        'var_0__fft_coefficient__attr_"angle"__coeff_72',
#        'var_0__fft_coefficient__attr_"angle"__coeff_73',
#        'var_0__fft_coefficient__attr_"angle"__coeff_74',
#        'var_0__fft_coefficient__attr_"angle"__coeff_75',
#        'var_0__fft_coefficient__attr_"angle"__coeff_76',
#        'var_0__fft_coefficient__attr_"angle"__coeff_77',
#        'var_0__fft_coefficient__attr_"angle"__coeff_78',
#        'var_0__fft_coefficient__attr_"angle"__coeff_79',
#        'var_0__fft_coefficient__attr_"angle"__coeff_80',
#        'var_0__fft_coefficient__attr_"angle"__coeff_81',
#        'var_0__fft_coefficient__attr_"angle"__coeff_82',
#        'var_0__fft_coefficient__attr_"angle"__coeff_83',
#        'var_0__fft_coefficient__attr_"angle"__coeff_84',
#        'var_0__fft_coefficient__attr_"angle"__coeff_85',
#        'var_0__fft_coefficient__attr_"angle"__coeff_86',
#        'var_0__fft_coefficient__attr_"angle"__coeff_87',
#        'var_0__fft_coefficient__attr_"angle"__coeff_88',
#        'var_0__fft_coefficient__attr_"angle"__coeff_89',
#        'var_0__fft_coefficient__attr_"angle"__coeff_90',
#        'var_0__fft_coefficient__attr_"angle"__coeff_91',
#        'var_0__fft_coefficient__attr_"angle"__coeff_92',
#        'var_0__fft_coefficient__attr_"angle"__coeff_93',
#        'var_0__fft_coefficient__attr_"angle"__coeff_94',
#        'var_0__fft_coefficient__attr_"angle"__coeff_95',
#        'var_0__fft_coefficient__attr_"angle"__coeff_96',
#        'var_0__fft_coefficient__attr_"angle"__coeff_97',
#        'var_0__fft_coefficient__attr_"angle"__coeff_98',
#        'var_0__fft_coefficient__attr_"angle"__coeff_99',
#        'var_0__fft_aggregated__aggtype_"centroid"',
#        'var_0__fft_aggregated__aggtype_"variance"',
#        'var_0__fft_aggregated__aggtype_"skew"',
#        'var_0__fft_aggregated__aggtype_"kurtosis"',
#        'var_0__value_count__value_0', 'var_0__value_count__value_1',
#        'var_0__value_count__value_-1',
#        'var_0__range_count__max_1__min_-1',
#        'var_0__range_count__max_0__min_-1000000000000.0',
#        'var_0__range_count__max_1000000000000.0__min_0',
#        'var_0__friedrich_coefficients__coeff_0__m_3__r_30',
#        'var_0__friedrich_coefficients__coeff_1__m_3__r_30',
#        'var_0__friedrich_coefficients__coeff_2__m_3__r_30',
#        'var_0__friedrich_coefficients__coeff_3__m_3__r_30',
#        'var_0__max_langevin_fixed_point__m_3__r_30',
#        'var_0__linear_trend__attr_"pvalue"',
#        'var_0__linear_trend__attr_"rvalue"',
#        'var_0__linear_trend__attr_"intercept"',
#        'var_0__linear_trend__attr_"slope"',
#        'var_0__linear_trend__attr_"stderr"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_10__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"rvalue"__chunk_len_50__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_5__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"intercept"__chunk_len_50__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_5__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_10__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"slope"__chunk_len_50__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_5__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"var"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"max"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"min"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"mean"',
#        'var_0__agg_linear_trend__attr_"stderr"__chunk_len_50__f_agg_"var"',
#        'var_0__augmented_dickey_fuller__attr_"teststat"__autolag_"AIC"',
#        'var_0__augmented_dickey_fuller__attr_"pvalue"__autolag_"AIC"',
#        'var_0__augmented_dickey_fuller__attr_"usedlag"__autolag_"AIC"',
#        'var_0__number_crossing_m__m_0', 'var_0__number_crossing_m__m_-1',
#        'var_0__number_crossing_m__m_1',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_2',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_5',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_6',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_8',
#        'var_0__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#        'var_0__ratio_beyond_r_sigma__r_0.5',
#        'var_0__ratio_beyond_r_sigma__r_1',
#        'var_0__ratio_beyond_r_sigma__r_1.5',
#        'var_0__ratio_beyond_r_sigma__r_2',
#        'var_0__ratio_beyond_r_sigma__r_2.5',
#        'var_0__ratio_beyond_r_sigma__r_3',
#        'var_0__ratio_beyond_r_sigma__r_5',
#        'var_0__ratio_beyond_r_sigma__r_6',
#        'var_0__ratio_beyond_r_sigma__r_7',
#        'var_0__ratio_beyond_r_sigma__r_10', 'var_0__count_above__t_0',
#        'var_0__count_below__t_0', 'var_0__lempel_ziv_complexity__bins_2',
#        'var_0__lempel_ziv_complexity__bins_3',
#        'var_0__lempel_ziv_complexity__bins_5',
#        'var_0__lempel_ziv_complexity__bins_10',
#        'var_0__lempel_ziv_complexity__bins_100',
#        'var_0__fourier_entropy__bins_2', 'var_0__fourier_entropy__bins_3',
#        'var_0__fourier_entropy__bins_5',
#        'var_0__fourier_entropy__bins_10',
#        'var_0__fourier_entropy__bins_100',
#        'var_0__permutation_entropy__dimension_3__tau_1',
#        'var_0__permutation_entropy__dimension_4__tau_1',
#        'var_0__permutation_entropy__dimension_5__tau_1',
#        'var_0__permutation_entropy__dimension_6__tau_1',
#        'var_0__permutation_entropy__dimension_7__tau_1',
#        'var_0__query_similarity_count__query_None__threshold_0.0',
#        'var_0__matrix_profile__feature_"min"__threshold_0.98',
#        'var_0__matrix_profile__feature_"max"__threshold_0.98',
#        'var_0__matrix_profile__feature_"mean"__threshold_0.98',
#        'var_0__matrix_profile__feature_"median"__threshold_0.98',
#        'var_0__matrix_profile__feature_"25"__threshold_0.98',
#        'var_0__matrix_profile__feature_"75"__threshold_0.98',
#        'var_0__mean_n_absolute_max__number_of_maxima_7'], dtype=object)

# %%
x_train_f.columns
# Out:
# Index(['var_0__variance_larger_than_standard_deviation',
#        'var_0__has_duplicate_max', 'var_0__has_duplicate_min',
#        'var_0__has_duplicate', 'var_0__sum_values', 'var_0__abs_energy',
#        'var_0__mean_abs_change', 'var_0__mean_change',
#        'var_0__mean_second_derivative_central', 'var_0__median',
#        ...
#        'var_0__permutation_entropy__dimension_6__tau_1',
#        'var_0__permutation_entropy__dimension_7__tau_1',
#        'var_0__query_similarity_count__query_None__threshold_0.0',
#        'var_0__matrix_profile__feature_"min"__threshold_0.98',
#        'var_0__matrix_profile__feature_"max"__threshold_0.98',
#        'var_0__matrix_profile__feature_"mean"__threshold_0.98',
#        'var_0__matrix_profile__feature_"median"__threshold_0.98',
#        'var_0__matrix_profile__feature_"25"__threshold_0.98',
#        'var_0__matrix_profile__feature_"75"__threshold_0.98',
#        'var_0__mean_n_absolute_max__number_of_maxima_7'],
#       dtype='object', length=783)

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel


lsvc = LinearSVC(C=0.005, penalty="l1", dual=False).fit(x_train_f, y_train)
model = SelectFromModel(lsvc, prefit=True)

x_train_f_new = model.transform(x_train_f)
x_test_f_new = model.transform(x_test_f)
x_train_f_new.shape
# Out:
# (736, 104)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report

# clf = RandomForestClassifier(max_depth=2, random_state=0)
clf = GradientBoostingClassifier()
clf.fit(x_train_f_new, y_train)

y_pred = clf.predict(x_test_f_new)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.72      0.88      0.79        50
#            2       0.83      0.81      0.82        48
#            3       0.91      0.66      0.76        44
#            4       0.86      0.75      0.80        51
#            5       0.78      0.90      0.83        50
#            6       0.91      0.92      0.91        52
#
#     accuracy                           0.82       295
#    macro avg       0.83      0.82      0.82       295
# weighted avg       0.83      0.82      0.82       295

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
# Mapping table for classes
labels = {1:'WALKING', 2:'WALKING UPSTAIRS', 3:'WALKING DOWNSTAIRS',
          4:'SITTING', 5:'STANDING', 6:'LAYING'}

print(classification_report( y_test, y_pred,
                            target_names=[l for l in labels.values()]))

conf_mat = confusion_matrix( y_test, y_pred,)

fig = plt.figure(figsize=(6,6))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=plt.cm.summer, interpolation='nearest')
for i, row in enumerate(conf_mat):
    for j, c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)
            
cb = fig.colorbar(res)
plt.title('Confusion Matrix')
_ = plt.xticks(range(6), [l for l in labels.values()], rotation=90)
_ = plt.yticks(range(6), [l for l in labels.values()])
# Out:
#                     precision    recall  f1-score   support
#
#            WALKING       0.72      0.86      0.78        50
#   WALKING UPSTAIRS       0.80      0.81      0.80        48
# WALKING DOWNSTAIRS       0.90      0.64      0.75        44
#            SITTING       0.86      0.75      0.80        51
#           STANDING       0.78      0.90      0.83        50
#             LAYING       0.92      0.94      0.93        52
#
#           accuracy                           0.82       295
#          macro avg       0.83      0.82      0.82       295
#       weighted avg       0.83      0.82      0.82       295
