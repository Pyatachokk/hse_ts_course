# %% [markdown]
# ### Данная тетрадка подготовлена Степаном Зиминым (tg @smzimin) и используется с его согласия.

# %% [markdown]
# # Financial data sources
#
#
# ## Content
#
#
# - Stock market data sources
#     - Yahoo Finance
#         - Daily data
#         - Daily returns
#         - Dividends and Stock splits
#         - Intraday data
#     - Finam
#         - (Raw) Intraday data for long period
#         - Data preprocessing
#     - Finnhub
#         - Nice API
#         - Different types of data: estimates, news etc.
#
#
# - Bond market data sources
#     - Finam and Cbonds
#         - Calendar of payments
#         - Clean and dirty price
#     - Bloomberg
#         - A lot of historical quotes
#         - Price and yield-to-maturity

# %%
import numpy as np
import pandas as pd
from datetime import datetime, date
import time

import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("bmh")
plt.rcParams['font.family'] = 'DejaVu Sans'

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Stock market data sources
#
# ## Yahoo Finance
#
# https://finance.yahoo.com/quote/TSLA/

# %% [markdown]
# #### Install and import yfinance library

# %%
# !pip install yfinance

import yfinance as yf

# %% [markdown]
# #### Get daily data for Apple stock by specifying the stock ticker, start date, and end date

# %%
prices = yf.download(
    tickers='TSLA',
    start='2015-01-01',
    end='2022-03-22',
)

prices.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-01-02  14.858000  14.883333  14.217333  14.620667  14.620667  71466000
# 2015-01-05  14.303333  14.433333  13.810667  14.006000  14.006000  80527500
# 2015-01-06  14.004000  14.280000  13.614000  14.085333  14.085333  93928500
# 2015-01-07  14.223333  14.318667  13.985333  14.063333  14.063333  44526000
# 2015-01-08  14.187333  14.253333  14.000667  14.041333  14.041333  51637500

# %% [markdown]
# #### Plot daily prices
#
# We'll use `Adjusted Close` to account for dividends and stock splits. Yahoo finance accounts for stock splits even in their `Close` price. However, some other data vendors don't (e.g. *Finam*). Pay attention.

# %%
plot_fields =  ['Close', 'Adj Close']

fig = plt.figure(figsize=(16, 5))

plt.plot(prices[plot_fields])
plt.legend(plot_fields)

plt.title("Stock daily price", weight="bold")

plt.show()

# %%
plot_fields =  ['Volume']

fig = plt.figure(figsize=(16, 5))

plt.plot(prices[plot_fields])
plt.legend(plot_fields)

plt.title("Daily Volume", weight="bold")

plt.show()

# %% [markdown]
# We convert datetime index to period

# %%
print(prices.index)

prices.index = prices.index.to_period(freq='d')

print(prices.index)
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11',
#                '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17',
#                '2022-03-18', '2022-03-21'],
#               dtype='datetime64[ns]', name='Date', length=1817, freq=None)
# PeriodIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#              '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#              '2015-01-14', '2015-01-15',
#              ...
#              '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11',
#              '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17',
#              '2022-03-18', '2022-03-21'],
#             dtype='period[D]', name='Date', length=1817)

# %%
price = prices['Adj Close']

price.head()
# Out:
# Date
# 2015-01-02    14.620667
# 2015-01-05    14.006000
# 2015-01-06    14.085333
# 2015-01-07    14.063333
# 2015-01-08    14.041333
# Freq: D, Name: Adj Close, dtype: float64

# %% [markdown]
# We can calculate absolute difference in prices, logarithmic returns and arithmetic returns

# %%
dX = price.diff()

ret = price.pct_change()

ret_log = np.log(price).diff()

ret
# Out:
# Date
# 2015-01-02         NaN
# 2015-01-05   -0.042041
# 2015-01-06    0.005664
# 2015-01-07   -0.001562
# 2015-01-08   -0.001564
#                 ...
# 2022-03-15    0.046348
# 2022-03-16    0.047812
# 2022-03-17    0.037335
# 2022-03-18    0.038768
# 2022-03-21    0.017418
# Freq: D, Name: Adj Close, Length: 1817, dtype: float64

# %%
ret = ret.dropna()

# %%
fig = plt.figure(figsize=(16, 5))

ret.plot()
plt.title("Daily returns", weight="bold")

plt.show()

# %% [markdown]
# #### Get daily data + information about Dividends	Stock Splits

# %%
prices = yf.download(
    tickers='TSLA',
    start='2020-01-01',
    end='2022-03-20',
    actions=True
)

prices.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-02  28.299999  28.713333  28.114000  28.684000  28.684000  142981500
# 2020-01-03  29.366667  30.266666  29.128000  29.534000  29.534000  266677500
# 2020-01-06  29.364668  30.104000  29.333332  30.102667  30.102667  151995000
# 2020-01-07  30.760000  31.441999  30.224001  31.270666  31.270666  268231500
# 2020-01-08  31.580000  33.232666  31.215334  32.809334  32.809334  467164500
#
#             Dividends  Stock Splits
# Date
# 2020-01-02        0.0           0.0
# 2020-01-03        0.0           0.0
# 2020-01-06        0.0           0.0
# 2020-01-07        0.0           0.0
# 2020-01-08        0.0           0.0

# %%
prices[['Stock Splits']].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# #### Intraday data

# %%
prices_intraday = yf.download(
    'TSLA', 
    period='5d', 
    interval='1m'
)

prices_intraday.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-03-27 09:30:00-04:00  194.414993  195.220001  194.080002  195.110107
# 2023-03-27 09:31:00-04:00  195.162003  195.789993  195.089996  195.175003
# 2023-03-27 09:32:00-04:00  195.220001  196.130005  195.220001  195.890106
# 2023-03-27 09:33:00-04:00  195.892593  196.190002  195.517105  195.910004
# 2023-03-27 09:34:00-04:00  195.930893  196.300003  195.399994  196.251999
#
#                             Adj Close   Volume
# Datetime
# 2023-03-27 09:30:00-04:00  195.110107  4126738
# 2023-03-27 09:31:00-04:00  195.175003  1119676
# 2023-03-27 09:32:00-04:00  195.890106   920561
# 2023-03-27 09:33:00-04:00  195.910004   710260
# 2023-03-27 09:34:00-04:00  196.251999   792214

# %%
plot_fields =  ['Close', 'Adj Close']

fig = plt.figure(figsize=(16, 5))

plt.plot(prices_intraday[plot_fields])
plt.legend(plot_fields)

plt.title("Stock price", weight="bold")

plt.show()

# %%
prices_intraday.index
# Out:
# DatetimeIndex(['2023-03-27 09:30:00-04:00', '2023-03-27 09:31:00-04:00',
#                '2023-03-27 09:32:00-04:00', '2023-03-27 09:33:00-04:00',
#                '2023-03-27 09:34:00-04:00', '2023-03-27 09:35:00-04:00',
#                '2023-03-27 09:36:00-04:00', '2023-03-27 09:37:00-04:00',
#                '2023-03-27 09:38:00-04:00', '2023-03-27 09:39:00-04:00',
#                ...
#                '2023-03-31 15:50:00-04:00', '2023-03-31 15:51:00-04:00',
#                '2023-03-31 15:52:00-04:00', '2023-03-31 15:53:00-04:00',
#                '2023-03-31 15:54:00-04:00', '2023-03-31 15:55:00-04:00',
#                '2023-03-31 15:56:00-04:00', '2023-03-31 15:57:00-04:00',
#                '2023-03-31 15:58:00-04:00', '2023-03-31 15:59:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Datetime', length=1950, freq=None)

# %%
prices_intraday.index.date
# Out:
# array([datetime.date(2023, 3, 27), datetime.date(2023, 3, 27),
#        datetime.date(2023, 3, 27), ..., datetime.date(2023, 3, 31),
#        datetime.date(2023, 3, 31), datetime.date(2023, 3, 31)],
#       dtype=object)

# %%
prices_intraday.index.time
# Out:
# array([datetime.time(9, 30), datetime.time(9, 31), datetime.time(9, 32),
#        ..., datetime.time(15, 57), datetime.time(15, 58),
#        datetime.time(15, 59)], dtype=object)

# %% [markdown]
# ## Finam
#
# https://www.finam.ru/quote/akcii-usa-bats/tesla-inc_tsla/

# %%
prices_intraday_finam = pd.read_csv('data/US1.TSLA_200101_210118_v2.csv', )

idx = prices_intraday_finam['<TIME>'] > 0
prices_intraday_finam = prices_intraday_finam.loc[idx]

prices_intraday_finam.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 prices_intraday_finam = pd.read_csv('data/US1.TSLA_200101_210118_v2.csv', )
#       3 idx = prices_intraday_finam['<TIME>'] > 0
#       4 prices_intraday_finam = prices_intraday_finam.loc[idx]
#
# File c:\Users\zehov\Desktop\current_projects\hse_ts_course\venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\zehov\Desktop\current_projects\hse_ts_course\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\zehov\Desktop\current_projects\hse_ts_course\venv\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\zehov\Desktop\current_projects\hse_ts_course\venv\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\zehov\Desktop\current_projects\hse_ts_course\venv\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\zehov\Desktop\current_projects\hse_ts_course\venv\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\zehov\Desktop\current_projects\hse_ts_course\venv\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/US1.TSLA_200101_210118_v2.csv'

# %%
pd.to_datetime(prices_intraday_finam['<DATE>'], format='%Y%m%d')
# Out:
# 0       2020-01-02
# 1       2020-01-02
# 2       2020-01-02
# 3       2020-01-02
# 4       2020-01-02
#            ...
# 98720   2021-01-15
# 98721   2021-01-15
# 98722   2021-01-15
# 98723   2021-01-15
# 98724   2021-01-15
# Name: <DATE>, Length: 98631, dtype: datetime64[ns]

# %%
# prices_intraday_finam['<TIME>'] = prices_intraday_finam['<TIME>'].astype(str)
# prices_intraday_finam['<TIME>'] = prices_intraday_finam['<TIME>'].replace({"0": "000000"})

pd.to_datetime(prices_intraday_finam['<TIME>'], format='%H%M%S')
# Out:
# 0       1900-01-01 17:31:00
# 1       1900-01-01 17:32:00
# 2       1900-01-01 17:33:00
# 3       1900-01-01 17:34:00
# 4       1900-01-01 17:35:00
#                 ...
# 98720   1900-01-01 23:55:00
# 98721   1900-01-01 23:56:00
# 98722   1900-01-01 23:57:00
# 98723   1900-01-01 23:58:00
# 98724   1900-01-01 23:59:00
# Name: <TIME>, Length: 98631, dtype: datetime64[ns]

# %%
prices_intraday_finam['time'] = prices_intraday_finam['<DATE>'] * 10**6 + prices_intraday_finam['<TIME>']

prices_intraday_finam['time']
# Out:
# 0        20200102173100
# 1        20200102173200
# 2        20200102173300
# 3        20200102173400
# 4        20200102173500
#               ...
# 98720    20210115235500
# 98721    20210115235600
# 98722    20210115235700
# 98723    20210115235800
# 98724    20210115235900
# Name: time, Length: 98631, dtype: int64

# %%
prices_intraday_finam['time'] = pd.to_datetime(prices_intraday_finam['time'], format='%Y%m%d%H%M%S')

# %%
prices_intraday_finam = prices_intraday_finam.set_index('time')

prices_intraday_finam.head()
# Out:
#                      <TICKER>  <PER>    <DATE>  <TIME>   <OPEN>  <HIGH>  \
# time
# 2020-01-02 17:31:00  US1.TSLA      1  20200102  173100  424.990  427.34
# 2020-01-02 17:32:00  US1.TSLA      1  20200102  173200  427.350  427.39
# 2020-01-02 17:33:00  US1.TSLA      1  20200102  173300  426.620  426.62
# 2020-01-02 17:34:00  US1.TSLA      1  20200102  173400  426.495  428.00
# 2020-01-02 17:35:00  US1.TSLA      1  20200102  173500  427.750  427.99
#
#                       <LOW>  <CLOSE>  <VOL>
# time
# 2020-01-02 17:31:00  424.39   427.09   6700
# 2020-01-02 17:32:00  425.60   426.51   2936
# 2020-01-02 17:33:00  425.59   426.02   4121
# 2020-01-02 17:34:00  426.31   427.75   5942
# 2020-01-02 17:35:00  425.88   426.00   4591

# %%
plot_fields =  ['<CLOSE>', '<OPEN>']

fig = plt.figure(figsize=(16, 5))

plt.plot(prices_intraday_finam[plot_fields])
plt.legend(plot_fields)

plt.title("Stock daily price", weight="bold")

plt.show()

# %%
idx = prices_intraday_finam.index.date == date(2021, 1, 15)

plot_fields =  ['<CLOSE>', '<OPEN>']

fig = plt.figure(figsize=(16, 5))

plt.plot(prices_intraday_finam.loc[idx ,plot_fields])
plt.legend(plot_fields)

plt.title("Stock price", weight="bold")

plt.show()

# %% [markdown]
# ## Finnhub
#
# https://github.com/Finnhub-Stock-API/finnhub-python
#
# https://finnhub.io/
#
# You have 60 API calls/minute for free

# %%
# !pip install finnhub-python

# %%
import finnhub

with open('finnhub_api_key.txt', 'r') as file:
    finnhub_api_key = file.read()

# Setup client
finnhub_client = finnhub.Client(api_key=finnhub_api_key)

# %%
start_date = date(2020,1,1)
end_date = date(2021,1,1)

# %%
int(time.mktime(start_date.timetuple()))
# Out:
# 1577826000

# %%
prices_daily = finnhub_client.stock_candles(
    symbol='TSLA', 
    resolution='D', 
    _from=int(time.mktime(start_date.timetuple())), 
    to=int(time.mktime(end_date.timetuple())), 
)

prices_daily = pd.DataFrame(prices_daily)

prices_daily.head()
# Out:
#         c         h       l         o   s           t         v
# 0  83.666  84.25800  80.416  81.00006  ok  1577750400  10292456
# 1  86.052  86.13914  84.342  84.90000  ok  1577923200   9558386
# 2  88.602  90.80000  87.384  88.10000  ok  1578009600  17794697
# 3  90.308  90.31200  88.000  88.09400  ok  1578268800  10157499
# 4  93.812  94.32600  90.671  92.28000  ok  1578355200  18209138

# %% [markdown]
# Returns:
# - o - List of open prices for returned candles.
#
# - h - List of high prices for returned candles.
#
# - l - List of low prices for returned candles.
#
# - c - List of close prices for returned candles.
#
# - v - List of volume data for returned candles.
#
# - t - List of timestamp for returned candles.
#
# - s - Status of the response. This field can either be ok or no_data.

# %%
prices_daily['time'] = prices_daily['t'].apply(lambda x: datetime.utcfromtimestamp(x))

prices_daily = prices_daily.set_index('time')

prices_daily.head()
# Out:
#                  c         h       l         o   s           t         v
# time
# 2019-12-31  83.666  84.25800  80.416  81.00006  ok  1577750400  10292456
# 2020-01-02  86.052  86.13914  84.342  84.90000  ok  1577923200   9558386
# 2020-01-03  88.602  90.80000  87.384  88.10000  ok  1578009600  17794697
# 2020-01-06  90.308  90.31200  88.000  88.09400  ok  1578268800  10157499
# 2020-01-07  93.812  94.32600  90.671  92.28000  ok  1578355200  18209138

# %%
plot_fields =  ['c', 'o']

fig = plt.figure(figsize=(16, 5))

plt.plot(prices_daily[plot_fields])
plt.legend(plot_fields)

plt.title("Stock daily price", weight="bold")

plt.show()

# %%
prices_daily = finnhub_client.stock_candles(
    symbol='TSLA', 
    resolution='1', 
    _from=int(time.mktime(start_date.timetuple())), 
    to=int(time.mktime(end_date.timetuple())), 
)

prices_daily = pd.DataFrame(prices_daily)

prices_daily.head()
# Out:
#         c       h       l       o   s           t       v
# 0  584.80  585.25  584.50  585.25  ok  1606856400  471605
# 1  584.69  584.90  584.69  584.90  ok  1606856460    5482
# 2  584.76  584.90  584.00  584.50  ok  1606856520    4026
# 3  585.15  585.15  584.00  584.31  ok  1606856580    7757
# 4  585.20  585.26  585.17  585.17  ok  1606856640  286219

# %%
prices_daily['time'] = prices_daily['t'].apply(lambda x: datetime.utcfromtimestamp(x))

prices_daily = prices_daily.set_index('time')

prices_daily.head()
# Out:
#                           c       h       l       o   s           t       v
# time
# 2020-12-01 21:00:00  584.80  585.25  584.50  585.25  ok  1606856400  471605
# 2020-12-01 21:01:00  584.69  584.90  584.69  584.90  ok  1606856460    5482
# 2020-12-01 21:02:00  584.76  584.90  584.00  584.50  ok  1606856520    4026
# 2020-12-01 21:03:00  585.15  585.15  584.00  584.31  ok  1606856580    7757
# 2020-12-01 21:04:00  585.20  585.26  585.17  585.17  ok  1606856640  286219

# %%
prices_daily.shape
# Out:
# (16217, 7)

# %%
plot_fields =  ['c', 'o']

fig = plt.figure(figsize=(16, 5))

plt.plot(prices_daily[plot_fields])
plt.legend(plot_fields)

plt.title("Stock daily price", weight="bold")

plt.show()

# %%
# Aggregate Indicators
print(finnhub_client.aggregate_indicator('TSLA', 'D'))
# Out:
# {'technicalAnalysis': {'count': {'buy': 7, 'neutral': 9, 'sell': 1}, 'signal': 'buy'}, 'trend': {'adx': 42.18154460092849, 'trending': True}}

# %%
# Basic financials
print(finnhub_client.company_basic_financials('TSLA', 'margin'))
# Out:
# {'metric': {'freeOperatingCashFlow/revenue5Y': -10.34128, 'freeOperatingCashFlow/revenueTTM': 6.48424, 'grossMargin5Y': 18.67445, 'grossMarginAnnual': 16.55546, 'grossMarginTTM': 21.13501, 'netProfitMargin5Y': -7.2878, 'netProfitMarginAnnual': -3.15323, 'netProfitMarginTTM': 2.47729, 'operatingMargin5Y': -5.04491, 'operatingMarginAnnual': -0.28074, 'operatingMarginTTM': 6.31034, 'pretaxMargin5Y': -7.99014, 'pretaxMarginAnnual': -2.70567, 'pretaxMarginTTM': 3.36811}, 'metricType': 'margin', 'symbol': 'TSLA'}

# %%
# Earnings surprises
print(finnhub_client.company_earnings('TSLA', limit=5))
# Out:
# [{'actual': 0.76, 'estimate': 0.6003006, 'period': '2020-09-30', 'symbol': 'TSLA'}, {'actual': 0.436, 'estimate': -0.026703599999999997, 'period': '2020-06-30', 'symbol': 'TSLA'}, {'actual': 0.228, 'estimate': -0.021573, 'period': '2020-03-31', 'symbol': 'TSLA'}, {'actual': 0.412, 'estimate': 0.3516756, 'period': '2019-12-31', 'symbol': 'TSLA'}]

# %%
# Company Executives

news = finnhub_client.company_news('TSLA', _from="2020-06-01", to="2020-06-10")

news[1]
# Out:
# {'category': 'company',
#  'datetime': 1591833600,
#  'headline': "General Motors' Electric Vehicle Unit Hires Former Tesla Head Of Vehicle Safety",
#  'id': 1424308,
#  'image': 'https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/gm_0.jpeg',
#  'related': 'TSLA',
#  'source': 'https://www.benzinga.com',
#  'summary': 'General Motors Company (NYSE: GM) has hired a former Tesla Inc. (NASDAQ: TSLA) engineer, Louise Zhang,\xa0as the new vice president of product safety at Cruise, its self-driving...',
#  'url': 'https://www.benzinga.com/news/20/06/16229122/general-motors-electric-vehicle-unit-hires-former-tesla-head-of-vehicle-safety'}

# %%
print(finnhub_client.company_executive('AAPL'))
# Out:
# ---------------------------------------------------------------------------
# FinnhubAPIException                       Traceback (most recent call last)
# <ipython-input-52-30f190c64c00> in <module>()
# ----> 1 print(finnhub_client.company_executive('AAPL'))
#
# ~\Anaconda3\lib\site-packages\finnhub\client.py in company_executive(self, symbol)
#     106
#     107     def company_executive(self, symbol):
# --> 108         return self._get("/stock/executive", params={"symbol": symbol})
#     109
#     110     def stock_dividends(self, symbol, _from=None, to=None):
#
# ~\Anaconda3\lib\site-packages\finnhub\client.py in _get(self, path, **kwargs)
#      67
#      68     def _get(self, path, **kwargs):
# ---> 69         return self._request("get", path, **kwargs)
#      70
#      71     @property
#
# ~\Anaconda3\lib\site-packages\finnhub\client.py in _request(self, method, path, **kwargs)
#      37
#      38         response = getattr(self._session, method)(uri, **kwargs)
# ---> 39         return self._handle_response(response)
#      40
#      41     @staticmethod
#
# ~\Anaconda3\lib\site-packages\finnhub\client.py in _handle_response(response)
#      42     def _handle_response(response):
#      43         if not response.ok:
# ---> 44             raise FinnhubAPIException(response)
#      45
#      46         try:
#
# FinnhubAPIException: FinnhubAPIException(status_code: 401): You don't have access to this resource.

# %%
news
# Out:
# [{'category': 'company',
#   'datetime': 1591833600,
#   'headline': 'Ford Recalls 2.5M Cars In The US As Faulty Door Latch Can Potentially Cause Injury',
#   'id': 10980366,
#   'image': 'https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/screenshot_2020-06-11_at_07.25.58.png',
#   'related': 'TSLA',
#   'source': 'https://www.benzinga.com',
#   'summary': 'The Ford Motor Company (NYSE: F) on Wednesday announced\xa0it was recalling about 2.5 million vehicles in the United States due to safety lapses.\nWhat Happened\nThe Detroit-based...',
#   'url': 'https://www.benzinga.com/news/20/06/16229631/ford-recalls-2-5m-cars-in-the-us-as-faulty-door-latch-can-potentially-cause-injury'},
#  {'category': 'company',
#   'datetime': 1591833600,
#   'headline': "General Motors' Electric Vehicle Unit Hires Former Tesla Head Of Vehicle Safety",
#   'id': 1424308,
#   'image': 'https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/gm_0.jpeg',
#   'related': 'TSLA',
#   'source': 'https://www.benzinga.com',
#   'summary': 'General Motors Company (NYSE: GM) has hired a former Tesla Inc. (NASDAQ: TSLA) engineer, Louise Zhang,\xa0as the new vice president of product safety at Cruise, its self-driving...',
#   'url': 'https://www.benzinga.com/news/20/06/16229122/general-motors-electric-vehicle-unit-hires-former-tesla-head-of-vehicle-safety'},
#  {'category': 'company',
#   'datetime': 1591833600,
#   'headline': '¿Cuánto más pueden subir las acciones de Tesla?',
#   'id': 1401701,
#   'image': 'https://i-invdn-com.akamaized.net/redesign/images/seo/v2/investingcom_analysis_og.jpg',
#   'related': 'TSLA',
#   'source': 'https://es.investing.com',
#   'summary': 'Análisis de Acciones por Investing.com (Haris Anwar/Investing.com) cubriendo: Bank of America Corp, Tesla Inc, Volkswagen AG VZO O.N.. Lea los Análisis de Acciones de Investing.com (Haris Anwar/Investing.com) en Investing.com.',
#   'url': 'https://es.investing.com/analysis/cuanto-mas-pueden-subir-las-acciones-de-tesla-200436617'},
#  {'category': 'company',
#   'datetime': 1591833600,
#   'headline': '6 Stocks And Targets To Watch',
#   'id': 756847,
#   'image': 'https://i-invdn-com.akamaized.net/redesign/images/seo/v2/investingcom_analysis_og.jpg',
#   'related': 'TSLA',
#   'source': 'investing',
#   'summary': "Stocks Analysis by Harry Boxer covering: SPDR S&P 500, Ballard Power Systems Inc, Tesla Inc, Riot Blockchain Inc. Read Harry Boxer's latest article on Investing.com",
#   'url': 'https://www.investing.com/analysis/be-cldx-dyai-ostk-paas-wrtc--stock-charts-to-watch-200527384'},
#  {'category': 'company',
#   'datetime': 1591833022,
#   'headline': 'Tesla officially begins Model Y international deliveries, starting with Canada',
#   'id': 756325,
#   'image': 'https://www.teslarati.com/wp-content/uploads/2020/06/Tesla-model-y-delivery-canada-vancouver.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.teslarati.com',
#   'summary': 'Tesla officially began its first Model Y international deliveries on Tuesday, with customers in Vancouver, British Columbia showcasing their newest all-electric crossover on social media. “Some really exciting news this morning. As you may have heard through the grapevine, Model Y deliveries are beginning in Vancouver this month (June), and I am happy to confirm …',
#   'url': 'https://www.teslarati.com/tesla-model-y-canada-deliveries/'},
#  {'category': 'company',
#   'datetime': 1591827854,
#   'headline': 'Asia stocks to slip; dollar declines on Powell',
#   'id': 1434213,
#   'image': 'https://assets.theedgemarkets.com/Market-Preview_20200611092339_theedgemarkets.jpg?null',
#   'related': 'TSLA',
#   'source': 'https://www.theedgemarkets.com',
#   'summary': '(June 11): Stocks in Asia looked set to drop as investors assessed the Federal Reserve’s forecast of a long road to recovery for the economy and loose monetary policy. Treasuries rose and the dollar extended this month’s slide.',
#   'url': 'https://www.theedgemarkets.com/article/asia-stocks-slip-dollar-declines-powell'},
#  {'category': 'company news',
#   'datetime': 1591827685,
#   'headline': 'Tesla Soars Past $1,000 After Musk Seizes on Nikola’s Hype',
#   'id': 1374914,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/5_YcUaPS7I.wIAHUoe8nOA--~B/aD03MjA7dz0xMjgwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/hd/cp-video-transcode/prod/2020-06/10/5ee160a792fc2851a333fe39/5ee160a792fc2851a333fe3a_o_U_v2.jpg',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Jun.10 -- Elon Musk, chief executive officer of Tesla, Inc., sent an email to employees before the market opened Wednesday declaring that it is “time to go all out” and put Tesla’s zero-emission semi trucks into production. Markets reacted with the stock past $1000 per share on Wedensday. Dan Ives, analyst at Wedbush, discusses on "Bloomberg Technology."',
#   'url': 'https://finance.yahoo.com/video/tesla-soars-past-1-000-222125332.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591827611,
#   'headline': "Stock market news live updates: Stock futures flat after Fed decision, Nasdaq's record high",
#   'id': 1374601,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/tASpYR.NlQO00P.WLjMYHQ--~B/aD0yOTQ0O3c9NDQxNjtzbT0xO2FwcGlkPXl0YWNoeW9u/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-images/2020-03/f5f48420-734d-11ea-afee-643b721c0cdd',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Stock futures were little changed Wednesday evening following the Federal Reserve’s monetary policy decision, in which policymakers projected interest rates would remain near zero through 2022 and telegraphed that the central bank’s pace of asset purchases would remain at minimum at the current rate.',
#   'url': 'https://finance.yahoo.com/news/stock-market-news-live-june-11-2020-222011316.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591825831,
#   'headline': 'Tesla stock tops $1,000',
#   'id': 1374915,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/ihLGa4z8IpPZR77mSwulNQ--~B/aD01NzU7dz0xMDI0O3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/hd/cp-video-transcode/prod/2020-06/10/5ee155a86ca6be5a883b84ed/5ee155a86ca6be5a883b84ee_o_U_v2.jpg',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': "Yahoo Finance's Rick Newman joins The Final Round to discuss the surge Tesla stock saw today as well as the news that Elon Musk plans to accelerate production of the Tesla Semi.",
#   'url': 'https://finance.yahoo.com/video/tesla-stock-tops-1-000-215031456.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591825560,
#   'headline': 'Tesla shares bust $1 000 barrier for the first time',
#   'id': 1424837,
#   'image': 'https://image-prod.iol.co.za/resize/800x366?source=https://cdn.africannewsagency.com/public/ana/media/web/photoimages_new/2019/03/15/e15343db86fa80a8f004b3872145d09e.jpg&operation=CROP&offset=0x84&resize=800x450',
#   'related': 'TSLA',
#   'source': 'https://www.iol.co.za',
#   'summary': 'Tesla’s highly anticipated “Battery Day” will provide the next setting for chief executive Elon Musk to announce a number of new potential developments.',
#   'url': 'https://www.iol.co.za/business-report/international/tesla-shares-bust-1-000-barrier-for-the-first-time-49240210'},
#  {'category': 'company',
#   'datetime': 1591824356,
#   'headline': 'Tesla shares surge past $1,000 as Musk revs up the Semi',
#   'id': 1424929,
#   'image': 'https://s2.reutersmedia.net/resources/r/?m=02&d=20200610&t=2&i=1521776106&w=1200&r=LYNXMPEG591ED',
#   'related': 'TSLA',
#   'source': 'https://in.reuters.com',
#   'summary': 'Tesla Inc\'s stock jumped above $1,000 a share on Wednesday after Chief Executive Elon Musk told his staff it was time to bring the Tesla Semi commercial truck to "volume production."',
#   'url': 'https://in.reuters.com/article/us-tesla-truck/tesla-shares-surge-past-1000-as-musk-revs-up-the-semi-idINKBN23H1PE'},
#  {'category': 'company',
#   'datetime': 1591824356,
#   'headline': 'Tesla shares surge past $1,000 as Musk revs up the Semi',
#   'id': 1424928,
#   'image': 'https://s2.reutersmedia.net/resources/r/?m=02&d=20200610&t=2&i=1521776106&w=1200&r=LYNXMPEG591ED',
#   'related': 'TSLA',
#   'source': 'https://www.reuters.com',
#   'summary': 'Tesla Inc\'s stock jumped above $1,000 a share on Wednesday after Chief Executive Elon Musk told his staff it was time to bring the Tesla Semi commercial truck to "volume production."',
#   'url': 'https://www.reuters.com/article/us-tesla-truck/tesla-shares-surge-past-1000-as-musk-revs-up-the-semi-idUSKBN23H1PE'},
#  {'category': 'company news',
#   'datetime': 1591822080,
#   'headline': 'Nasdaq Tops 10,000 on Tesla Surge; Starbucks Cools Off',
#   'id': 1374815,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/eaPx1np_EpRxPk5.E6G61w--~B/aD05NTE7dz0xNDAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/motleyfool.com/166f57f814409851f05ad471036e7907',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'The Nasdaq Composite (NASDAQINDEX: ^IXIC) had another great day, rising almost 1% and closing above 10,000 for the first time in its history.  The Nasdaq 100 index did even better, gaining almost 1.5% and also climbing over the 10,000 hurdle.  Leading the Nasdaq higher on its historic day was Tesla (NASDAQ: TSLA), which celebrated a share-price milestone of its own.',
#   'url': 'https://finance.yahoo.com/m/d8c510c9-bcc8-3ade-8a8c-a9bd7b4ebe72/nasdaq-tops-10%2C000-on-tesla.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591822021,
#   'headline': 'Tesla shares surge past $US1000 as Elon Musk revs up Semi truck',
#   'id': 1425093,
#   'image': 'https://static.ffx.io/images/$zoom_0.53%2C$multiply_0.7554%2C$ratio_1.777778%2C$width_1059%2C$x_0%2C$y_0/t_crop_custom/e_sharpen:25%2Cq_85%2Cf_auto/69b9fe0b2dae5d2aa94f0a4e949f9c020381c427',
#   'related': 'TSLA',
#   'source': 'https://www.afr.com',
#   'summary': "The Tesla CEO's message to staff about bringing the truck to 'volume production' coincided with a surge in the share price of rival clean truck maker Nikola.",
#   'url': 'https://www.afr.com/markets/equity-markets/tesla-shares-surge-past-us1000-as-elon-musk-revs-up-semi-truck-20200611-p551gx'},
#  {'category': 'company',
#   'datetime': 1591821970,
#   'headline': 'Nikola in talks with automakers for Badger pickup truck production: founder | MarketScreener',
#   'id': 15198989,
#   'image': 'https://img.zonebourse.com/reuters/2020-06-10T204610Z_1_LYNXMPEG5924D_RTROPTP_3_CNH-INDUSTRIAL-NIKOLA.JPG',
#   'related': 'TSLA',
#   'source': 'https://www.marketscreener.com',
#   'summary': '',
#   'url': 'https://www.marketscreener.com/TESLA-INC-6344549/news/Nikola-in-talks-with-automakers-for-Badger-pickup-truck-production-founder-30753510/'},
#  {'category': 'company news',
#   'datetime': 1591821671,
#   'headline': 'Nikola in talks with automakers for Badger pickup truck production -founder',
#   'id': 1374918,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Nikola Corp, a maker of hydrogen-fueled vehicles, is in the process of picking a partner to produce its Badger pickup truck, while also aiming to start deliveries of its electric commercial big rigs next year, founder Trevor Milton said on Wednesday.  Nikola shares have nearly doubled since their debut on the Nasdaq last week, getting a bump on Monday after Milton tweeted that the company would open reservations for Badger on June 29.  "There are three (automakers) in the running right now for a joint venture on Badger, and we will announce who that is in the next few months," Milton, who is also the company\'s executive chairman, told Reuters.',
#   'url': 'https://finance.yahoo.com/news/nikola-talks-automakers-badger-pickup-204111004.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591821000,
#   'headline': 'China Launches Bold New Electric Vehicle Credit Scheme',
#   'id': 1374919,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Once again propelling itself ahead in global electric vehicle markets, Beijing has just rolled out a new credit scheme that will essentially pay citizens to make the switch to EVs',
#   'url': 'https://finance.yahoo.com/news/china-launches-bold-electric-vehicle-203000736.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591820815,
#   'headline': 'Dow Jones Tumbles 300 Points After Fed, But Nasdaq Notches New High Again',
#   'id': 1374604,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/Fxg63HIIgAv_Z.4OUuVTag--~B/aD01NjM7dz0xMDAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/ab279b0a3e232f724c1eb2b66f3ad88e',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': "The Dow Jones Industrial Average briefly rallied after the Federal Reserve signaled it\xa0won't raise interest rates\xa0before 2023.",
#   'url': 'https://finance.yahoo.com/m/d8357eb7-3609-3c96-a907-065214cf4a3e/dow-jones-tumbles-300-points.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591820076,
#   'headline': 'Tesla Stock Hits Record As Report Suggests Big-Rig Truck Push',
#   'id': 1374920,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/qR943LYcI1YDjpDMRlYuPw--~B/aD01NjM7dz0xMDAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/11067e0cee5c6020967211eff36e83cc',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Tesla stock hit a new high, as positive sentiments about the company builds and as a report said CEO Elon Musk wants to bring production of its big-rig truck to “volume production.”',
#   'url': 'https://finance.yahoo.com/m/64d59f97-bcfd-37a0-a573-2e322647498f/tesla-stock-hits-record-as.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591819744,
#   'headline': 'Dow ends 282 points lower, but Nasdaq logs 3rd straight record and first finish at 10,000 as Fed signals zero rates through 2022',
#   'id': 754759,
#   'image': 'https://s.wsj.net/public/resources/MWimages/MW-GP644_MicroS_ZG_20180906154215.jpg',
#   'related': 'TSLA',
#   'source': 'marketwatch',
#   'summary': 'U.S. stock benchmarks closed mostly lower Wednesday, but large-capitalization companies saw powerful gains, after the Federal Reserve projected no...',
#   'url': 'https://www.marketwatch.com/story/dow-ends-282-points-lower-but-nasdaq-logs-3rd-straight-record-and-first-finish-at-10000-as-fed-signals-zero-rates-through-2022-2020-06-10'},
#  {'category': 'company news',
#   'datetime': 1591819020,
#   'headline': "Tesla Loses Top Exec Who Led the Company's Chinese Expansion",
#   'id': 1374921,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/g6UHqXRXlFi2HTZuIXKIFQ--~B/aD02MDc7dz0xNDAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/motleyfool.com/2a19c22c42e4fcf84f40439a5a32d2df',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': "Late Tuesday evening, Tesla's (NASDAQ: TSLA) Vice President of Business Development Robin Ren updated his LinkedIn profile, listing June 2020 as the end date of his position at the electric carmaker.  The move confirmed rumors that Ren had become the latest top executive to leave Tesla.  Ren had been with Tesla since 2015, first as Vice President of Asia Pacific.",
#   'url': 'https://finance.yahoo.com/m/da4ef5e9-da09-3f73-8291-5dc14057d062/tesla-loses-top-exec-who-led.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591818081,
#   'headline': "Tesla shares rocket as Elon Musk says Semi truck is ready for 'volume production'",
#   'id': 1675127,
#   'image': 'https://static.ffx.io/images/$zoom_0.53%2C$multiply_0.7554%2C$ratio_1.777778%2C$width_1059%2C$x_0%2C$y_0/t_crop_custom/q_86%2Cf_auto/69b9fe0b2dae5d2aa94f0a4e949f9c020381c427',
#   'related': 'TSLA',
#   'source': 'https://www.smh.com.au',
#   'summary': 'Tesla shares jump over $US1000 after an email to staff was leaked, making the company the second-most valuable carmaker in the world.',
#   'url': 'https://www.smh.com.au/business/companies/elon-musk-says-tesla-semi-truck-is-ready-for-volume-production-20200611-p551gd.html'},
#  {'category': 'company',
#   'datetime': 1591818081,
#   'headline': "Tesla shares rocket as Elon Musk says Semi truck is ready for 'volume production'",
#   'id': 1401994,
#   'image': 'https://static.ffx.io/images/$zoom_0.53%2C$multiply_0.7554%2C$ratio_1.777778%2C$width_1059%2C$x_0%2C$y_0/t_crop_custom/q_86%2Cf_auto/69b9fe0b2dae5d2aa94f0a4e949f9c020381c427',
#   'related': 'TSLA',
#   'source': 'https://www.theage.com.au',
#   'summary': 'Tesla shares jump over $US1000 after an email to staff was leaked, making the company the second-most valuable carmaker in the world.',
#   'url': 'https://www.theage.com.au/business/companies/elon-musk-says-tesla-semi-truck-is-ready-for-volume-production-20200611-p551gd.html'},
#  {'category': 'company news',
#   'datetime': 1591816121,
#   'headline': "Musk: It's Time For Tesla Semi To Get On The Road",
#   'id': 1374922,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/GIiuLmtG11sC4tcNmIyRKg--~B/aD00MDA7dz02MDA7c209MTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/Benzinga/94b2d3d80f329ec2da6920a83dfcb895',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'The oft-delayed Tesla Motors Inc (NASDAQ: TSLA) battery-powered semi-truck is in the news again following a leaked internal memo from CEO Elon Musk saying the company needs to go "all out" to get the truck on the road.The memo, first reported Wednesday by Reuters, doesn\'t give a production date. The current expectation is 2021 after launch delays in 2019 and this year. Limited production is expected this year, Musk said on Tesla\'s first-quarter earnings call."It\'s time to go all out and bring the Tesla Semi to volume production," the memo said. "It\'s been in limited production so far, which has allowed us to improve many aspects of the design. Production of the battery and powertrain would take place at Giga Nevada, with most of the other work probably occurring in other states."Timing coincidence? The timing of the memo coincides with buzz surrounding startup Nikola Corp. (NASDAQ: NKLA), which began public trading June 4 and has seen a runup in its stock price despite extreme volatility. Meanwhile, Tesla shares traded above $1,000 for the first time on Wednesday.Nikola has a manufacturing joint venture with IVECO to produce its heavy-duty Tre battery-electric day cab in Ulm, Germany in mid-2021. The company is best known for its Class 8 hydrogen-powered fuel cell trucks planned for production in a new plant south of Phoenix, Arizona, in 2023.Musk is a critic of fuel cells for long-haul trucking, calling them "fool cells."\xa0In another coincidence, Nikola announced Wednesday that former Tesla director of manufacturing, Mark Duchesne, would be its new global head of manufacturing. Duchesne worked at Tesla from 2012 to 2016.Skeptics to supporters While major truck makers for years questioned the viability of the technology, industry leader Daimler Trucks this week formed a fuel cell truck subsidiary.\xa0Daimler Truck Fuel Cell GmbH & Co. KG precedes a joint venture with Sweden\'s Volvo Group to mass produce fuel cell trucks and stationary fuel cells as emergency backup power for data centers.As recently as April 2019, Daimler Trucks North America CEO Roger Nielsen said he can "see a glimpse of fuel cells on the horizon. But it will not be this generation of engineers who will be delivering it."Tesla and Nikola have some of the same customers, including Anheuser-Busch (NYSE: BUD), which has ordered 40 Tesla semis and up to 800 Nikola fuel cell trucks. The beverage maker is focused on the zero-emissions promise of electric trucking rather than whether it is fueled by hydrogen or batteries.Working with electric truck rival BYD, Nikola made an emissions-free delivery of beer to the home of the St. Louis Blues hockey team in November 2019. Getting hydrogen stations ready for routes regularly traveled by Anheuser-Busch is a priority after launching its battery-electric trucks in Europe, Nikola Executive Chairman Trevor Milton told FreightWaves.PepsiCo (NASDAQ: PEP) plans to introduce 15 Tesla Semi electric trucks at its Frito-Lay manufacturing site in Modesto, California in 2021.Click for more FreightWaves articles by Alan AdlerPhoto: TeslaSee more from Benzinga * Today\'s Pickup: Saudi Arabia And Russia Push For Extending Oil Output Cuts * Today\'s Pickup: Ford Reopens Two Facilities, Twice In The Same Week Over COVID-19 Scare * Wallbox, A Company Founded By Former Tesla Employees, Closes M Seed Round(C) 2020 Benzinga.com. Benzinga does not provide investment advice. All rights reserved.',
#   'url': 'https://finance.yahoo.com/news/musk-time-tesla-semi-road-190841454.html?.tsrc=rss'},
#  {'category': '',
#   'datetime': 1591816089,
#   'headline': "'Tesla factory workplace safety is 5% better than industry average for manufacturers & improving fast' -Tweet From Tesla's Elon Musk",
#   'id': 32852616,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16225621/tesla-factory-workplace-safety-is-5-better-than-industry-average-for-manufacturers-improving-fast-tw'},
#  {'category': 'company news',
#   'datetime': 1591812900,
#   'headline': 'Stock Market Today With Jim Cramer: Buy Tesla Shares',
#   'id': 1374923,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Jim Cramer discusses the stock market today including buying Tesla shares, buying Chewy stock after earnings and picking stocks in the Nasdaq or S&P; 500.',
#   'url': 'https://finance.yahoo.com/m/afb0be20-6760-368f-8d30-2bee278e4e99/stock-market-today-with-jim.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591812327,
#   'headline': 'TSLA Above $1K, Tesla Stock Price to Hit $3K in 5 Years, Says Baron',
#   'id': 2789769,
#   'image': 'https://www.coinspeaker.com/wp-content/uploads/2020/06/tesla-stock-price-hit-3000-baron.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.coinspeaker.com',
#   'summary': 'Ronald Stephen Baron believes there is more room for Tesla (TSLA) stock price to rise in the next few years.',
#   'url': 'https://www.coinspeaker.com/tesla-stock-price-hit-3000-baron/'},
#  {'category': 'company',
#   'datetime': 1591810382,
#   'headline': 'Volkswagen Delays Key Electric Car Launch Amid Software Troubles | MarketScreener',
#   'id': 1425874,
#   'image': 'https://www.marketscreener.com/images/twitter_MS_fdgris.png',
#   'related': 'TSLA',
#   'source': 'https://www.marketscreener.com',
#   'summary': '',
#   'url': 'https://www.marketscreener.com/VOLKSWAGEN-AG-436737/news/Volkswagen-Delays-Key-Electric-Car-Launch-Amid-Software-Troubles-30752871/'},
#  {'category': 'company',
#   'datetime': 1591810085,
#   'headline': 'Cadillac Super Cruise vs. Tesla Autopilot | Digital Trends',
#   'id': 1425897,
#   'image': 'https://icdn3.digitaltrends.com/image/digitaltrends/the-2021-escalade-enters-the-future-of-mobility-as-the-first-full-size-suv-with-super-cruise-the-industrys-best-driver-assistance-technology-no-other-luxury-suv-offers-a-comparable-system-1200x630-c-ar1.91.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.digitaltrends.com',
#   'summary': "Cadillac Super Cruise and Tesla Autopilot are two of the partially automated systems available in 2020. Here's how they're similar, and where they're different.",
#   'url': 'https://www.digitaltrends.com/cars/cadillac-super-cruise-versus-tesla-autopilot/'},
#  {'category': 'company news',
#   'datetime': 1591809800,
#   'headline': 'Dow Jones Tumbles 300 Points Ahead Of Fed Meeting, As Boeing Dives; Tesla Surges 8% On Semi News',
#   'id': 1374694,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/IYpRREJxRwJ_VTdIapwU4Q--~B/aD01NjM7dz0xMDAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/3cc16c8ca552c67f3c8ac166f13da3ce',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'The major stock indexes were mixed Wednesday, as the Nasdaq jumped above 10,000. Apple and Tesla advanced to record highs.',
#   'url': 'https://finance.yahoo.com/m/c7fb1939-fcfa-32f5-8572-240ebb6adfd0/dow-jones-tumbles-300-points.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591808580,
#   'headline': 'Tesla Shares Soar Past $1,000 on Elon Musk’s Plan to Move Forward With Semi Truck',
#   'id': 754167,
#   'image': 'https://images.wsj.net/im-196813/social',
#   'related': 'TSLA',
#   'source': 'wsj',
#   'summary': 'Tesla investors pushed the auto maker’s stock to more than $1,000 a share, lifting its valuation nearer to Toyota’s, after Elon Musk told employees it was time to begin volume production of the company’s long-promised, all-electric semitrailer truck.',
#   'url': 'https://www.wsj.com/articles/tesla-shares-soar-past-1-000-on-elon-musks-plan-to-move-forward-with-semi-truck-11591808585'},
#  {'category': '',
#   'datetime': 1591807318,
#   'headline': "'Tesla hacker unlocks Performance upgrade and acceleration boost at a discount' -Elektrek Report",
#   'id': 32852617,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16224205/tesla-hacker-unlocks-performance-upgrade-and-acceleration-boost-at-a-discount-elektrek-report'},
#  {'category': 'company',
#   'datetime': 1591807260,
#   'headline': 'Tesla hacker unlocks Performance upgrade and acceleration boost at a discount - Electrek',
#   'id': 1402259,
#   'image': 'https://electrek.co/wp-content/uploads/sites/3/2020/03/Tesla-Track-Mode-V2-hero.jpg?resize=1024,493',
#   'related': 'TSLA',
#   'source': 'https://electrek.co',
#   'summary': 'It was bound to happen at some point and it finally did. A company hacked Tesla’s software and it is now offering some of its performance upgrades at a discount. For a few years now, Tesla started selling vehicles with upgradable software-locked capabilities, like 75 kWh battery pack software-locked at 60 kWh or higher power …',
#   'url': 'https://electrek.co/2020/06/10/tesla-hacker-unlocks-performance-upgrade-acceleration-boost/'},
#  {'category': 'company',
#   'datetime': 1591805730,
#   'headline': 'VW’s bid to challenge Tesla starts with software patch',
#   'id': 1426282,
#   'image': 'https://assets.theedgemarkets.com/362599207.jpg?null',
#   'related': 'TSLA',
#   'source': 'https://www.theedgemarkets.com',
#   'summary': 'Volkswagen AG (VW) will narrowly meet an end-of-summer deadline to start deliveries of its flagship ID.3 electric car, but early buyers will have to wait months for all the features to work. Two software functions in the first vehicles delivered in September will be activated only through an update in early 2021, VW said today in a statement. Customers willing to wait for delivery until the fourth quarter will have full functionality right from the start.',
#   'url': 'https://www.theedgemarkets.com/article/vws-bid-challenge-tesla-starts-software-patch'},
#  {'category': 'company',
#   'datetime': 1591804887,
#   'headline': 'Tesla Rival Nikola (NKLA) Stock Down 12% after 104% Up on Monday',
#   'id': 1692793,
#   'image': 'https://www.coinspeaker.com/wp-content/uploads/2020/06/nikola-stock-skyrocketing-monday.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.coinspeaker.com',
#   'summary': 'Nikola Corporation (NKLA) stock is down today. Chairman Trevor Milton has indicated a launch date for their Badger truck.',
#   'url': 'https://www.coinspeaker.com/nikola-stock-skyrocketing-monday/'},
#  {'category': 'company',
#   'datetime': 1591804500,
#   'headline': 'Tesla stock surges past $1,000 amid Elon Musk’s push for Tesla Semi',
#   'id': 754014,
#   'image': 'https://s.marketwatch.com/public/resources/images/MW-II311_tesla__ZH_20200610113846.jpg',
#   'related': 'TSLA',
#   'source': 'marketwatch',
#   'summary': 'Shares of Tesla Inc. rally after Chief Executive Elon Musk urges the company “to go all out” on the production of the Tesla Semi, its electric freight truck,...',
#   'url': 'https://www.marketwatch.com/story/tesla-stock-surges-past-1000-amid-elon-musks-push-for-tesla-semi-2020-06-10'},
#  {'category': 'company',
#   'datetime': 1591804387,
#   'headline': 'Tesla shares soar past US$1,000 after Musk seizes on Nikola hype - BNN Bloomberg',
#   'id': 1426459,
#   'image': 'http://www.bnnbloomberg.ca/polopoly_fs/1.1448386!/fileimage/httpImage/image.jpg_gen/derivatives/landscape_620/elon-musk-photographer-andrew-harrer-bloomberg.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.bnnbloomberg.ca',
#   'summary': 'Elon Musk wasn’t about to let a revenue-less manufacturer of zero-emission semi trucks steal the spotlight from Tesla Inc.',
#   'url': 'https://www.bnnbloomberg.ca/tesla-shares-soar-past-us-1-000-after-musk-seizes-on-nikola-hype-1.1448385'},
#  {'category': 'company',
#   'datetime': 1591803720,
#   'headline': 'Tesla shares surge past $1,000 for first time as Musk revs up the Semi',
#   'id': 2959462,
#   'image': 'https://images.livemint.com/img/2020/06/10/600x338/2020-06-05T000737Z_2_LYNXMPEG53274_RTROPTP_3_HEALTH-CORONAVIRUS-TESLA_1591803608207_1591803623178.JPG',
#   'related': 'TSLA',
#   'source': 'https://www.livemint.com',
#   'summary': "Musk on Wednesday tweeted 'Yes' to a question on Twitter about whether the report of the leaked Semi truck production email was accurate",
#   'url': 'https://www.livemint.com/news/world/tesla-shares-surge-past-1-000-for-first-time-as-musk-revs-up-the-semi-11591803528232.html'},
#  {'category': 'company',
#   'datetime': 1591803660,
#   'headline': 'Coronavirus update: Global death toll passes 412,000, as Dr. Fauci warns that COVID-19 is far from over',
#   'id': 753985,
#   'image': 'https://s.marketwatch.com/public/resources/images/MW-II312_Corona_ZG_20200610113907.jpg',
#   'related': 'TSLA',
#   'source': 'marketwatch',
#   'summary': 'The coronavirus pandemic that has cost more than 412,000 lives globally took just one month to span the globe and is still far from over, even as countries...',
#   'url': 'https://www.marketwatch.com/story/coronavirus-update-global-death-toll-passes-412000-as-dr-fauci-warns-that-covid-19-is-far-from-over-2020-06-10'},
#  {'category': '',
#   'datetime': 1591803198,
#   'headline': 'GM On Track To Spend $20B On EV And AV Development By 2025',
#   'id': 32153871,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16223414/gm-on-track-to-spend-20b-on-ev-and-av-development-by-2025'},
#  {'category': 'company',
#   'datetime': 1591803094,
#   'headline': 'Tesla shares surge past $1,000 as Musk revs up the Semi | MarketScreener',
#   'id': 15199073,
#   'image': 'https://img.zonebourse.com/reuters/2020-06-10T114018Z_1_LYNXMPEG59144_RTROPTP_3_LATVIA-AUTOS-ELECTRIC.JPG',
#   'related': 'TSLA',
#   'source': 'https://www.marketscreener.com',
#   'summary': '',
#   'url': 'https://www.marketscreener.com/NIKOLA-44211889/news/Tesla-shares-surge-past-1-000-as-Musk-revs-up-the-Semi-30750629/'},
#  {'category': 'company',
#   'datetime': 1591802855,
#   'headline': 'Tesla shares surge past $1,000 as Musk revs up the Semi | MarketScreener',
#   'id': 15199074,
#   'image': 'https://img.zonebourse.com/reuters/2020-06-10T141617Z_2_LYNXMPEG591ED-OCABS_RTROPTP_3_CBUSINESS-US-TESLA-TRUCK.JPG',
#   'related': 'TSLA',
#   'source': 'https://www.marketscreener.com',
#   'summary': '',
#   'url': 'https://www.marketscreener.com/TESLA-INC-6344549/news/Tesla-shares-surge-past-1-000-as-Musk-revs-up-the-Semi-30751734/'},
#  {'category': 'company',
#   'datetime': 1591802381,
#   'headline': 'Bill Gates among big winners with Vroom doubling in debut',
#   'id': 1426633,
#   'image': 'https://assets.theedgemarkets.com/Bill Gates.jpg?null',
#   'related': 'TSLA',
#   'source': 'https://www.theedgemarkets.com',
#   'summary': 'Bill Gates, already the world’s second-richest person, got an added boost as his investment in used-car platform Vroom Inc more than doubled on the company’s first day of trading.',
#   'url': 'https://www.theedgemarkets.com/article/bill-gates-among-big-winners-vroom-doubling-debut'},
#  {'category': 'company',
#   'datetime': 1591801647,
#   'headline': 'Tesla shares top US$1,000 for the first time',
#   'id': 1426746,
#   'image': 'https://assets.theedgemarkets.com/Tesla Model 3_0.JPG?null',
#   'related': 'TSLA',
#   'source': 'https://www.theedgemarkets.com',
#   'summary': 'Tesla Inc shares eclipsed US$1,000 (RM4,275.50) for the first time ever today as ramping demand for the company’s Model 3 in China led Wedbush analysts to tout the “massive”’ market opportunity and its ongoing battery efforts.',
#   'url': 'https://www.theedgemarkets.com/article/tesla-shares-top-us1000-first-time'},
#  {'category': 'company',
#   'datetime': 1591801540,
#   'headline': 'Guatemala says returns of its nationals restarting from U.S.',
#   'id': 15783033,
#   'image': 'https://www.devdiscourse.com/remote.axd?https://devdiscourse.blob.core.windows.net/devnews/09_06_2020_10_07_07_5886454.jpg?width=920&format=jpeg',
#   'related': 'TSLA',
#   'source': 'https://www.devdiscourse.com',
#   'summary': 'Read more about Guatemala says returns of its nationals restarting from U.S. on Devdiscourse',
#   'url': 'https://www.devdiscourse.com/article/international/1087028-guatemala-says-returns-of-its-nationals-restarting-from-us'},
#  {'category': 'company',
#   'datetime': 1591801247,
#   'headline': 'The challenges of revamping public transport after COVID-19 safely',
#   'id': 15866578,
#   'image': 'https://img-cdn.tnwcdn.com/image/tnw?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2020%2F06%2FCopy-of-Copy-of-Copy-of-Copy-of-Copy-of-Copy-of-...-5-1.png&signature=f5058f24a9064cc6a82415671ed1e34b',
#   'related': 'TSLA',
#   'source': 'https://thenextweb.com',
#   'summary': 'This article was originally published by Sarah Wray on Cities Today, the leading news platform on urban mobility and innovation, reaching an international audience of city leaders. For the latest updates follow Cities Today on Twitter, Facebook, LinkedIn, Instagram, and YouTube, or sign up for Cities Today News. The coronavirus pandemic has forced mobility leaders …',
#   'url': 'https://thenextweb.com/shift/2020/06/10/the-challenges-of-revamping-public-transport-after-covid-19-safely-syndication/'},
#  {'category': 'company',
#   'datetime': 1591801080,
#   'headline': 'Why Tesla Stock Jumped on Wednesday, Crossing $1,000 for the First Time | The Motley Fool',
#   'id': 1426860,
#   'image': 'https://g.foolcdn.com/editorial/images/578165/why-tesla-stock-jumped-on-wednesday.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.fool.com',
#   'summary': "The stock is up nearly 400% in just 12 months. Here's why investors are so bullish.",
#   'url': 'https://www.fool.com/investing/2020/06/10/why-tesla-stock-jumped-on-wednesday-crossing-1000.aspx'},
#  {'category': 'company',
#   'datetime': 1591798804,
#   'headline': 'Tesla shares\xa0just went over\xa0$1,000 for the first time ever',
#   'id': 1429561,
#   'image': 'https://financialpostcom.files.wordpress.com/2020/06/tesla-1.jpg',
#   'related': 'TSLA',
#   'source': 'https://business.financialpost.com',
#   'summary': 'Tesla shares have nearly quintupled in the past year as its market value ballooned to US$185 billion',
#   'url': 'https://business.financialpost.com/investing/tesla-shares-just-went-over-1000-for-the-first-time-ever'},
#  {'category': '',
#   'datetime': 1591797534,
#   'headline': 'Tesla Shares Mark Session And New All-Time High At $1,000',
#   'id': 32852620,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/hot/20/06/16221958/tesla-shares-mark-session-and-new-all-time-high-at-1-000'},
#  {'category': 'company',
#   'datetime': 1591796219,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Lazydays Holdings, Tellurian, Cardiovascular Systems',
#   'id': 61109108,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?16821921',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com/articles/buzz-u.s.-stocks-on-the-move-lazydays-holdings-tellurian-cardiovascular-systems-2020-06-10'},
#  {'category': 'company news',
#   'datetime': 1591796219,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Lazydays Holdings, Tellurian, Cardiovascular Systems',
#   'id': 59581000,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?442225655',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com//articles/buzz-u.s.-stocks-on-the-move-lazydays-holdings-tellurian-cardiovascular-systems-2020-06-10'},
#  {'category': 'company',
#   'datetime': 1591796168,
#   'headline': 'Bourse de Wall Street : Les valeurs à suivre à Wall Street',
#   'id': 1642869,
#   'image': 'https://img.zonebourse.com/reuters/2016-09-29T200821Z_1_LYNXNPEC8S1L6_RTROPTP_2_USA.JPG',
#   'related': 'TSLA',
#   'source': 'https://www.zonebourse.com',
#   'summary': '',
#   'url': 'https://www.zonebourse.com/actualite-bourse/Les-valeurs-a-suivre-a-Wall-Street--30751709/'},
#  {'category': 'company',
#   'datetime': 1591794487,
#   'headline': 'Bill Gates among biggest winners with Vroom doubling in debut - BNN Bloomberg',
#   'id': 7359255,
#   'image': 'http://www.bnnbloomberg.ca/polopoly_fs/1.1427835!/fileimage/httpImage/image.jpg_gen/derivatives/landscape_620/bill-gates-co-chair-of-the-bill-and-melinda-gates-foundation-speaks-during-the-bloomberg-new-economy-forum-in-beijing-china-on-thursday-nov-21-2019-the-new-economy-forum-organized-by-bloomberg-media-group-a-division-of-bloomberg-lp-aims-to-bring-together-leaders-from-public-and-private-sectors-to-find-solutions-to-the-world-s-greatest-challenges-photographer-takaaki-iwabu-bloomberg.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.bnnbloomberg.ca',
#   'summary': 'Bill Gates, already the world’s second-richest person, got an added boost Tuesday as his investment in used-car platform Vroom Inc. more than doubled on the company’s first day of trading.',
#   'url': 'https://www.bnnbloomberg.ca/bill-gates-among-biggest-winners-with-vroom-doubling-in-debut-1.1448276'},
#  {'category': 'company',
#   'datetime': 1591793265,
#   'headline': "Musk memo calls on Tesla to begin 'all out' volume production of Semi",
#   'id': 753634,
#   'image': 'https://image.cnbcfm.com/api/v1/image/104849853-GettyImages-875152628.jpg?v=1591795003',
#   'related': 'TSLA',
#   'source': 'cnbc',
#   'summary': 'Tesla CEO Elon Musk said it\'s time to bring its Semi commercial truck to "volume production," according to a memo obtained by CNBC.',
#   'url': 'https://www.cnbc.com/2020/06/10/tesla-to-start-volume-production-of-semi-trucks-according-to-memo.html'},
#  {'category': '',
#   'datetime': 1591792993,
#   'headline': 'Wedbush Maintains Neutral on Tesla, Raises Price Target to $1000',
#   'id': 32852622,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16220834/wedbush-maintains-neutral-on-tesla-raises-price-target-to-1000'},
#  {'category': 'company',
#   'datetime': 1591791350,
#   'headline': 'USA: Les valeurs à suivre à Wall Street',
#   'id': 3872765,
#   'image': 'https://img.zonebourse.com/reuters/2020-06-11T130227Z_1_LYNXMPEG5A194_RTROPTP_3_USA-STOCKS-BOEING.JPG',
#   'related': 'TSLA',
#   'source': 'https://www.zonebourse.com',
#   'summary': '',
#   'url': 'https://www.zonebourse.com/actualite-bourse/USA-Les-valeurs-a-suivre-a-Wall-Street--30750291/'},
#  {'category': '',
#   'datetime': 1591791273,
#   'headline': "Musk Says It's Time To Ramp Production Of Tesla Semi: Report",
#   'id': 32852623,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Tanzeel Akhtar',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16220141/musk-says-its-time-to-start-production-of-tesla-semi-report'},
#  {'category': 'company',
#   'datetime': 1591790235,
#   'headline': 'Tesla to start volume production of Semi trucks',
#   'id': 1432945,
#   'image': 'https://www.theglobeandmail.com/resizer/VchGyve3wrCCAIabvOB5aqCd0Z4=/1200x0/filters:quality(80)/cloudfront-us-east-1.images.arcpublishing.com/tgam/Q3KLY5XMTFHFHP3BE7HU3DH4XY.JPG',
#   'related': 'TSLA',
#   'source': 'https://www.theglobeandmail.com',
#   'summary': 'Musk did not specify a timeframe for the production',
#   'url': 'https://www.theglobeandmail.com/business/international-business/us-business/article-tesla-to-start-volume-production-of-semi-trucks/'},
#  {'category': '',
#   'datetime': 1591790149,
#   'headline': "Tesla shares are trading higher after Wedbush raised its price target on the company's stock from $800 to $1000.",
#   'id': 32852624,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/wiim/20/06/16220126/tesla-shares-are-trading-higher-after-wedbush-raised-its-price-target-on-the-companys-stock-from-800'},
#  {'category': 'company',
#   'datetime': 1591789800,
#   'headline': "BUZZ-U.S. STOCKS ON THE MOVE-Tesla, GrubHub, Chico's FAS",
#   'id': 61109109,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?1390740610',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com/articles/buzz-u.s.-stocks-on-the-move-tesla-grubhub-chicos-fas-2020-06-10'},
#  {'category': 'company news',
#   'datetime': 1591789800,
#   'headline': "BUZZ-U.S. STOCKS ON THE MOVE-Tesla, GrubHub, Chico's FAS",
#   'id': 59581001,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?1636094917',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com//articles/buzz-u.s.-stocks-on-the-move-tesla-grubhub-chicos-fas-2020-06-10'},
#  {'category': 'company',
#   'datetime': 1591788168,
#   'headline': "15 Large-Cap Stocks Leading Wall Street's Biggest Rally Ever",
#   'id': 2336705,
#   'image': 'https://investorplace.com/wp-content/uploads/2019/07/large-cap-winner-versus-small-cap.jpg',
#   'related': 'TSLA',
#   'source': 'https://investorplace.com',
#   'summary': 'Wall Street is in the midst of its biggest rally of all time, and these large-cap stocks are leading the way. Which ones should you buy?',
#   'url': 'https://investorplace.com/2020/06/large-cap-stocks-leading-wall-streets-biggest-rally-ever/'},
#  {'category': 'company',
#   'datetime': 1591783203,
#   'headline': 'Elon Musk In Hot Water After Tesla Employees Test Positive For Coronavirus',
#   'id': 4258585,
#   'image': 'https://s1.ibtimes.com/sites/www.ibtimes.com/files/styles/full/public/2019/04/01/fremont-factory_0.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.ibtimes.com',
#   'summary': 'Elon Musk will be held accountable for these infections\xa0because of his public fight since March with Alameda County officials, demanding they allow Fremont to reopen.',
#   'url': 'https://www.ibtimes.com/elon-musk-hot-water-after-tesla-employees-test-positive-coronavirus-2991158'},
#  {'category': 'company',
#   'datetime': 1591782975,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Starbucks, Five Below, Guess? Inc',
#   'id': 61140666,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?1321637703',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com/articles/buzz-u.s.-stocks-on-the-move-starbucks-five-below-guess-inc-2020-06-10'},
#  {'category': 'company news',
#   'datetime': 1591782975,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Starbucks, Five Below, Guess? Inc',
#   'id': 59367940,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?1890946054',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com//articles/buzz-u.s.-stocks-on-the-move-starbucks-five-below-guess-inc-2020-06-10'},
#  {'category': 'company',
#   'datetime': 1591780993,
#   'headline': "Tesla's Double-WTF Chart Of The Year (NASDAQ:TSLA)",
#   'id': 752810,
#   'image': 'https://static3.seekingalpha.com/assets/og_image_192-59bfd51c9fe6af025b2f9f96c807e46f8e2f06c5ae787b15bf1423e6c676d4db.png',
#   'related': 'TSLA',
#   'source': 'seekingalpha',
#   'summary': "Tesla's shares closed at a new closing high today of $949.92. This beat the prior closing high of February 19 of $917.42. But it remains a tad below the intrada",
#   'url': 'https://seekingalpha.com/article/4352996-teslas-double-wtf-chart-of-year'},
#  {'category': 'company',
#   'datetime': 1591780109,
#   'headline': 'Tesla shares surge past $1\xa0000 as Musk revs up the Semi - TechCentral',
#   'id': 1430605,
#   'image': 'https://techcentral.co.za/wp-content/uploads/2020/06/tesla-semi-2156-1120.jpg',
#   'related': 'TSLA',
#   'source': 'https://techcentral.co.za',
#   'summary': 'Tesla\'s stock jumped above $1\xa0000/share on Wednesday after CEO Elon Musk told his staff it was time to bring the Tesla Semi commercial truck to "volume production".',
#   'url': 'https://techcentral.co.za/tesla-shares-surge-past-1-000-as-musk-revs-up-the-semi/98742/'},
#  {'category': 'company',
#   'datetime': 1591779684,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Verint Systems, Eventbrite, Nio',
#   'id': 61140667,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?1246290130',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com/articles/buzz-u.s.-stocks-on-the-move-verint-systems-eventbrite-nio-2020-06-10'},
#  {'category': 'company news',
#   'datetime': 1591779684,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Verint Systems, Eventbrite, Nio',
#   'id': 59591442,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203438Z_1172753215_RC2KWG9X4720_RTRMADP_2_USA-STOCKS.JPG?1379088212',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com//articles/buzz-u.s.-stocks-on-the-move-verint-systems-eventbrite-nio-2020-06-10'},
#  {'category': 'company',
#   'datetime': 1591771626,
#   'headline': 'Stripped of Core Duties, VW CEO Turns to Launch of Electric Car -- WSJ | MarketScreener',
#   'id': 1435109,
#   'image': 'https://www.marketscreener.com/images/twitter_MS_fdblanc.png',
#   'related': 'TSLA',
#   'source': 'https://www.marketscreener.com',
#   'summary': '',
#   'url': 'https://www.marketscreener.com/VOLKSWAGEN-AG-436737/news/Stripped-of-Core-Duties-VW-CEO-Turns-to-Launch-of-Electric-Car-WSJ-30749503/'},
#  {'category': 'company',
#   'datetime': 1591771497,
# ...
#   'id': 1362371,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Investors had breathed a sigh of relief on Friday when President Donald Trump chose not to mention sanctions or tariffs at a press conference about China’s new security law in Hong Kong.  Futures traders had initially shrugged off a weekend of protests against police killings of black people.  After opening lower the Dow Jones Industrial Average  (DJIA)\xa0 reversed losses after the Institute for Supply Management manufacturing index indicated the slowdown in factory production may soon come to an end.',
#   'url': 'https://finance.yahoo.com/m/0213694c-6ecb-3199-bc45-6ea0379b5fe0/here%E2%80%99s-why-the-%E2%80%98unloved-but.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591033063,
#   'headline': 'Tesla patents aluminum "spray quench" process for molecular-level strengthening',
#   'id': 1462799,
#   'image': 'https://www.teslarati.com/wp-content/uploads/2020/01/Fremont-Model-Y-body-shop-Q419-Tesla-3-1024x511.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.teslarati.com',
#   'summary': 'Tesla has submitted a patent that describes a new, more effective cooling process for manufacturing high-strength aluminum components to be used in its product line. The patent entitled, “System and Method for Facilitating Pulsed Spray Quench of Extruded Objects”, describes a quenching process that aims to increase the strength, rigidity, and energy absorption of aluminum …',
#   'url': 'https://www.teslarati.com/tesla-patent-pulsed-spray-quench-aluminum-manufacturing/'},
#  {'category': 'company news',
#   'datetime': 1591030320,
#   'headline': 'Stock Market News: SpaceX Success Launches Tesla, Virgin Galactic Stocks',
#   'id': 1362679,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/qVThvjMLmst2jJkM5x8KWg--~B/aD03ODc7dz0xNDAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/motleyfool.com/b6743fce0f9b19238455721b2d91d63d',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'A partnership between the National Aeronautics and Space Administration and privately held launch company SpaceX was responsible for sending two astronauts to the International Space Station.  The news lifted shares of two other companies, Tesla (NASDAQ: TSLA) and Virgin Galactic Holdings (NYSE: SPCE), for related but somewhat different reasons.  Tesla shares rose almost 6% Monday morning, reaching their best level since their February all-time highs.',
#   'url': 'https://finance.yahoo.com/m/cf6fc993-0411-36f5-a9cb-135fd887431d/stock-market-news%3A-spacex.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591029959,
#   'headline': 'Will protests and looting permanently damage the economy?',
#   'id': 1362485,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/oHWkMXk8_n1n7fa.mZcNvA--~B/aD0zMDAwO3c9NDUwMDtzbT0xO2FwcGlkPXl0YWNoeW9u/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-images/2020-06/0ba00f20-a41c-11ea-bbdf-d648bfdb3720',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': "Here's how investors should be thinking through the impact of social unrest sweeping the country.",
#   'url': 'https://finance.yahoo.com/news/protests-and-looting-may-permanently-damage-the-economy-164559562.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591028940,
#   'headline': "Here's Why Amyris Is Soaring Today",
#   'id': 1362680,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/a.0DoAWiQNP0eWd2jeCVog--~B/aD05MzM7dz0xNDAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/motleyfool.com/5e79d12159bdda2efa5a205fe78f13aa',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': "Shares of Amyris (NASDAQ: AMRS) soared as much as 20.9% today after an article on Seeking Alpha suggested the synthetic biology company could be the next Tesla.  On the one hand, what investor wouldn't want to own the next Tesla?  Shares of the electric vehicle manufacturer and energy pioneer have jumped 3,570% since the initial public offering (IPO).",
#   'url': 'https://finance.yahoo.com/m/ec18a593-a809-3abd-a143-85c23fed8b29/here%27s-why-amyris-is-soaring.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591027620,
#   'headline': 'SpaceX Makes Tesla Stock Look Even Better. Just Ask Wall Street.',
#   'id': 1362681,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'SpaceX’s launch of two astronauts from American soil—the first for the U.S. since 2011 and the only time a NASA crew has headed into space on a commercially built rocket and capsule—made Saturday a day for the history books.  Now Wall Street is explaining why the SpaceX success is good for  (TSLA) stock.  The news connection is obvious: Elon Musk leads both companies.',
#   'url': 'https://finance.yahoo.com/m/88908188-4424-31eb-8eb6-6d1879074011/spacex-makes-tesla-stock-look.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591026125,
#   'headline': 'Dow Jones Erases 150-Point Loss Amid Rising U.S.-China Tensions; Pfizer Dives 8%, But Tesla Surges 6% To Breakout',
#   'id': 1362478,
#   'image': 'https://s.yimg.com/uu/api/res/1.2/PX9Uk69x_0Fx0Sg0jl1KiQ--~B/aD02MDA7dz0xMDY1O3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/640a42b3b1af0667b50e82774cf9718a',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': 'Major stock indexes were higher early Monday on rising U.S.-China tensions. Pfizer dove 7% on a failed drug trial.',
#   'url': 'https://finance.yahoo.com/m/e05827e8-e9a8-398d-9406-7d6fd9fb6a06/dow-jones-erases-150-point.html?.tsrc=rss'},
#  {'category': 'company news',
#   'datetime': 1591024208,
#   'headline': 'How SpaceX could revolutionize the space industry',
#   'id': 1362682,
#   'image': 'https://s.yimg.com/cv/apiv2/social/images/yahoo_default_logo.png',
#   'related': 'TSLA',
#   'source': 'Yahoo',
#   'summary': "Yahoo Finance's Brian Sozzi, Alexis Christoforous, and Ines Ferre speak with ProcureAM CEO Andrew Chanin about what the SpaceX launch means for the future of corporate space travel, and the impact for the broader space economy.",
#   'url': 'https://finance.yahoo.com/video/spacex-could-revolutionize-space-industry-151008273.html?.tsrc=rss'},
#  {'category': 'company',
#   'datetime': 1591022102,
#   'headline': 'Tesla (TSLA) Stock Up 5% after SpaceX Astronaut Launch, Any Relation?',
#   'id': 15830163,
#   'image': 'https://www.coinspeaker.com/wp-content/uploads/2020/06/tesla-spacex-elon-musk.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.coinspeaker.com',
#   'summary': 'SpaceX launch has opened doors of opportunity to investors in space exploration, meanwhile, Tesla (TSLA) stock is up. Is there any relation?',
#   'url': 'https://www.coinspeaker.com/tesla-stock-spacex-relation/'},
#  {'category': 'company',
#   'datetime': 1591020617,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Coty, Tesla, Zoom Video, Zynga',
#   'id': 61101052,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203027Z_514699450_RC2KWG93J9WV_RTRMADP_2_USA-STOCKS.JPG?463825075',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com/articles/buzz-u.s.-stocks-on-the-move-coty-tesla-zoom-video-zynga-2020-06-01'},
#  {'category': 'company news',
#   'datetime': 1591020617,
#   'headline': 'BUZZ-U.S. STOCKS ON THE MOVE-Coty, Tesla, Zoom Video, Zynga',
#   'id': 59066994,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2020-05-26T203027Z_514699450_RC2KWG93J9WV_RTRMADP_2_USA-STOCKS.JPG?1288059641',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': 'A compilation of the most active stocks on U.S. exchanges. For faster updates on individual market-movers, Eikon users please use search string "STXBZ US" and Thomson One users please search "RT/STXBZ US".',
#   'url': 'https://www.nasdaq.com//articles/buzz-u.s.-stocks-on-the-move-coty-tesla-zoom-video-zynga-2020-06-01'},
#  {'category': 'company',
#   'datetime': 1591014540,
#   'headline': "Here's Why Amyris Is Soaring Today",
#   'id': 61108407,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2019-05/0902-Q19%20Total%20Markets%20photos%20and%20gif_CC8.jpg?292347497',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': "What happened\nShares of Amyris (NASDAQ: AMRS) soared as much as 20.9% today after an article on Seeking Alpha suggested the synthetic biology company could be the next Tesla. The bullish take -- the author's first article published on the platform -- pushed shares over the $4 ma",
#   'url': 'https://www.nasdaq.com/articles/heres-why-amyris-is-soaring-today-2020-06-01'},
#  {'category': 'company news',
#   'datetime': 1591014540,
#   'headline': "Here's Why Amyris Is Soaring Today",
#   'id': 59361073,
#   'image': 'https://www.nasdaq.com/sites/acquia.prod/files/2019-05/0902-Q19%20Total%20Markets%20photos%20and%20gif_CC8.jpg?107872160',
#   'related': 'TSLA',
#   'source': 'Nasdaq',
#   'summary': "What happened\nShares of Amyris (NASDAQ: AMRS) soared as much as 20.9% today after an article on Seeking Alpha suggested the synthetic biology company could be the next Tesla. The bullish take -- the author's first article published on the platform -- pushed shares over the $4 ma",
#   'url': 'https://www.nasdaq.com//articles/heres-why-amyris-is-soaring-today-2020-06-01'},
#  {'category': 'company',
#   'datetime': 1591000791,
#   'headline': 'Battery Market Share – Industry Analysis, Growth, Trends, By Type, Top Key Players and Regional Forecast 2019-2026',
#   'id': 727507,
#   'image': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png',
#   'related': 'TSLA',
#   'source': 'marketwatch',
#   'summary': 'Jun 01, 2020 (Market Insight Reports) --\nSelbyville, Delaware, Global Battery Market Report added at Market Study Report LLC offers industry size, share,...',
#   'url': 'https://www.marketwatch.com/story/battery-market-share-industry-analysis-growth-trends-by-type-top-key-players-and-regional-forecast-2019-2026-2020-06-01'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': 'Nio CEO Says Tesla An Ally In Increasing Sales, Remains Bullish On Chinese EV Market Growth',
#   'id': 32496239,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Neer Varshney',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16146910/nio-ceo-says-tesla-an-ally-in-increasing-sales-remains-bullish-on-chinese-ev-market-growth'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': 'Shares of several consumer discretionary companies are trading higher as equities gain amid continued optimism towards a rebound in economic activity, which could lead to a potential rebound in spending.',
#   'id': 31471617,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga\u2003Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/wiim/20/06/16151071/shares-of-several-consumer-discretionary-companies-are-trading-higher-as-equities-gain-amid-continue'},
#  {'category': '',
#   'datetime': 1591012302,
#   'headline': 'Cramer Gives His Opinion On Caleres, Cognex And More',
#   'id': 31789910,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Craig Jones',
#   'summary': '',
#   'url': 'https://www.benzinga.com/markets/penny-stocks/20/06/16148260/cramer-gives-his-opinion-on-caleres-cognex-and-more'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': 'NASA Astronauts Launched By SpaceX Reach International Space Station, Celebrate Historic Moment',
#   'id': 32852639,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Neer Varshney',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16147025/nasa-astronauts-launched-by-spacex-reach-international-space-station-celebrate-historic-moment'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': 'Watching Teslare Shares As Hearing Wedbush Publishing Note On Space X Launch, Battery Announcement',
#   'id': 32852637,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16153096/watching-teslare-shares-as-hearing-wedbush-publishing-note-on-space-x-launch-battery-announcement'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': 'Tesla Shares Spike, Hitting Session High Of $886.6 After Wedbush Note Rumors',
#   'id': 32852636,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/news/20/06/16153110/tesla-shares-spike-hitting-session-high-of-886-6-after-wedbush-note-rumors'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': "Wedbush Says 'SpaceX Success Further Elevates Musk and Tesla Brand'; Says While Tesla And SpaceX Are Separate, 'from a consumer perspective the Musk DNA remains the linchpin to both of these next generation technology stalwarts'",
#   'id': 32852635,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/20/06/16153464/wedbush-says-spacex-success-further-elevates-musk-and-tesla-brand-says-while-tesla-'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': "Wedbush Says 'Battery enhancements and China remain key to the Telsa story'",
#   'id': 32852633,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/20/06/16153467/wedbush-says-battery-enhancements-and-china-remain-key-to-the-telsa-story'},
#  {'category': '',
#   'datetime': 1590969600,
#   'headline': "Wedbush Maintains Neutral Rating On Tesla, Says 'We continue to believe EV demand in China is starting to accelerate with Tesla competing with a number of domestic and international competitors for market share'",
#   'id': 32852634,
#   'image': '',
#   'related': 'TSLA',
#   'source': 'Benzinga Newsdesk',
#   'summary': '',
#   'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/20/06/16153475/wedbush-maintains-neutral-rating-on-tesla-says-we-continue-to-believe-ev-demand-in-'},
#  {'category': 'company',
#   'datetime': 1590969600,
#   'headline': 'PreMarket Prep Stock Of The Day: Tesla',
#   'id': 1465204,
#   'image': 'https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/tesla-2875852_1920_15.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.benzinga.com',
#   'summary': "Benzinga's\xa0PreMarket Prep\xa0airs every morning from 8-9 a.m. ET. During that fast-paced, highly informative hour, traders and investors tune in to get the major news...",
#   'url': 'https://www.benzinga.com/trading-ideas/long-ideas/20/06/16151640/premarket-prep-stock-of-the-day-tesla'},
#  {'category': 'company',
#   'datetime': 1590969600,
#   'headline': "SpaceX Falcon 9 Launch A 'Major Shot In The Arm' For Tesla Brand, Analyst Says",
#   'id': 1465192,
#   'image': 'https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/tesla-1724773_1920_127.jpg',
#   'related': 'TSLA',
#   'source': 'https://www.benzinga.com',
#   'summary': 'Tesla Inc (NASDAQ: TSLA) shares traded higher by 5.8% on Monday following a successful launch by\xa0CEO Elon Musk’s other company, SpaceX.\nWhile Tesla and SpaceX have only...',
#   'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/20/06/16153092/spacex-falcon-9-launch-a-major-shot-in-the-arm-for-tesla-brand-analyst-says'},
#  {'category': 'company',
#   'datetime': 1590969600,
#   'headline': "Elon Musk's Baby Has A Nickname, Grimes Reveals",
#   'id': 1465189,
#   'image': 'https://cdn.benzinga.com/files/imagecache/og_image_social_share_1200x630/images/story/2012/elon_musk_baby.png',
#   'related': 'TSLA',
#   'source': 'https://www.benzinga.com',
#   'summary': 'Tesla Inc. (NASDAQ: TSLA) CEO Elon Musk’s partner,\xa0Grimes, has revealed the nickname for their infant named X Æ A-12.\nWhat Happened\nGrimes, whose given name is...',
#   'url': 'https://www.benzinga.com/news/20/06/16146849/elon-musks-baby-has-a-nickname-grimes-reveals'}]

# %%
news[1]['summary']
# Out:
# 'General Motors Company (NYSE: GM) has hired a former Tesla Inc. (NASDAQ: TSLA) engineer, Louise Zhang,\xa0as the new vice president of product safety at Cruise, its self-driving...'

# %% [markdown]
# # Bond market data sources
#
# ## Finam
#
# https://bonds.finam.ru/issue/details0288D00001/default.asp

# %%
coupon_data = pd.read_excel('data/mts_bond.xlsx')

coupon_data
# Out:
#      №        Дата Ставка Купоны, % Купоны,Размер  Погашение, %от  \
# 0    1  21.05.2020   6,6%     1,645     16,45RUR              NaN
# 1    2  20.08.2020   6,6%     1,645     16,45RUR              NaN
# 2    3  19.11.2020   6,6%     1,645     16,45RUR              NaN
# 3    4  18.02.2021   6,6%     1,645     16,45RUR              NaN
# 4    5  20.05.2021   6,6%     1,645     16,45RUR              NaN
# 5    6  19.08.2021   6,6%     1,645     16,45RUR              NaN
# 6    7  18.11.2021   6,6%     1,645     16,45RUR              NaN
# 7    8  17.02.2022   6,6%     1,645     16,45RUR              NaN
# 8    9  19.05.2022   6,6%     1,645     16,45RUR              NaN
# 9   10  18.08.2022   6,6%     1,645     16,45RUR              NaN
# 10  11  17.11.2022   6,6%     1,645     16,45RUR              NaN
# 11  12  16.02.2023   6,6%     1,645     16,45RUR              NaN
# 12  13  18.05.2023   6,6%     1,645     16,45RUR              NaN
# 13  14  17.08.2023   6,6%     1,645     16,45RUR              NaN
# 14  15  16.11.2023   6,6%     1,645     16,45RUR              NaN
# 15  16  15.02.2024   6,6%     1,645     16,45RUR              NaN
# 16  17  16.05.2024   6,6%     1,645     16,45RUR              NaN
# 17  18  15.08.2024   6,6%     1,645     16,45RUR              NaN
# 18  19  14.11.2024   6,6%     1,645     16,45RUR              NaN
# 19  20  13.02.2025   6,6%     1,645     16,45RUR              NaN
# 20  21  15.05.2025   6,6%     1,645     16,45RUR              NaN
# 21  22  14.08.2025   6,6%     1,645     16,45RUR              NaN
# 22  23  13.11.2025   6,6%     1,645     16,45RUR              NaN
# 23  24  12.02.2026   6,6%     1,645     16,45RUR              NaN
# 24  25  14.05.2026   6,6%     1,645     16,45RUR              NaN
# 25  26  13.08.2026   6,6%     1,645     16,45RUR              NaN
# 26  27  12.11.2026   6,6%     1,645     16,45RUR              NaN
# 27  28  11.02.2027   6,6%     1,645     16,45RUR            100.0
#
#    Погашение,Размер
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# 20              NaN
# 21              NaN
# 22              NaN
# 23              NaN
# 24              NaN
# 25              NaN
# 26              NaN
# 27          1000RUR

# %%
coupon_data.columns = ['number', 'date', 'coupon_rate', 'coupon_percent', 'coupon',
       'face_value_percent', 'face_value']

coupon_data['coupon'] = coupon_data['coupon'].str.replace(',', '.')
coupon_data['coupon'] = coupon_data['coupon'].str.extract(r'(\d+.\d+)').astype('float')

coupon_data['face_value'] = coupon_data['face_value'].str.extract(r'(\d+.\d+)').astype('float')
coupon_data['face_value'] = coupon_data['face_value'] .fillna(0)

coupon_data.tail()
# Out:
#     number        date coupon_rate coupon_percent  coupon  face_value_percent  \
# 23      24  12.02.2026        6,6%          1,645   16.45                 NaN
# 24      25  14.05.2026        6,6%          1,645   16.45                 NaN
# 25      26  13.08.2026        6,6%          1,645   16.45                 NaN
# 26      27  12.11.2026        6,6%          1,645   16.45                 NaN
# 27      28  11.02.2027        6,6%          1,645   16.45               100.0
#
#     face_value
# 23         0.0
# 24         0.0
# 25         0.0
# 26         0.0
# 27      1000.0

# %%
coupon_data['date'] = pd.to_datetime(coupon_data['date'], format='%d.%m.%Y')

# %%
r = 0.06
current_date = date(2021, 1, 15)

# %%
coupon_data['days_till_payment'] = (coupon_data['date'].dt.date - current_date).dt.days

coupon_data['will_be_paid'] = coupon_data['days_till_payment'] > 0

coupon_data.loc[~coupon_data['will_be_paid'], 'days_till_payment'] = 0

coupon_data['discount_factor'] = np.power( 1 / (1 + r) , coupon_data['days_till_payment']/365)

coupon_data.head(10)
# Out:
#    number       date coupon_rate coupon_percent  coupon  face_value_percent  \
# 0       1 2020-05-21        6,6%          1,645   16.45                 NaN
# 1       2 2020-08-20        6,6%          1,645   16.45                 NaN
# 2       3 2020-11-19        6,6%          1,645   16.45                 NaN
# 3       4 2021-02-18        6,6%          1,645   16.45                 NaN
# 4       5 2021-05-20        6,6%          1,645   16.45                 NaN
# 5       6 2021-08-19        6,6%          1,645   16.45                 NaN
# 6       7 2021-11-18        6,6%          1,645   16.45                 NaN
# 7       8 2022-02-17        6,6%          1,645   16.45                 NaN
# 8       9 2022-05-19        6,6%          1,645   16.45                 NaN
# 9      10 2022-08-18        6,6%          1,645   16.45                 NaN
#
#    face_value  days_till_payment  will_be_paid  discount_factor
# 0         0.0                  0         False         1.000000
# 1         0.0                  0         False         1.000000
# 2         0.0                  0         False         1.000000
# 3         0.0                 34          True         0.994587
# 4         0.0                125          True         0.980243
# 5         0.0                216          True         0.966105
# 6         0.0                307          True         0.952172
# 7         0.0                398          True         0.938439
# 8         0.0                489          True         0.924905
# 9         0.0                580          True         0.911566

# %%
coupon_data['coupon'] * coupon_data['will_be_paid'] * coupon_data['discount_factor']
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3     16.360955
# 4     16.124992
# 5     15.892433
# 6     15.663227
# 7     15.437327
# 8     15.214685
# 9     14.995255
# 10    14.778988
# 11    14.565841
# 12    14.355768
# 13    14.148725
# 14    13.944668
# 15    13.743554
# 16    13.545340
# 17    13.349985
# 18    13.157447
# 19    12.967687
# 20    12.780663
# 21    12.596336
# 22    12.414668
# 23    12.235620
# 24    12.059154
# 25    11.885233
# 26    11.713821
# 27    11.544880
# dtype: float64

# %%
coupon_data['face_value'] * coupon_data['will_be_paid'] * coupon_data['discount_factor']
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# 5       0.000000
# 6       0.000000
# 7       0.000000
# 8       0.000000
# 9       0.000000
# 10      0.000000
# 11      0.000000
# 12      0.000000
# 13      0.000000
# 14      0.000000
# 15      0.000000
# 16      0.000000
# 17      0.000000
# 18      0.000000
# 19      0.000000
# 20      0.000000
# 21      0.000000
# 22      0.000000
# 23      0.000000
# 24      0.000000
# 25      0.000000
# 26      0.000000
# 27    743.427677
# dtype: float64

# %%
(coupon_data['coupon'] + coupon_data['face_value']) * coupon_data['discount_factor'] * coupon_data['will_be_paid']
# Out:
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3      16.375407
# 4      16.177421
# 5      15.981829
# 6      15.788602
# 7      15.597711
# 8      15.409127
# 9      15.222824
# 10     15.038774
# 11     14.856948
# 12     14.677321
# 13     14.499866
# 14     14.324556
# 15     14.151366
# 16     13.980270
# 17     13.811242
# 18     13.644258
# 19     13.479293
# 20     13.316323
# 21     13.155322
# 22     12.996269
# 23     12.839138
# 24     12.683907
# 25     12.530553
# 26     12.379053
# 27    755.657062
# dtype: float64

# %%
bond_value_dummy = ((coupon_data['coupon'] + coupon_data['face_value']) * coupon_data['discount_factor']).sum()

bond_value_dummy
# Out:
# 1096.643690501714

# %% [markdown]
# ## Bloomberg

# %%
data_bonds = pd.read_excel('data/Extract1_ListQuotes1_one_bond.xlsx', parse_dates=['Date'], index_col=0)

data_bonds = data_bonds.dropna()

data_bonds.head()
# Out:
#             RU000A101FH6
# Date
# 2020-02-20        100.40
# 2020-02-21        100.39
# 2020-02-25        100.00
# 2020-02-26        100.02
# 2020-02-27         99.49

# %%
plot_fields =  ['RU000A101FH6']

fig = plt.figure(figsize=(16, 5))

plt.plot(data_bonds[plot_fields])
plt.legend(plot_fields)

plt.title("Bond daily price", weight="bold")

plt.show()

# %% [markdown]
# # Probably won't be included

# %% [markdown]
# ## Cbonds
#
# https://cbonds.ru/bonds/682351/
#
# https://www.moex.com/ru/issue.aspx?code=RU000A101FH6&board=

# %% [markdown]
# https://quant.stackexchange.com/questions/36532/pricing-a-fixed-rate-bond-in-quantlib-python
#
#
# https://pypi.org/project/qfrm/
